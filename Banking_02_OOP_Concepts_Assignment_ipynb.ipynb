# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafimunnisa/nafimunnisa-2026/blob/main/Banking_02_OOP_Concepts_Assignment_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Banking Assignment — Object-Oriented Programming (100 Questions with Hints)

# %%
#Q1. Create a account class for banking case 1; use sample reference ACC-1001 and explain the result.


class Account():
  def __init__(self, Account_Number, Customer_Name, Account_Balance):
    self.Account_Number = Account_Number
    self.Customer_Name = Customer_Name
    self.Account_Balance = Account_Balance

  def display_details(self):
    print("Account Number:",self.Account_Number)
    print("Customer Name:",self.Customer_Name)
    print("Balance:",self.Account_Balance)

Account_details = [Account("ACC-1001","Nafim",1000),Account("Acc-1001","Rubina",5000)]

for account in Account_details:
  account.display_details()
# Out:
# Account Number: ACC-1001
# Customer Name: Nafim
# Balance: 1000
# Account Number: Acc-1001
# Customer Name: Rubina
# Balance: 5000

# %%
#Q2. Add an initializer to accountholder for banking case 1; use sample reference ACC-1002 and explain the result.


class AccountHolder:
  def __init__(self,Account_Number,customer_name,Customer_ph_number):
    self.Account_Number = Account_Number
    self.customer_name = customer_name
    self.Customer_ph_number = Customer_ph_number

  def display(self):
    print("Account Number:",self.Account_Number)
    print("Customer Name:",self.customer_name )
    print("Customer Phone Number:",self.Customer_ph_number)

Account1 = AccountHolder("ACC-1002","Nafimunnisa",9866419847)

Account1.display()
# Out:
# Account Number: ACC-1002
# Customer Name: Nafimunnisa
# Customer Phone Number: 9866419847

# %%
#Q3. Represent an transfer object for banking case 1; use sample reference ACC-1003 and explain the result.


class Transfer:
  def __init__(self,Account_Number,Receiver_AccNumber,Transfer_Amount):
    self.Account_Number = Account_Number
    self.Receiver_AccNumber = Receiver_AccNumber
    self.Transfer_Amount = Transfer_Amount

  def Display_Transfer_Details(self):
    print("Account Number:",self.Account_Number)
    print("Receiver Account Number:",self.Receiver_AccNumber)
    print("Transfer Amount:",self.Transfer_Amount)

Transfer1 = Transfer("ACC-1003","Acc-1003",500)

Transfer1.Display_Transfer_Details()
# Out:
# Account Number: ACC-1003
# Receiver Account Number: Acc-1003
# Transfer Amount: 500

# %%
#Q4. Add a method that calculates line total for banking case 1; use sample reference ACC-1004 and explain the result.


class Transction:

  def __init__(self,Account_Number,Amount,Charges):
    self.Account_Number = Account_Number
    self.Amount = Amount
    self.Charges = Charges

  def Display_Calcualtion_total(self):
    print("Account Number:",self.Account_Number)
    print("Amount of Transction:",self.Amount)
    print("Charges for Transction:",self.Charges)
    print("Total Amount with Charges:",self.Amount + self.Charges)

total = [Transction("ACC-1004",5000,200),Transction("Acc-1004",10000,400)]

for i in total:
  i.Display_Calcualtion_total()
  print()
# Out:
# Account Number: ACC-1004
# Amount of Transction: 5000
# Charges for Transction: 200
# Total Amount with Charges: 5200
#
# Account Number: Acc-1004
# Amount of Transction: 10000
# Charges for Transction: 400
# Total Amount with Charges: 10400

# %%
#Q5. Use a class attribute for branch name for banking case 1; use sample reference ACC-1005 and explain the result.


class Account:

  Branch_Name = "Hyderabad Branch"

  def __init__(self,Account_Number,Customer_Name,Balance):
    self.Account_Number = Account_Number
    self.Customer_Name = Customer_Name
    self.Balance = Balance

  def Display(self):
    print("Account Number:",self.Account_Number)
    print("Customer name",self.Customer_Name)
    print("Balance",self.Balance)
    print("Branch Name:",Account.Branch_Name)

Accounts = [Account("ACC-1005","Nafimunnisa",800),Account("Acc-1005","Nafi",900)]

for i in Accounts:
  i.Display()
  print()

 ## A class attribute is shared by all objects of a class.
 ## Here, branch_name is a class attribute that stores the common branch name for all accounts, while account details are stored as instance attributes.
# Out:
# Account Number: ACC-1005
# Customer name Nafimunnisa
# Balance 800
# Branch Name: Hyderabad Branch
#
# Account Number: Acc-1005
# Customer name Nafi
# Balance 900
# Branch Name: Hyderabad Branch

# %%
#Q6. Write a readable str method for banking case 1; use sample reference ACC-1006 and explain the result.


class Account:

  def __init__(self,Account_Number,Account_Balance,Account_Type):
    self.Account_Number = Account_Number
    self.Account_Balance = Account_Balance
    self.Account_Type = Account_Type

  def __str__(self):
    return f"Account Number : {self.Account_Number}\nAccount Balance : {self.Account_Balance}\nAccount Type : {self.Account_Type}"

Accounts = [Account("ACC-1006","Hussain","Savings"),Account('ACC-1006',"Nafim","Current"),Account("Acc-1006","Rubina","Savings")]

for i in Accounts:
  print(i)
  print()

  ##The __str__() method is used to provide a readable string representation of an object.
  ## When print(account1)
# Out:
# Account Number : ACC-1006
# Account Balance : Hussain
# Account Type : Savings
#
# Account Number : ACC-1006
# Account Balance : Nafim
# Account Type : Current
#
# Account Number : Acc-1006
# Account Balance : Rubina
# Account Type : Savings

# %%
#Q7. Compare two account references with eq for banking case 1; use sample reference ACC-1007 and explain the result.


class Account:

  def __init__(self,Account_Number,Account_Name,Balance):
    self.Account_Number = Account_Number
    self.Account_Name = Account_Name
    self.Balance = Balance

  def __eq__(self, other):
    return self.Account_Number == other.Account_Number and self.Account_Name == other.Account_Name and self.Balance == other.Balance

Accounts = [Account("ACC-1007","Yuvateja",5000),Account('ACC-1007',"Yuvateja",5000),Account("Acc-1007","YUVATEJA",5000)]

print(Accounts[0]==Accounts[1])
print(Accounts[1]==Accounts[2])

## The __eq__() method is used to define custom object comparison.
## In this question, two account objects are considered equal when their account numbers are the same.
# Out:
# True
# False

# %%
#Q8. Protect a amount with a property for banking case 1; use sample reference ACC-1008 and explain the result.


class Account:

  def __init__(self,Account_Number,Balance):
    self.Account_Number = Account_Number
    self._Balance = Balance

  @property
  def Balance(self):
    return self._Balance

account = Account("ACC-1008", 50000)
print("Account Number :", account.Account_Number)
print("Balance :", account.Balance)

## A property is used to protect and control access to an attribute. In ACC-1008,
## the balance is stored as a protected attribute (_balance) and accessed through the @property method, ensuring safer data handling.
# Out:
# Account Number : ACC-1008
# Balance : 50000

# %%
#Q9. Create portfolio and add_item for banking case 1; use sample reference ACC-1009 and explain the result.


class Portfolio:

  def __init__(self,Account_Number):
    self.Account_Numner = Account_Number
    self.items = []

  def add_item(self,item):
    self.items.append(item)

  def display(self):
    print("Account Number:",self.Account_Numner)
    print("Portfoilo:",self.items)

portfoilo = Portfolio("ACC-1009")

portfoilo.add_item("Fixed Deposit")
portfoilo.add_item("Mutual Funds")

portfoilo.display()

### The Portfolio class manages a collection of banking or investment products.
### The add_item() method adds new items to the portfolio, and ACC-1009 maintains a list of all added investments.
# Out:
# Account Number: ACC-1009
# Portfoilo: ['Fixed Deposit', 'Mutual Funds']

# %%
#Q10. Model a branchaddress for banking case 1; use sample reference ACC-1010 and explain the result.


class BranchAddress:

    def __init__(self, account_number, branch_name, city, pincode):
        self.account_number = account_number
        self.branch_name = branch_name
        self.city = city
        self.pincode = pincode

    def display(self):
        print("Account Number :", self.account_number)
        print("Branch Name    :", self.branch_name)
        print("City           :", self.city)
        print("Pincode        :", self.pincode)


branch = [BranchAddress("ACC-1010","Main Branch","Bengaluru",560001),BranchAddress("Acc-1010","Main Branch","Bengaluru",560001)]

for i in branch:
  i.display()
  print()

### The BranchAddress class is used to model a bank branch's address information.
### An object for ACC-1010 stores and displays branch details such as branch name, city, and pincode.
# Out:
# Account Number : ACC-1010
# Branch Name    : Main Branch
# City           : Bengaluru
# Pincode        : 560001
#
# Account Number : Acc-1010
# Branch Name    : Main Branch
# City           : Bengaluru
# Pincode        : 560001

# %%
#Q11. Use a static method to validate account reference for banking case 1; use sample reference ACC-1011 and explain the result.


class Account:

  @staticmethod
  def validationaccount(account_number):
    if account_number.startswith("ACC-"):
      print(account_number, "- Vaild")
    else:
      print(account_number,"-Invalid")

account = ["ACC-1011","ABC-1011","ACC-10111"]

for i in account:
  Account.validationaccount(i)

### A static method is used when a function belongs to a class but does not need object data.

### Here, validationaccount() checks whether the account reference follows the expected format (ACC-1011), and returns a validation result.
# Out:
# ACC-1011 - Vaild
# ABC-1011 -Invalid
# ACC-10111 - Vaild

# %%
#Q12. Use a class method as an alternate constructor for banking case 1; use sample reference ACC-1012 and explain the result.


class Account:

    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    @classmethod
    def create_account(cls):
      # return [cls("ACC-1012", "Yuvateja", 50000),cls("ACC-1011", "Yuvateja", 50000)]
      return cls("ACC-1012", "Yuvateja", 50000)

    def display(self):
        print("Account Number :", self.account_number)
        print("Account Name   :", self.account_name)
        print("Balance        :", self.balance)

account = Account.create_account()

# for i in account:
#   i.display()
#   print()

account.display()

### A class method uses cls and can be used as an alternate constructor.
### In this, create_account() creates and returns an Account object for ACC-1012 without directly calling the class constructor.
# Out:
# Account Number : ACC-1012
# Account Name   : Yuvateja
# Balance        : 50000

# %%
#Q13. Track object count for banking case 1; use sample reference ACC-1013 and explain the result.


class Account:

    count = 0

    def __init__(self, account_number, account_name, balance,account_type):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance
        self.account_type = account_type

        Account.count += 1

    def display(self):
        print("Account Number :", self.account_number)
        print("Account Name   :", self.account_name)
        print("Balance        :", self.balance)

accounts = [Account("ACC-1013", "Yuvateja", 50000,"Savings"),Account("ACC-1", "Rahul", 70000,"Current"),Account("Acc-1013", "Rahul", 70000,"Current")]


print("Total Objects Created :", Account.count)

### A class variable is used to track the total number of objects created.
### Every time an Account object is instantiated, the count is incremented, allowing the program to maintain an object count across all instances.
# Out:
# Total Objects Created : 3

# %%
#Q14. Model a loyaltyaccount for banking case 1; use sample reference ACC-1014 and explain the result.


class LoyaltyAccount:

    def __init__(self, account_number, customer_name, balance, loyalty_points):
        self.account_number = account_number
        self.customer_name = customer_name
        self.balance = balance
        self.loyalty_points = loyalty_points

    def display(self):
        print("Account Number :", self.account_number)
        print("Customer Name  :", self.customer_name)
        print("Balance        :", self.balance)
        print("Loyalty Points :", self.loyalty_points)


account = LoyaltyAccount("ACC-1014","Yuvateja",50000,250)

account.display()

## A LoyaltyAccount is a bank account that also tracks reward or loyalty points.
### For ACC-1014, the account stores customer details, balance, and loyalty points, which can be used for banking rewards and benefits.
# Out:
# Account Number : ACC-1014
# Customer Name  : Yuvateja
# Balance        : 50000
# Loyalty Points : 250

# %%
#Q15. Create a supplier class for banking case 1; use sample reference ACC-1015 and explain the result.


class Supplier:

    def __init__(self, account_number, supplier_name, amount):
        self.account_number = account_number
        self.supplier_name = supplier_name
        self.amount = amount

    def display(self):
        print("Account Number :", self.account_number)
        print("Supplier Name  :", self.supplier_name)
        print("Amount         :", self.amount)


supplier = Supplier("ACC-1015", "ABC Traders", 50000)

supplier.display()

## The Supplier class is used to represent supplier information in a banking system.
## The object supplier1 stores the account reference ACC-1015, supplier name, and amount, and displays the details successfully.
# Out:
# Account Number : ACC-1015
# Supplier Name  : ABC Traders
# Amount         : 50000

# %%
#Q16. Create a account class for banking case 2; use sample reference ACC-1016 and explain the result.


class Account():
  def __init__(self, Account_Number, Customer_Name, Account_Balance):
    self.Account_Number = Account_Number
    self.Customer_Name = Customer_Name
    self.Account_Balance = Account_Balance

  def display_details(self):
    print("Account Number:",self.Account_Number)
    print("Customer Name:",self.Customer_Name)
    print("Balance:",self.Account_Balance)

Account_details = [Account("ACC-1016","Nafimunnisa",1000),Account("Acc-1016","Rubina",5000)]

for account in Account_details:
  account.display_details()
  print()
# Out:
# Account Number: ACC-1016
# Customer Name: Nafimunnisa
# Balance: 1000
#
# Account Number: Acc-1016
# Customer Name: Rubina
# Balance: 5000

# %%
#Q17. Add an initializer to accountholder for banking case 2; use sample reference ACC-1017 and explain the result.


class AccountHolder:
  def __init__(self,Account_Number,customer_name,Customer_ph_number):
    self.Account_Number = Account_Number
    self.customer_name = customer_name
    self.Customer_ph_number = Customer_ph_number

  def display(self):
    print("Account Number:",self.Account_Number)
    print("Customer Name:",self.customer_name )
    print("Customer Phone Number:",self.Customer_ph_number)

Account1 = AccountHolder("ACC-1017","Nafimunnisa",9866419847)

Account1.display()
# Out:
# Account Number: ACC-1017
# Customer Name: Nafimunnisa
# Customer Phone Number: 9866419847

# %%
#Q18. Represent an transfer object for banking case 2; use sample reference ACC-1018 and explain the result.


class Transfer:
  def __init__(self,Account_Number,Receiver_AccNumber,Transfer_Amount):
    self.Account_Number = Account_Number
    self.Receiver_AccNumber = Receiver_AccNumber
    self.Transfer_Amount = Transfer_Amount

  def Display_Transfer_Details(self):
    print("Account Number:",self.Account_Number)
    print("Receiver Account Number:",self.Receiver_AccNumber)
    print("Transfer Amount:",self.Transfer_Amount)

Transfer1 = Transfer("ACC-1018","Acc-18",500)

Transfer1.Display_Transfer_Details()
# Out:
# Account Number: ACC-1018
# Receiver Account Number: Acc-18
# Transfer Amount: 500

# %%
#Q19. Add a method that calculates line total for banking case 2; use sample reference ACC-1019 and explain the result.


class Transction:

  def __init__(self,Account_Number,Amount,Charges):
    self.Account_Number = Account_Number
    self.Amount = Amount
    self.Charges = Charges

  def Display_Calcualtion_total(self):
    print("Account Number:",self.Account_Number)
    print("Amount of Transction:",self.Amount)
    print("Charges for Transction:",self.Charges)
    print("Total Amount with Charges:",self.Amount + self.Charges)

total = [Transction("ACC-1019",5000,200),Transction("Acc-0019",10000,400)]

for i in total:
  i.Display_Calcualtion_total()
  print()
# Out:
# Account Number: ACC-1019
# Amount of Transction: 5000
# Charges for Transction: 200
# Total Amount with Charges: 5200
#
# Account Number: Acc-0019
# Amount of Transction: 10000
# Charges for Transction: 400
# Total Amount with Charges: 10400

# %%
#Q20. Use a class attribute for branch name for banking case 2; use sample reference ACC-1020 and explain the result.


class Account:

  Branch_Name = "Hyderabad Branch"

  def __init__(self,Account_Number,Customer_Name,Balance):
    self.Account_Number = Account_Number
    self.Customer_Name = Customer_Name
    self.Balance = Balance

  def Display(self):
    print("Account Number:",self.Account_Number)
    print("Customer name",self.Customer_Name)
    print("Balance",self.Balance)
    print("Branch Name:",Account.Branch_Name)

Accounts = [Account("ACC-1020","Nafim",800),Account("Acc-1020","Unnisa",900)]

for i in Accounts:
  i.Display()
  print()

 ## A class attribute is shared by all objects of a class.
 ## Here, branch_name is a class attribute that stores the common branch name for all accounts, while account details are stored as instance attributes.
# Out:
# Account Number: ACC-1020
# Customer name Nafim
# Balance 800
# Branch Name: Hyderabad Branch
#
# Account Number: Acc-1020
# Customer name Unnisa
# Balance 900
# Branch Name: Hyderabad Branch

# %%
#Q21. Write a readable str method for banking case 2; use sample reference ACC-1021 and explain the result.


class Account:

  def __init__(self,Account_Number,Account_Balance,Account_Type):
    self.Account_Number = Account_Number
    self.Account_Balance = Account_Balance
    self.Account_Type = Account_Type

  def __str__(self):
    return f"Account Number : {self.Account_Number}\nAccount Balance : {self.Account_Balance}\nAccount Type : {self.Account_Type}"

Accounts = [Account("ACC-1021","Nafim","Savings"),Account('ACC-1021',"Nafim","Current"),Account("Acc-1021","Nafim","Savings")]

for i in Accounts:
  print(i)
  print()

  ##The __str__() method is used to provide a readable string representation of an object.
  ## When print(account1) is called, the account details of ACC-1021 are displayed instead of the default object memory address.
# Out:
# Account Number : ACC-1021
# Account Balance : Nafim
# Account Type : Savings
#
# Account Number : ACC-1021
# Account Balance : Nafim
# Account Type : Current
#
# Account Number : Acc-1021
# Account Balance : Nafim
# Account Type : Savings

# %%
#Q22. Compare two account references with eq for banking case 2; use sample reference ACC-1022 and explain the result.


class Account:

  def __init__(self,Account_Number,Account_Name,Balance):
    self.Account_Number = Account_Number
    self.Account_Name = Account_Name
    self.Balance = Balance

  def __eq__(self, other):
    return self.Account_Number == other.Account_Number and self.Account_Name == other.Account_Name and self.Balance == other.Balance

Accounts = [Account("ACC-1021","Nafim",5000),Account('ACC-1021',"Nafim",5000),Account("Acc-1021","Nafim",5000)]

print(Accounts[0]==Accounts[1])
print(Accounts[1]==Accounts[2])

## The __eq__() method is used to define custom object comparison.
## In this question, two account objects are considered equal when their account numbers are the same.
# Out:
# True
# False

# %%
#Q23. Protect a amount with a property for banking case 2; use sample reference ACC-1023 and explain the result.


class Account:

  def __init__(self,Account_Number,Balance):
    self.Account_Number = Account_Number
    self._Balance = Balance

  @property
  def Balance(self):
    return self._Balance

account = Account("ACC-1023", 50000)
print("Account Number :", account.Account_Number)
print("Balance :", account.Balance)

## A property is used to protect and control access to an attribute. In ACC-1008,
## the balance is stored as a protected attribute (_balance) and accessed through the @property method, ensuring safer data handling.
# Out:
# Account Number : ACC-1023
# Balance : 50000

# %%
#Q24. Create portfolio and add_item for banking case 2; use sample reference ACC-1024 and explain the result.


class Portfolio:

  def __init__(self,Account_Number):
    self.Account_Numner = Account_Number
    self.items = []

  def add_item(self,item):
    self.items.append(item)

  def display(self):
    print("Account Number:",self.Account_Numner)
    print("Portfoilo:",self.items)

portfoilo = Portfolio("ACC-1024")

portfoilo.add_item("Fixed Deposit")
portfoilo.add_item("Mutual Funds")

portfoilo.display()

### The Portfolio class manages a collection of banking or investment products.
### The add_item() method adds new items to the portfolio, and ACC-1024 maintains a list of all added investments.
# Out:
# Account Number: ACC-1024
# Portfoilo: ['Fixed Deposit', 'Mutual Funds']

# %%
#Q25. Model a branchaddress for banking case 2; use sample reference ACC-1025 and explain the result.


class BranchAddress:

    def __init__(self, account_number, branch_name, city, pincode):
        self.account_number = account_number
        self.branch_name = branch_name
        self.city = city
        self.pincode = pincode

    def display(self):
        print("Account Number :", self.account_number)
        print("Branch Name    :", self.branch_name)
        print("City           :", self.city)
        print("Pincode        :", self.pincode)


branch = [BranchAddress("ACC-1025","Main Branch","Hyderabad",500094),BranchAddress("Acc-1025","Main Branch","Hyderabad",500094)]

for i in branch:
  i.display()
  print()

### The BranchAddress class is used to model a bank branch's address information.
### An object for ACC-1025 stores and displays branch details such as branch name, city, and pincode.
# Out:
# Account Number : ACC-1025
# Branch Name    : Main Branch
# City           : Hyderabad
# Pincode        : 500094
#
# Account Number : Acc-1025
# Branch Name    : Main Branch
# City           : Hyderabad
# Pincode        : 500094

# %%
#Q26. Use a static method to validate account reference for banking case 2; use sample reference ACC-1026 and explain the result.


class Account:

  @staticmethod
  def validationaccount(account_number):
    if account_number.startswith("ACC-"):
      print(account_number, "- Vaild")
    else:
      print(account_number,"-Invalid")

account = ["ACC-1026","ABC-1026","ACC-10266"]

for i in account:
  Account.validationaccount(i)

### A static method is used when a function belongs to a class but does not need object data.

### Here, validationaccount() checks whether the account reference follows the expected format (ACC-1026), and returns a validation result.
# Out:
# ACC-1026 - Vaild
# ABC-1026 -Invalid
# ACC-10266 - Vaild

# %%
#Q27. Use a class method as an alternate constructor for banking case 2; use sample reference ACC-1027 and explain the result.


class Account:

    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    @classmethod
    def create_account(cls):
      # return [cls("ACC-1027", "Nafim", 50000),cls("Acc-1027", "Nafim", 50000)]
      return cls("ACC-1027", "Nafim", 50000)

    def display(self):
        print("Account Number :", self.account_number)
        print("Account Name   :", self.account_name)
        print("Balance        :", self.balance)

account = Account.create_account()

# for i in account:
#   i.display()
#   print()

account.display()

### A class method uses cls and can be used as an alternate constructor.
### In this, create_account() creates and returns an Account object for ACC-1027 without directly calling the class constructor.
# Out:
# Account Number : ACC-1027
# Account Name   : Nafim
# Balance        : 50000

# %%
#Q28. Track object count for banking case 2; use sample reference ACC-1028 and explain the result.


class Account:

    count = 0

    def __init__(self, account_number, account_name, balance,account_type):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance
        self.account_type = account_type

        Account.count += 1

    def display(self):
        print("Account Number :", self.account_number)
        print("Account Name   :", self.account_name)
        print("Balance        :", self.balance)

accounts = [Account("ACC-1028", "Nafim", 50000,"Savings"),Account("Acc-1028", "Ruby", 70000,"Current")]


print("Total Objects Created :", Account.count)

### A class variable is used to track the total number of objects created.
### Every time an Account object is instantiated, the count is incremented, allowing the program to maintain an object count across all instances.
# Out:
# Total Objects Created : 2

# %%
#Q29. Model a loyaltyaccount for banking case 2; use sample reference ACC-1029 and explain the result.


class LoyaltyAccount:

    def __init__(self, account_number, customer_name, balance, loyalty_points):
        self.account_number = account_number
        self.customer_name = customer_name
        self.balance = balance
        self.loyalty_points = loyalty_points

    def display(self):
        print("Account Number :", self.account_number)
        print("Customer Name  :", self.customer_name)
        print("Balance        :", self.balance)
        print("Loyalty Points :", self.loyalty_points)


account = LoyaltyAccount("ACC-1029","Nafim",50000,250)

account.display()

## A LoyaltyAccount is a bank account that also tracks reward or loyalty points.
### For ACC-1029, the account stores customer details, balance, and loyalty points, which can be used for banking rewards and benefits.
# Out:
# Account Number : ACC-1029
# Customer Name  : Nafim
# Balance        : 50000
# Loyalty Points : 250

# %%
#Q30. Create a supplier class for banking case 2; use sample reference ACC-1030 and explain the result.


class Supplier:

    def __init__(self, account_number, supplier_name, amount):
        self.account_number = account_number
        self.supplier_name = supplier_name
        self.amount = amount

    def display(self):
        print("Account Number :", self.account_number)
        print("Supplier Name  :", self.supplier_name)
        print("Amount         :", self.amount)


supplier = Supplier("ACC-1030", "ABC Traders", 50000)

supplier.display()

## The Supplier class is used to represent supplier information in a banking system.
## The object supplier1 stores the account reference ACC-1030, supplier name, and amount, and displays the details successfully.
# Out:
# Account Number : ACC-1030
# Supplier Name  : ABC Traders
# Amount         : 50000

# %%
#Q31. Inherit perishableaccount from account for banking case 1; use sample reference ACC-1031 and explain the result.


class Account:

  def __init__(self,Account_Number,Account_Name,Balance):
    self.Account_Number = Account_Number
    self.Account_Name = Account_Name
    self.Balance = Balance

class Perishableaccount(Account):
  def __init__(self,Account_Number,Account_Name,Balance,Expiry_date):
    super().__init__(Account_Number,Account_Name,Balance)
    self.Expiry_date = Expiry_date

  def display(self):
    print("Account Number :",self.Account_Number)
    print("Account Name   :",self.Account_Name)
    print("Balance        :",self.Balance)
    print("Expiry Date    :",self.Expiry_date)

account = Perishableaccount("ACC-1031","Nafim",50000,"01-08-2008")

account.display()

## Inheritance allows a child class to reuse the properties and methods of a parent class.
## Here, PerishableAccount inherits from Account, reducing code duplication while adding an additional attribute called expiry_date.
# Out:
# Account Number : ACC-1031
# Account Name   : Nafim
# Balance        : 50000
# Expiry Date    : 01-08-2008

# %%
#Q32. Override a discount method for banking case 1; use sample reference ACC-1032 and explain the result.


class Account:

  def __init__(self,Account_Number,Balance):
    self.Account_Number = Account_Number
    self.Balance = Balance

  def Discount(self):
    return self.Balance * 0.05

class vipaccount(Account):
  def Discount(self):
    return self.Balance * 0.10

account = [vipaccount("ACC-1032",60000),Account("Acc-1032",5000)]

for i in account:
  print("Account_Number  :",i.Account_Number)
  print('Balance         :',i.Balance)
  print("Discount        :",i.Discount())
  print()

## Method overriding occurs when a child class provides its own implementation of a method already defined in the parent class.
## For ACC-1032, LoyaltyAccount overrides the discount() method and provides a higher discount rate than the parent Account class.
# Out:
# Account_Number  : ACC-1032
# Balance         : 60000
# Discount        : 6000.0
#
# Account_Number  : Acc-1032
# Balance         : 5000
# Discount        : 250.0

# %%
#Q33. Use polymorphic payment processors for banking case 1; use sample reference ACC-1033 and explain the result.


class BankTransfer:

  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount

  def Process_Payment(self):
    print (f"{self.Account_Number} Bank Transfer payment method {self.Amount}")

class UPI:

  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount

  def Process_Payment(self):
    print (f"{self.Account_Number} UPI payment method {self.Amount}")

class NetBanking:

  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount

  def Process_Payment(self):
    print (f"{self.Account_Number} Net-Banking Transfer payment method {self.Amount}")

payment = [BankTransfer("ACC-1033",10000),UPI("Acc-1033",8888),NetBanking("Acc-1033",7908)]

for i in payment:
  i.Process_Payment()

### Polymorphism allows different classes to use the same method name while providing different implementations.
### In this example, BankTransfer, UPI, and CardPayment all implement process_payment(), and Python executes the correct version based on the object type.
# Out:
# ACC-1033 Bank Transfer payment method 10000
# Acc-1033 UPI payment method 8888
# Acc-1033 Net-Banking Transfer payment method 7908

# %%
#Q34. Compose transfer from transferline objects for banking case 1; use sample reference ACC-1034 and explain the result.


class Transferline:
  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount
  def display(self):
    print(f"Account Name : {self.Account_Number} | Amount : {self.Amount}")

class Transfer:
  def __init__(self,transfer_refrence):
    self.transfer_refrence = transfer_refrence
    self.transfer_lines = []

  def add_transfer_line(self,transfer_line):
    self.transfer_lines.append(transfer_line)

  def calculate_total(self):
    return sum(line.Amount for line in self.transfer_lines)

  def display(self):
    print(f"\nTransfer Reference: {self.transfer_refrence}")
    print('Transfer Details:')

    for line in self.transfer_lines:
      line.display()

    print(f"\nTotal Amunt: ₹{self.calculate_total()}")


transfer = Transfer("ACC-1034")

line1 = Transferline("Acc-1034",8908)
line2 = Transferline("ACC-10034",8976)

transfer.add_transfer_line(line1)
transfer.add_transfer_line(line2)

transfer.display()

## Composition is an OOP concept where one class contains objects of another class. In this example,
## the Transfer class is composed of multiple TransferLine objects, allowing us to model a banking transfer
## that contains several transaction entries and calculate the total transfer amount.
# Out:
# Transfer Reference: ACC-1034
# Transfer Details:
# Account Name : Acc-1034 | Amount : 8908
# Account Name : ACC-10034 | Amount : 8976
#
# Total Amunt: ₹17884

# %%
#Q35. Define an abstract paymentmethod for banking case 1; use sample reference ACC-1035 and explain the result.


class PaymentMethod:

    def pay(self, amount):
        raise ValueError("No Payment Method Found")


class UPI(PaymentMethod):
    def pay(self, amount):
        print(f"ACC-1035: ₹{amount} paid using UPI")


class CreditCard(PaymentMethod):
    def pay(self, amount):
        print(f"ACC-1035: ₹{amount} paid using Credit Card")

class NetBanking(PaymentMethod):
  pass

payments = [(UPI(),5000),(NetBanking(),809),(CreditCard(),900)]

for i,amount in payments:
  try:
    i.pay(amount)
  except ValueError as e:
    print("Error:", e)



### Abstraction is the process of hiding implementation details and exposing only essential behavior.
### In this example, PaymentMethod is an abstract class that defines the common method pay().
### Child classes such as UPI and CreditCard provide their own implementation of pay(). This ensures consistency and enforces a common interface for all payment methods.
# Out:
# ACC-1035: ₹5000 paid using UPI
# Error: No Payment Method Found
# ACC-1035: ₹900 paid using Credit Card

# %%
#Q36. Use a dataclass for inventoryrecord for banking case 1; use sample reference ACC-1036 and explain the result.


from dataclasses import dataclass

@dataclass
class InventoryRecord:
  Account_Number : str
  Account_Name : str
  Balance : float

record = InventoryRecord("ACC-1036",'Nafim',50000)
print(record)

### Dataclass is a decorator that automatically generates methods like __init__(), __repr__(), and __eq__() for a class,
### reducing boilerplate code and making data-holding classes easier to create and maintain.
# Out:
# InventoryRecord(Account_Number='ACC-1036', Account_Name='Nafim', Balance=50000)

# %%
#Q37. Implement a custom iterator for portfolio for banking case 1; use sample reference ACC-1037 and explain the result.


class accounts:
  def __init__(self,Account_number,Account_Name,Balance):
    self.Account_number = Account_number
    self.Account_Name = Account_Name
    self.Balance = Balance
  def __str__(self):
    return f"{self.Account_number} | {self.Account_Name} | {self.Balance}"

class Portfolio:
  def __init__(self,accounts):
    self.accounts = accounts
    self.index = 0

  def __iter__(self):
    return self

  def __next__(self):
    if self.index < len(self.accounts):
      account= self.accounts[self.index]
      self.index += 1
      return account
    raise  StopIteration

Accounts = [accounts("ACC-1037","Nafim",8000),accounts("Acc-1037","Nafim",9000),accounts("ACC-37","Nafim",7000),accounts("Acc-37","Nafim",6000)]

portfolio = Portfolio(Accounts)

for i in portfolio:
  print(i)

 ## iter() creates an iterator object from an iterable (list, tuple, string, etc.).
 ### An iterator returns one item at a time using next() until StopIteration is raised.
# Out:
# ACC-1037 | Nafim | 8000
# Acc-1037 | Nafim | 9000
# ACC-37 | Nafim | 7000
# Acc-37 | Nafim | 6000

# %%
#Q38. Use multiple inheritance carefully for timestampeditem for banking case 1; use sample reference ACC-1038 and explain the result.


from datetime import datetime

class AccountInfo:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

class TimestampMixin:
    def __init__(self):
        self.created_at = datetime.now()

class TimestampedItem(AccountInfo, TimestampMixin):
    def __init__(self, account_number, account_name, balance):
        AccountInfo.__init__(self, account_number, account_name, balance)
        TimestampMixin.__init__(self)

account = [TimestampedItem("ACC-1038","Nafim",15000),TimestampedItem("Acc-1038","Nafim",15000)]

for i in account:
  print("Account Number:", i.account_number)
  print("Account Name:", i.account_name)
  print("Balance:", i.balance)
  print("Created At:", i.created_at)
  print()

  ### Multiple Inheritance allows a class to inherit from more than one parent class.
  ### It should be used carefully because method name conflicts can occur. Python resolves such conflicts using MRO (Method Resolution Order).
# Out:
# Account Number: ACC-1038
# Account Name: Nafim
# Balance: 15000
# Created At: 2026-09-17 23:17:08.201837
#
# Account Number: Acc-1038
# Account Name: Nafim
# Balance: 15000
# Created At: 2026-09-17 23:17:08.201845

# %%
#Q39. Create a account factory for banking case 1; use sample reference ACC-1039 and explain the result.


class Account:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance
    def display(self):
        print(f"Account Number : {self.account_number}")
        print(f"Account Name   : {self.account_name}")
        print(f"Balance        : ₹{self.balance}")

class AccountFactory:
    @staticmethod
    def create_account(account_number, account_name, balance):
        return Account(account_number, account_name, balance)


account = AccountFactory.create_account("ACC-1039","Nafim",15000)

account.display()

### Factory Pattern is a creational design pattern that creates objects without exposing the object creation logic to the client.
### A factory method returns the required object based on the input.
# Out:
# Account Number : ACC-1039
# Account Name   : Nafim
# Balance        : ₹15000

# %%
#Q40. Apply a strategy for interest offers for banking case 1; use sample reference ACC-1040 and explain the result.


class Account:
    def __init__(self, account_number, balance, strategy):
        self.account_number = account_number
        self.balance = balance
        self.strategy = strategy
    def get_interest(self):
        return self.strategy.calculate(self.balance)

class SavingsInterest:
    def calculate(self, balance):
        return balance * 0.04

class PremiumInterest:
    def calculate(self, balance):
        return balance * 0.06

class VIPInterest:
    def calculate(self, balance):
        return balance * 0.08

account = [Account("ACC-1040",100000,VIPInterest()),Account("ACC-1040",100000,SavingsInterest()),Account("ACC-1040",100000,PremiumInterest())]

for i in account:
  print("Account Number:", i.account_number)
  print("Balance:",i.balance)
  print("Interest Offer:", i.get_interest())
  print()

### Strategy Pattern allows selecting an algorithm at runtime.
### Different strategies implement the same operation, and the client can switch between them without modifying existing code.
# Out:
# Account Number: ACC-1040
# Balance: 100000
# Interest Offer: 8000.0
#
# Account Number: ACC-1040
# Balance: 100000
# Interest Offer: 4000.0
#
# Account Number: ACC-1040
# Balance: 100000
# Interest Offer: 6000.0

# %%
#Q41. Encapsulate balance reservation for banking case 1; use sample reference ACC-1041 and explain the result.


class Account:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.__balance = balance
        self.__reserved_amount = 0

    def reserve_balance(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            self.__reserved_amount += amount
            print(f"₹{amount} reserved successfully.")
        else:
            print("Insufficient balance.")

    def show_details(self):
        print(f"Account Number   : {self.account_number}")
        print(f"Available Balance: ₹{self.__balance}")
        print(f"Reserved Amount  : ₹{self.__reserved_amount}")


account = Account("ACC-1041", 50000)

account.reserve_balance(3000)

account.show_details()

### Encapsulation is the OOP principle of hiding data and controlling access through methods.
### In this example, balance and reserved amount are private attributes, and they can only be modified using the reserve_balance() method.
# Out:
# ₹3000 reserved successfully.
# Account Number   : ACC-1041
# Available Balance: ₹47000
# Reserved Amount  : ₹3000

# %%
#Q42. Model aggregation between branch and employees for banking case 1; use sample reference ACC-1042 and explain the result.


class Employee:
    def __init__(self, emp_id, emp_name):
        self.emp_id = emp_id
        self.emp_name = emp_name

    def display(self):
        print(f"Employee ID   : {self.emp_id}")
        print(f"Employee Name : {self.emp_name}")


class Branch:
    def __init__(self, branch_name, employees):
        self.branch_name = branch_name
        self.employees = employees

    def display(self):
        print(f"\nBranch Name : {self.branch_name}")
        print("Employees:")

        for employee in self.employees:
            print(f"{employee.emp_id} - {employee.emp_name}")

emp1 = Employee("EMP101", "Nafim")
emp2 = Employee("EMP102", "Hussain")
emp3 = Employee("EMP103", "Rubina")

branch = [Branch("Secbad Branch ACC-1042",[emp1, emp2]),Branch("Hyderbad Branch Acc-1042",[emp3])]

for i in branch:
  i.display()

## Aggregation is a "has-a" relationship where one object contains references to other objects,
### but those objects can exist independently of the container object.
# Out:
# Branch Name : Secbad Branch ACC-1042
# Employees:
# EMP101 - Nafim
# EMP102 - Hussain
#
# Branch Name : Hyderbad Branch Acc-1042
# Employees:
# EMP103 - Rubina

# %%
#Q43. Serialize an transfer to a dictionary for banking case 1; use sample reference ACC-1043 and explain the result.


class Transfer:
    def __init__(self, transfer_id, from_account, to_account, amount):
        self.transfer_id = transfer_id
        self.from_account = from_account
        self.to_account = to_account
        self.amount = amount

    def to_dict(self):
        return {
            "transfer_id": self.transfer_id,
            "from_account": self.from_account,
            "to_account": self.to_account,
            "amount": self.amount
        }


transfer = Transfer("ACC-1043","ACC-1001","ACC-1002",5000)

transfer_data = transfer.to_dict()

print(transfer_data)

## Serialization is the process of converting an object into a format such as a dictionary or JSON so that it can be stored, transmitted, or processed easily.
### In Python, this can be done using a custom to_dict() method or the object's __dict__ attribute.
# Out:
# {'transfer_id': 'ACC-1043', 'from_account': 'ACC-1001', 'to_account': 'ACC-1002', 'amount': 5000}

# %%
#Q44. Implement a repository abstraction for banking case 1; use sample reference ACC-1044 and explain the result.


class Account:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance
    def __str__(self):
        return f"{self.account_number} | {self.account_name} | ₹{self.balance}"

class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self.accounts.get(account_number)

# Create Repository
repo = AccountRepository()
# Create Account
account = Account("ACC-1044", "Nafim", 25000)
# Save Account
repo.save(account)
# Fetch Account
result = repo.get_by_id("ACC-1044")
print(result)

### Repository Pattern provides an abstraction layer between the business logic and data storage.
### Instead of accessing data directly, the application uses a repository to save, retrieve, update, or delete objects.
# Out:
# ACC-1044 | Nafim | ₹25000

# %%
#Q45. Apply dependency injection to checkout for banking case 1; use sample reference ACC-1045 and explain the result.


class UPI:
    def pay(self, amount):
        print(f"Paid ₹{amount} using UPI")

class CreditCard:
    def pay(self, amount):
        print(f"Paid ₹{amount} using Credit Card")

class Checkout:
    def __init__(self, payment_method):
        self.payment_method = payment_method

    def process_payment(self, amount):
        self.payment_method.pay(amount)


payment = CreditCard()

checkout = Checkout(payment)

checkout.process_payment(500)
### Dependency Injection is a design principle where an object receives its dependencies from outside instead of creating them internally.
### This reduces coupling, improves flexibility, and makes testing easier.
# Out:
# Paid ₹500 using Credit Card

# %%
#Q46. Inherit perishableaccount from account for banking case 2; use sample reference ACC-1046 and explain the result.


class Account:

  def __init__(self,Account_Number,Account_Name,Balance):
    self.Account_Number = Account_Number
    self.Account_Name = Account_Name
    self.Balance = Balance

class Perishableaccount(Account):
  def __init__(self,Account_Number,Account_Name,Balance,Expiry_date):
    super().__init__(Account_Number,Account_Name,Balance)
    self.Expiry_date = Expiry_date

  def display(self):
    print("Account Number :",self.Account_Number)
    print("Account Name   :",self.Account_Name)
    print("Balance        :",self.Balance)
    print("Expiry Date    :",self.Expiry_date)

account = Perishableaccount("ACC-1046","Nafim",50000,"01-08-2008")

account.display()

## Inheritance allows a child class to reuse the properties and methods of a parent class.
## Here, PerishableAccount inherits from Account, reducing code duplication while adding an additional attribute called expiry_date.
# Out:
# Account Number : ACC-1046
# Account Name   : Nafim
# Balance        : 50000
# Expiry Date    : 01-08-2008

# %%
#Q47. Override a discount method for banking case 2; use sample reference ACC-1047 and explain the result.


class Account:

  def __init__(self,Account_Number,Balance):
    self.Account_Number = Account_Number
    self.Balance = Balance

  def Discount(self):
    return self.Balance * 0.05

class vipaccount(Account):
  def Discount(self):
    return self.Balance * 0.10

account = [vipaccount("ACC-1047",60000),Account("Acc-1047",5000)]

for i in account:
  print("Account_Number  :",i.Account_Number)
  print('Balance         :',i.Balance)
  print("Discount        :",i.Discount())
  print()

## Method overriding occurs when a child class provides its own implementation of a method already defined in the parent class.
## For ACC-1032, LoyaltyAccount overrides the discount() method and provides a higher discount rate than the parent Account class.
# Out:
# Account_Number  : ACC-1047
# Balance         : 60000
# Discount        : 6000.0
#
# Account_Number  : Acc-1047
# Balance         : 5000
# Discount        : 250.0

# %%
#Q48. Use polymorphic payment processors for banking case 2; use sample reference ACC-1048 and explain the result.


class BankTransfer:

  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount

  def Process_Payment(self):
    print (f"{self.Account_Number} Bank Transfer payment method {self.Amount}")

class UPI:

  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount

  def Process_Payment(self):
    print (f"{self.Account_Number} UPI payment method {self.Amount}")

class NetBanking:

  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount

  def Process_Payment(self):
    print (f"{self.Account_Number} Net-Banking Transfer payment method {self.Amount}")

payment = [BankTransfer("ACC-1048",10000),UPI("Acc-1048",8888),NetBanking("Acc-1048",7908)]

for i in payment:
  i.Process_Payment()

### Polymorphism allows different classes to use the same method name while providing different implementations.
### In this example, BankTransfer, UPI, and CardPayment all implement process_payment(), and Python executes the correct version based on the object type.
# Out:
# ACC-1048 Bank Transfer payment method 10000
# Acc-1048 UPI payment method 8888
# Acc-1048 Net-Banking Transfer payment method 7908

# %%
#Q49. Compose transfer from transferline objects for banking case 2; use sample reference ACC-1049 and explain the result.


class Transferline:
  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount
  def display(self):
    print(f"Account Name : {self.Account_Number} | Amount : {self.Amount}")

class Transfer:
  def __init__(self,transfer_refrence):
    self.transfer_refrence = transfer_refrence
    self.transfer_lines = []

  def add_transfer_line(self,transfer_line):
    self.transfer_lines.append(transfer_line)

  def calculate_total(self):
    return sum(line.Amount for line in self.transfer_lines)

  def display(self):
    print(f"\nTransfer Reference: {self.transfer_refrence}")
    print('Transfer Details:')

    for line in self.transfer_lines:
      line.display()

    print(f"\nTotal Amunt: ₹{self.calculate_total()}")


transfer = Transfer("ACC-1049")

line1 = Transferline("Acc-1049",8908)
line2 = Transferline("ACC-1049",8976)

transfer.add_transfer_line(line1)
transfer.add_transfer_line(line2)

transfer.display()

## Composition is an OOP concept where one class contains objects of another class. In this example,
## the Transfer class is composed of multiple TransferLine objects, allowing us to model a banking transfer
## that contains several transaction entries and calculate the total transfer amount.
# Out:
# Transfer Reference: ACC-1049
# Transfer Details:
# Account Name : Acc-1049 | Amount : 8908
# Account Name : ACC-1049 | Amount : 8976
#
# Total Amunt: ₹17884

# %%
#Q50. Define an abstract paymentmethod for banking case 2; use sample reference ACC-1050 and explain the result.


class PaymentMethod:

    def pay(self, amount):
        raise ValueError("No Payment Method Found")


class UPI(PaymentMethod):
    def pay(self, amount):
        print(f"ACC-1050: ₹{amount} paid using UPI")


class CreditCard(PaymentMethod):
    def pay(self, amount):
        print(f"ACC-1050: ₹{amount} paid using Credit Card")

class NetBanking(PaymentMethod):
  pass

payments = [(UPI(),5000),(NetBanking(),809),(CreditCard(),900)]

for i,amount in payments:
  try:
    i.pay(amount)
  except ValueError as e:
    print("Error:", e)



### Abstraction is the process of hiding implementation details and exposing only essential behavior.
### In this example, PaymentMethod is an abstract class that defines the common method pay().
### Child classes such as UPI and CreditCard provide their own implementation of pay(). This ensures consistency and enforces a common interface for all payment methods.
# Out:
# ACC-1050: ₹5000 paid using UPI
# Error: No Payment Method Found
# ACC-1050: ₹900 paid using Credit Card

# %%
#Q51. Use a dataclass for inventoryrecord for banking case 2; use sample reference ACC-1051 and explain the result.


from dataclasses import dataclass

@dataclass
class InventoryRecord:
  Account_Number : str
  Account_Name : str
  Balance : float

record = [InventoryRecord("ACC-1051",'Nafim',50000),InventoryRecord("Acc-1051",'Nafim',50000),InventoryRecord("ACC-51",'Nafim',50000)]

for i in record:
  print(i)
  print()

### Dataclass is a decorator that automatically generates methods like __init__(), __repr__(), and __eq__() for a class,
### reducing boilerplate code and making data-holding classes easier to create and maintain.
# Out:
# InventoryRecord(Account_Number='ACC-1051', Account_Name='Nafim', Balance=50000)
#
# InventoryRecord(Account_Number='Acc-1051', Account_Name='Nafim', Balance=50000)
#
# InventoryRecord(Account_Number='ACC-51', Account_Name='Nafim', Balance=50000)

# %%
#Q52. Implement a custom iterator for portfolio for banking case 2; use sample reference ACC-1052 and explain the result.


class accounts:
  def __init__(self,Account_number,Account_Name,Balance):
    self.Account_number = Account_number
    self.Account_Name = Account_Name
    self.Balance = Balance
  def __str__(self):
    return f"{self.Account_number} | {self.Account_Name} | {self.Balance}"

class Portfolio:
  def __init__(self,accounts):
    self.accounts = accounts
    self.index = 0

  def __iter__(self):
    return self

  def __next__(self):
    if self.index < len(self.accounts):
      account= self.accounts[self.index]
      self.index += 1
      return account
    raise  StopIteration

Accounts = [accounts("ACC-1052","Nafim",8000),accounts("Acc-1052","Nafim",9000),accounts("ACC-52","Nafim",7000),accounts("Acc-52","Nafim",6000)]

portfolio = Portfolio(Accounts)

for i in portfolio:
  print(i)

 ## iter() creates an iterator object from an iterable (list, tuple, string, etc.).
 ### An iterator returns one item at a time using next() until StopIteration is raised.
# Out:
# ACC-1052 | Nafim | 8000
# Acc-1052 | Nafim | 9000
# ACC-52 | Nafim | 7000
# Acc-52 | Nafim | 6000

# %%
#Q53. Use multiple inheritance carefully for timestampeditem for banking case 2; use sample reference ACC-1053 and explain the result.


from datetime import datetime

class AccountInfo:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

class TimestampMixin:
    def __init__(self):
        self.created_at = datetime.now()

class TimestampedItem(AccountInfo, TimestampMixin):
    def __init__(self, account_number, account_name, balance):
        AccountInfo.__init__(self, account_number, account_name, balance)
        TimestampMixin.__init__(self)

account = [TimestampedItem("ACC-1053","Nafim",15000),TimestampedItem("Acc-1053","Nafim",15000)]

for i in account:
  print("Account Number:", i.account_number)
  print("Account Name:", i.account_name)
  print("Balance:", i.balance)
  print("Created At:", i.created_at)
  print()
# Out:
# Account Number: ACC-1053
# Account Name: Nafim
# Balance: 15000
# Created At: 2026-09-17 23:32:42.497119
#
# Account Number: Acc-1053
# Account Name: Nafim
# Balance: 15000
# Created At: 2026-09-17 23:32:42.497128

# %%
#Q54. Create a account factory for banking case 2; use sample reference ACC-1054 and explain the result.


class Account:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance
    def display(self):
        print(f"Account Number : {self.account_number}")
        print(f"Account Name   : {self.account_name}")
        print(f"Balance        : ₹{self.balance}")

class AccountFactory:
    @staticmethod
    def create_account(account_number, account_name, balance):
        return Account(account_number, account_name, balance)


account = AccountFactory.create_account("ACC-1054","Nafim",15000)

account.display()

### Factory Pattern is a creational design pattern that creates objects without exposing the object creation logic to the client.
### A factory method returns the required object based on the input.
# Out:
# Account Number : ACC-1054
# Account Name   : Nafim
# Balance        : ₹15000

# %%
#Q55. Apply a strategy for interest offers for banking case 2; use sample reference ACC-1055 and explain the result.


class Account:
    def __init__(self, account_number, balance, strategy):
        self.account_number = account_number
        self.balance = balance
        self.strategy = strategy
    def get_interest(self):
        return self.strategy.calculate(self.balance)

class SavingsInterest:
    def calculate(self, balance):
        return balance * 0.04

class PremiumInterest:
    def calculate(self, balance):
        return balance * 0.06

class VIPInterest:
    def calculate(self, balance):
        return balance * 0.08

account = Account("ACC-1055",800000,VIPInterest())

print("Account Number:", account.account_number)
print("Interest Offer:", account.get_interest())

### Strategy Pattern allows selecting an algorithm at runtime.
### Different strategies implement the same operation, and the client can switch between them without modifying existing code.
# Out:
# Account Number: ACC-1055
# Interest Offer: 64000.0

# %%
#Q56. Encapsulate balance reservation for banking case 2; use sample reference ACC-1056 and explain the result.


class Account:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.__balance = balance
        self.__reserved_amount = 0

    def reserve_balance(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            self.__reserved_amount += amount
            print(f"₹{amount} reserved successfully.")
        else:
            print("Insufficient balance.")

    def show_details(self):
        print(f"Account Number   : {self.account_number}")
        print(f"Available Balance: ₹{self.__balance}")
        print(f"Reserved Amount  : ₹{self.__reserved_amount}")


account = Account("ACC-1056", 800)

account.reserve_balance(2000)

account.show_details()

### Encapsulation is the OOP principle of hiding data and controlling access through methods.
### In this example, balance and reserved amount are private attributes, and they can only be modified using the reserve_balance() method.
# Out:
# Insufficient balance.
# Account Number   : ACC-1056
# Available Balance: ₹800
# Reserved Amount  : ₹0

# %%
#Q57. Model aggregation between branch and employees for banking case 2; use sample reference ACC-1057 and explain the result.


class Employee:
    def __init__(self, emp_id, emp_name):
        self.emp_id = emp_id
        self.emp_name = emp_name

    def display(self):
        print(f"Employee ID   : {self.emp_id}")
        print(f"Employee Name : {self.emp_name}")


class Branch:
    def __init__(self, branch_name, employees):
        self.branch_name = branch_name
        self.employees = employees

    def display(self):
        print(f"\nBranch Name : {self.branch_name}")
        print("Employees:")

        for employee in self.employees:
            print(f"{employee.emp_id} - {employee.emp_name}")

emp1 = Employee("EMP101", "Nafim")
emp2 = Employee("EMP102", "Hussain")
emp3 = Employee("EMP103", "Rubina")

branch = [Branch("Sec-Bad Branch ACC-1057",[emp1, emp2]),Branch("Hyderbad Branch Acc-1057",[emp3])]

for i in branch:
  i.display()

## Aggregation is a "has-a" relationship where one object contains references to other objects,
### but those objects can exist independently of the container object.
# Out:
# Branch Name : Sec-Bad Branch ACC-1057
# Employees:
# EMP101 - Nafim
# EMP102 - Hussain
#
# Branch Name : Hyderbad Branch Acc-1057
# Employees:
# EMP103 - Rubina

# %%
#Q58. Serialize an transfer to a dictionary for banking case 2; use sample reference ACC-1058 and explain the result.


class Transfer:
    def __init__(self, transfer_id, from_account, to_account, amount):
        self.transfer_id = transfer_id
        self.from_account = from_account
        self.to_account = to_account
        self.amount = amount

    def to_dict(self):
        return {
            "transfer_id": self.transfer_id,
            "from_account": self.from_account,
            "to_account": self.to_account,
            "amount": self.amount
        }


transfer = Transfer("ACC-1058","ACC-1001","ACC-1002",5000)

transfer_data = transfer.to_dict()

print(transfer_data)

## Serialization is the process of converting an object into a format such as a dictionary or JSON so that it can be stored, transmitted, or processed easily.
### In Python, this can be done using a custom to_dict() method or the object's __dict__ attribute.
# Out:
# {'transfer_id': 'ACC-1058', 'from_account': 'ACC-1001', 'to_account': 'ACC-1002', 'amount': 5000}

# %%
#Q59. Implement a repository abstraction for banking case 2; use sample reference ACC-1059 and explain the result.


class Account:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance
    def __str__(self):
        return f"{self.account_number} | {self.account_name} | ₹{self.balance}"

class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self.accounts.get(account_number)

# Create Repository
repo = AccountRepository()
# Create Account
account = Account("ACC-1059", "Nafim", 25000)
# Save Account
repo.save(account)
# Fetch Account
result = repo.get_by_id("ACC-1059")
print(result)

### Repository Pattern provides an abstraction layer between the business logic and data storage.
### Instead of accessing data directly, the application uses a repository to save, retrieve, update, or delete objects.
# Out:
# ACC-1059 | Nafim | ₹25000

# %%
#Q60. Apply dependency injection to checkout for banking case 2; use sample reference ACC-1060 and explain the result.


class UPI:
    def pay(self, amount):
        print(f"Paid ₹{amount} using UPI")

class CreditCard:
    def pay(self, amount):
        print(f"Paid ₹{amount} using Credit Card")

class Checkout:
    def __init__(self, payment_method):
        self.payment_method = payment_method

    def process_payment(self, amount):
        self.payment_method.pay(amount)


payment = UPI()

checkout = Checkout(payment)

checkout.process_payment(5000)
### Dependency Injection is a design principle where an object receives its dependencies from outside instead of creating them internally.
### This reduces coupling, improves flexibility, and makes testing easier.
# Out:
# Paid ₹5000 using UPI

# %%
#Q61. Inherit perishableaccount from account for banking case 3; use sample reference ACC-1061 and explain the result.


class Account:

  def __init__(self,Account_Number,Account_Name,Balance):
    self.Account_Number = Account_Number
    self.Account_Name = Account_Name
    self.Balance = Balance

class Perishableaccount(Account):
  def __init__(self,Account_Number,Account_Name,Balance,Expiry_date):
    super().__init__(Account_Number,Account_Name,Balance)
    self.Expiry_date = Expiry_date

  def display(self):
    print("Account Number :",self.Account_Number)
    print("Account Name   :",self.Account_Name)
    print("Balance        :",self.Balance)
    print("Expiry Date    :",self.Expiry_date)

account = Perishableaccount("ACC-1061","Nafim",50000,"01-08-2008")

account.display()

## Inheritance allows a child class to reuse the properties and methods of a parent class.
## Here, PerishableAccount inherits from Account, reducing code duplication while adding an additional attribute called expiry_date.
# Out:
# Account Number : ACC-1061
# Account Name   : Nafim
# Balance        : 50000
# Expiry Date    : 01-08-2008

# %%
#Q62. Override a discount method for banking case 3; use sample reference ACC-1062 and explain the result.


class Account:

  def __init__(self,Account_Number,Balance):
    self.Account_Number = Account_Number
    self.Balance = Balance

  def Discount(self):
    return self.Balance * 0.05

class vipaccount(Account):
  def Discount(self):
    return self.Balance * 0.10

account = [vipaccount("ACC-1062",60000),Account("Acc-1062",5000)]

for i in account:
  print("Account_Number  :",i.Account_Number)
  print('Balance         :',i.Balance)
  print("Discount        :",i.Discount())
  print()

## Method overriding occurs when a child class provides its own implementation of a method already defined in the parent class.
## For ACC-1032, LoyaltyAccount overrides the discount() method and provides a higher discount rate than the parent Account class.
# Out:
# Account_Number  : ACC-1062
# Balance         : 60000
# Discount        : 6000.0
#
# Account_Number  : Acc-1062
# Balance         : 5000
# Discount        : 250.0

# %%
#Q63. Use polymorphic payment processors for banking case 3; use sample reference ACC-1063 and explain the result.


class BankTransfer:

  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount

  def Process_Payment(self):
    print (f"{self.Account_Number} Bank Transfer payment method {self.Amount}")

class UPI:

  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount

  def Process_Payment(self):
    print (f"{self.Account_Number} UPI payment method {self.Amount}")

class NetBanking:

  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount

  def Process_Payment(self):
    print (f"{self.Account_Number} Net-Banking Transfer payment method {self.Amount}")

payment = [BankTransfer("ACC-1063",10000),UPI("Acc-1063",8888),NetBanking("Acc-1063",7908)]

for i in payment:
  i.Process_Payment()

### Polymorphism allows different classes to use the same method name while providing different implementations.
### In this example, BankTransfer, UPI, and CardPayment all implement process_payment(), and Python executes the correct version based on the object type.
# Out:
# ACC-1063 Bank Transfer payment method 10000
# Acc-1063 UPI payment method 8888
# Acc-1063 Net-Banking Transfer payment method 7908

# %%
#Q64. Compose transfer from transferline objects for banking case 3; use sample reference ACC-1064 and explain the result.


class Transferline:
  def __init__(self,Account_Number,Amount):
    self.Account_Number = Account_Number
    self.Amount = Amount
  def display(self):
    print(f"Account Name : {self.Account_Number} | Amount : {self.Amount}")

class Transfer:
  def __init__(self,transfer_refrence):
    self.transfer_refrence = transfer_refrence
    self.transfer_lines = []

  def add_transfer_line(self,transfer_line):
    self.transfer_lines.append(transfer_line)

  def calculate_total(self):
    return sum(line.Amount for line in self.transfer_lines)

  def display(self):
    print(f"\nTransfer Reference: {self.transfer_refrence}")
    print('Transfer Details:')

    for line in self.transfer_lines:
      line.display()

    print(f"\nTotal Amunt: ₹{self.calculate_total()}")


transfer = Transfer("ACC-1049")

line1 = Transferline("Acc-1064",8908)
line2 = Transferline("ACC-1064",8976)

transfer.add_transfer_line(line1)
transfer.add_transfer_line(line2)

transfer.display()

## Composition is an OOP concept where one class contains objects of another class. In this example,
## the Transfer class is composed of multiple TransferLine objects, allowing us to model a banking transfer
## that contains several transaction entries and calculate the total transfer amount.
# Out:
# Transfer Reference: ACC-1049
# Transfer Details:
# Account Name : Acc-1064 | Amount : 8908
# Account Name : ACC-1064 | Amount : 8976
#
# Total Amunt: ₹17884

# %%
#Q65. Define an abstract paymentmethod for banking case 3; use sample reference ACC-1065 and explain the result.


class PaymentMethod:

    def pay(self, amount):
        raise ValueError("No Payment Method Found")


class UPI(PaymentMethod):
    def pay(self, amount):
        print(f"ACC-1065: ₹{amount} paid using UPI")


class CreditCard(PaymentMethod):
    def pay(self, amount):
        print(f"ACC-1065: ₹{amount} paid using Credit Card")

class NetBanking(PaymentMethod):
  pass

payments = [(UPI(),5000),(NetBanking(),809),(CreditCard(),900)]

for i,amount in payments:
  try:
    i.pay(amount)
  except ValueError as e:
    print("Error:", e)



### Abstraction is the process of hiding implementation details and exposing only essential behavior.
### In this example, PaymentMethod is an abstract class that defines the common method pay().
### Child classes such as UPI and CreditCard provide their own implementation of pay(). This ensures consistency and enforces a common interface for all payment methods.
# Out:
# ACC-1065: ₹5000 paid using UPI
# Error: No Payment Method Found
# ACC-1065: ₹900 paid using Credit Card

# %%
#Q66. Use a dataclass for inventoryrecord for banking case 3; use sample reference ACC-1066 and explain the result.


from dataclasses import dataclass

@dataclass
class InventoryRecord:
  Account_Number : str
  Account_Name : str
  Balance : float

record = [InventoryRecord("ACC-1066",'Nafim',50000),InventoryRecord("Acc-1066",'Nafim',50000),InventoryRecord("ACC-66",'Nafim',50000)]

for i in record:
  print(i)
  print()
# Out:
# InventoryRecord(Account_Number='ACC-1066', Account_Name='Nafim', Balance=50000)
#
# InventoryRecord(Account_Number='Acc-1066', Account_Name='Nafim', Balance=50000)
#
# InventoryRecord(Account_Number='ACC-66', Account_Name='Nafim', Balance=50000)

# %%
#Q67. Implement a custom iterator for portfolio for banking case 3; use sample reference ACC-1067 and explain the result.


class accounts:
  def __init__(self,Account_number,Account_Name,Balance):
    self.Account_number = Account_number
    self.Account_Name = Account_Name
    self.Balance = Balance
  def __str__(self):
    return f"{self.Account_number} | {self.Account_Name} | {self.Balance}"

class Portfolio:
  def __init__(self,accounts):
    self.accounts = accounts
    self.index = 0

  def __iter__(self):
    return self

  def __next__(self):
    if self.index < len(self.accounts):
      account= self.accounts[self.index]
      self.index += 1
      return account
    raise  StopIteration

Accounts = [accounts("ACC-1067","Nafim",8000),accounts("Acc-1067","Nafim",9000),accounts("ACC-67","Nafim",7000),accounts("Acc-67","Nafim",6000)]

portfolio = Portfolio(Accounts)

for i in portfolio:
  print(i)

 ## iter() creates an iterator object from an iterable (list, tuple, string, etc.).
 ### An iterator returns one item at a time using next() until StopIteration is raised.
# Out:
# ACC-1067 | Nafim | 8000
# Acc-1067 | Nafim | 9000
# ACC-67 | Nafim | 7000
# Acc-67 | Nafim | 6000

# %%
#Q68. Use multiple inheritance carefully for timestampeditem for banking case 3; use sample reference ACC-1068 and explain the result.


from datetime import datetime

class AccountInfo:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

class TimestampMixin:
    def __init__(self):
        self.created_at = datetime.now()

class TimestampedItem(AccountInfo, TimestampMixin):
    def __init__(self, account_number, account_name, balance):
        AccountInfo.__init__(self, account_number, account_name, balance)
        TimestampMixin.__init__(self)

account = [TimestampedItem("ACC-1068","Nafim",15000),TimestampedItem("Acc-1068","Nafim",15000)]

for i in account:
  print("Account Number:", i.account_number)
  print("Account Name:", i.account_name)
  print("Balance:", i.balance)
  print("Created At:", i.created_at)
  print()
# Out:
# Account Number: ACC-1068
# Account Name: Nafim
# Balance: 15000
# Created At: 2026-09-17 23:42:49.920840
#
# Account Number: Acc-1068
# Account Name: Nafim
# Balance: 15000
# Created At: 2026-09-17 23:42:49.920849

# %%
#Q69. Create a account factory for banking case 3; use sample reference ACC-1069 and explain the result.


class Account:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance
    def display(self):
        print(f"Account Number : {self.account_number}")
        print(f"Account Name   : {self.account_name}")
        print(f"Balance        : ₹{self.balance}")

class AccountFactory:
    @staticmethod
    def create_account(account_number, account_name, balance):
        return Account(account_number, account_name, balance)


account = AccountFactory.create_account("ACC-1069","Nafim",15000)

account.display()

### Factory Pattern is a creational design pattern that creates objects without exposing the object creation logic to the client.
### A factory method returns the required object based on the input.
# Out:
# Account Number : ACC-1069
# Account Name   : Nafim
# Balance        : ₹15000

# %%
#Q70. Apply a strategy for interest offers for banking case 3; use sample reference ACC-1070 and explain the result.


class Account:
    def __init__(self, account_number, balance, strategy):
        self.account_number = account_number
        self.balance = balance
        self.strategy = strategy
    def get_interest(self):
        return self.strategy.calculate(self.balance)

class SavingsInterest:
    def calculate(self, balance):
        return balance * 0.04

class PremiumInterest:
    def calculate(self, balance):
        return balance * 0.06

class VIPInterest:
    def calculate(self, balance):
        return balance * 0.08

account = Account("ACC-1070",10000,VIPInterest())

print("Account Number:", account.account_number)
print("Interest Offer:", account.get_interest())

### Strategy Pattern allows selecting an algorithm at runtime.
### Different strategies implement the same operation, and the client can switch between them without modifying existing code.
# Out:
# Account Number: ACC-1070
# Interest Offer: 800.0

# %%
#Q71. Design an extensible pricing engine for banking case 1; use sample reference ACC-1071 and explain the result.


class RegularPricing:
    def calculate(self, amount):
        fee = amount * 0.02
        return fee

class PremiumPricing:
    def calculate(self, amount):
        fee = amount * 0.01
        return fee

class VIPPricing:
    def calculate(self, amount):
        return 0

class PricingEngine:
    def __init__(self, pricing_strategy):
        self.pricing_strategy = pricing_strategy

    def calculate_fee(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be greater than zero")

        return self.pricing_strategy.calculate(amount)


# Account details
account_reference = "ACC-1071"
transaction_amount = 10000

# Select a pricing rule
engine = PricingEngine(PremiumPricing())

# Calculate the transaction fee
fee = engine.calculate_fee(transaction_amount)
final_amount = transaction_amount + fee

print("Account Reference :", account_reference)
print("Transaction Amount:", transaction_amount)
print("Processing Fee    :", fee)
print("Final Amount       :", final_amount)

### An extensible pricing engine separates each pricing rule into its own class.
### The required pricing strategy is passed to the engine, allowing new pricing rules to be added without changing the engine's existing code.
# Out:
# Account Reference : ACC-1071
# Transaction Amount: 10000
# Processing Fee    : 100.0
# Final Amount       : 10100.0

# %%
#Q72. Implement an observer for low balance for banking case 1; use sample reference ACC-1072 and explain the result.


class SMSALERT:
  def update(self,Account_number,Balance):
    print(f"SMS Alert: {Account_number} has a low balance of {Balance}")

class EMAILAlert:
  def update(self,Account_number,Balance):
    print(f"Email Alert: {Account_number} has a low balance of {Balance}")

class Account:
  def __init__(self,Account_number,Balance,Minimum_balance):
    self.Account_number = Account_number
    self.Balance = Balance
    self.Minimum_balance = Minimum_balance
    self.observers = []

  def add_observers(self,observer):
    self.observers.append(observer)

  def remove_observers(self,observer):
    if observer in self.observers:
      self.observers.remove(observer)

  def Notify(self):
    for observer in self.observers:
      observer.update(self.Account_number,self.Balance)

  def withdraw(self,amount):
    if amount <= 0:
      print(" Amount should be greater than zero")
    elif amount > self.Balance:
      print("Insufficent Balance")
    else:
      self.Balance -= amount

      print(f"{amount} Withdrawn Successfully")
      print(f"Current Balance:{self.Balance}")

      if self.Balance < self.Minimum_balance:
        self.Notify()

account = Account("ACC-1072",100000,5000)

sms_alert = SMSALERT()
Email_alert = EMAILAlert()

account.add_observers(sms_alert)
account.add_observers(Email_alert)

account.withdraw(96000)

### The Observer Pattern creates a one-to-many relationship between objects. When the subject's state changes, all registered observers are notified automatically.
### Here, the Account is the subject, and SMSAlert and EmailAlert are observers that receive notifications when the account balance falls below the minimum balance.
# Out:
# 96000 Withdrawn Successfully
# Current Balance:4000
# SMS Alert: ACC-1072 has a low balance of 4000
# Email Alert: ACC-1072 has a low balance of 4000

# %%
#Q73. Build a state machine for transfer status for banking case 1; use sample reference ACC-1073 and explain the result.


class Transfer:
    def __init__(self, account_reference, amount):
        self.account_reference = account_reference
        self.amount = amount
        self.status = "PENDING"

    def start_processing(self):
        if self.status == "PENDING":
            self.status = "PROCESSING"
            print("Transfer processing started.")
        else:
            print(
                f"Cannot start processing when status is {self.status}."
            )

    def complete_transfer(self):
        if self.status == "PROCESSING":
            self.status = "COMPLETED"
            print("Transfer completed successfully.")
        else:
            print(
                f"Cannot complete transfer when status is {self.status}."
            )

    def fail_transfer(self):
        if self.status in ["PENDING", "PROCESSING"]:
            self.status = "FAILED"
            print("Transfer failed.")
        else:
            print(
                f"Cannot fail transfer when status is {self.status}."
            )

    def display(self):
        print(f"Account Reference : {self.account_reference}")
        print(f"Transfer Amount   : ₹{self.amount}")
        print(f"Transfer Status   : {self.status}")


# Create transfer
transfer = Transfer("ACC-1073", 5000)

print("Initial Transfer Details")
transfer.display()

print("\nStarting Transfer")
transfer.start_processing()
transfer.display()

print("\nCompleting Transfer")
transfer.complete_transfer()
transfer.display()

### A state machine controls how an object moves between different states.
### In this banking example, a transfer starts in the PENDING state, moves to PROCESSING, and finally becomes either COMPLETED or FAILED. Each method validates the current status before allowing the next transition.
# Out:
# Initial Transfer Details
# Account Reference : ACC-1073
# Transfer Amount   : ₹5000
# Transfer Status   : PENDING
#
# Starting Transfer
# Transfer processing started.
# Account Reference : ACC-1073
# Transfer Amount   : ₹5000
# Transfer Status   : PROCESSING
#
# Completing Transfer
# Transfer completed successfully.
# Account Reference : ACC-1073
# Transfer Amount   : ₹5000
# Transfer Status   : COMPLETED

# %%
#Q74. Create an immutable money value object for banking case 1; use sample reference ACC-1074 and explain the result.


from dataclasses import dataclass
from decimal import Decimal


@dataclass(frozen=True)
class Money:
    amount: Decimal
    currency: str

    def __post_init__(self):
        if self.amount < 0:
            raise ValueError("Money amount cannot be negative")

        if not self.currency:
            raise ValueError("Currency cannot be empty")

    def add(self, other):
        if self.currency != other.currency:
            raise ValueError("Cannot add different currencies")

        return Money(self.amount + other.amount,self.currency)

    def __str__(self):
        return f"{self.currency} {self.amount:.2f}"


class Account:
    def __init__(self, account_number, Opening_balance):
        self.account_number = account_number
        self.Opening_balance = Opening_balance

        self.balance = Opening_balance

    def deposit(self, money):
        self.balance = self.balance.add(money)

    def display(self):
        print("Opening Balance  :", self.Opening_balance)
        print("Account Reference:", self.account_number)
        print("Account Balance  :", self.balance)


opening_balance = Money(Decimal("10000.00"),"INR")

account = Account("ACC-1074",opening_balance)

deposit_amount = Money(Decimal("2500.00"),"INR")

account.deposit(deposit_amount)
account.display()

### An immutable money value object represents an amount together with its currency and does not allow its values to be changed after creation.
#### In Python, @dataclass(frozen=True) provides immutability and value-based equality. Money operations return new objects rather than modifying existing objects.
# Out:
# Opening Balance  : INR 10000.00
# Account Reference: ACC-1074
# Account Balance  : INR 12500.00

# %%
#Q75. Implement a unit-of-work transaction for banking case 1; use sample reference ACC-1075 and explain the result.


class Account:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    def __str__(self):
        return (f"{self.account_number} | {self.account_name} | Balance: ₹{self.balance}")


class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def add(self, account):
        self.accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self.accounts.get(account_number)

class UnitOfWork:
    def __init__(self, repository):
        self.repository = repository
        self.original_balances = {}
        self.is_committed = False

    def __enter__(self):
        # Save original balances before making changes
        for account_number, account in self.repository.accounts.items():
            self.original_balances[account_number] = account.balance

        print("Transaction started.")
        return self

    def commit(self):
        self.is_committed = True
        print("Transaction committed successfully.")

    def rollback(self):
        # Restore every account's original balance
        for account_number, original_balance in self.original_balances.items():
            account = self.repository.get_by_id(account_number)

            if account is not None:
                account.balance = original_balance

        print("Transaction rolled back.")

    def __exit__(self, exception_type, exception_value, traceback):
        if exception_type is not None or not self.is_committed:
            self.rollback()

        # False means Python will not hide an exception
        return False


class TransferService:
    def transfer(self, from_account, to_account, amount):
        if amount <= 0:
            raise ValueError("Transfer amount must be greater than zero.")

        if from_account.balance < amount:
            raise ValueError("Insufficient balance in sender account.")

        from_account.balance -= amount
        to_account.balance += amount

        print(f"₹{amount} transferred from {from_account.account_number} to {to_account.account_number}.")


# Create repository
repository = AccountRepository()

# Create accounts
sender = Account("ACC-1075","Nafim",10000)

receiver = Account("ACC-2001","Ruby",5000)

# Store accounts in repository
repository.add(sender)
repository.add(receiver)

print("Balances before transfer:")
print(sender)
print(receiver)

transfer_service = TransferService()

# Unit-of-work transaction
try:
    with UnitOfWork(repository) as unit_of_work:
        transfer_service.transfer(sender,receiver,3000)
        unit_of_work.commit()

except ValueError as error:
    print("Error:", error)

print("\nBalances after transfer:")
print(sender)
print(receiver)

### The Unit of Work pattern groups multiple data changes into a single transaction. It commits all changes when every operation succeeds and rolls them back when any operation fails.
### In this example, debiting ACC-1075 and crediting the receiver are treated as one atomic transaction.
# Out:
# Balances before transfer:
# ACC-1075 | Nafim | Balance: ₹10000
# ACC-2001 | Ruby | Balance: ₹5000
# Transaction started.
# ₹3000 transferred from ACC-1075 to ACC-2001.
# Transaction committed successfully.
#
# Balances after transfer:
# ACC-1075 | Nafim | Balance: ₹7000
# ACC-2001 | Ruby | Balance: ₹8000

# %%
#Q76. Separate domain and infrastructure layers for banking case 1; use sample reference ACC-1076 and explain the result.


# ==================================================
# DOMAIN LAYER
# Contains banking business rules
# ==================================================

class Account:
    def __init__(self, account_number, account_name, balance):
        if balance < 0:
            raise ValueError("Opening balance cannot be negative.")

        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount must be greater than zero.")

        self.balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Withdrawal amount must be greater than zero.")

        if amount > self.balance:
            raise ValueError("Insufficient balance.")

        self.balance -= amount

    def __str__(self):
        return (f"{self.account_number} | {self.account_name} | Balance: ₹{self.balance}")


class AccountRepository:
    """Domain-level repository abstraction."""

    def save(self, account):
        raise NotImplementedError("Subclass must implement save().")

    def get_by_id(self, account_number):
        raise NotImplementedError("Subclass must implement get_by_id().")


# ==================================================
# INFRASTRUCTURE LAYER
# Contains technical storage implementation
# ==================================================

class InMemoryAccountRepository(AccountRepository):
    def __init__(self):
        self._accounts = {}

    def save(self, account):
        self._accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self._accounts.get(account_number)


# ==================================================
# APPLICATION / EXECUTION LAYER
# Connects domain and infrastructure
# ==================================================

repository = InMemoryAccountRepository()

account = Account(account_number="ACC-1076",account_name="Nafim",balance=10000)

account.deposit(3000)
account.withdraw(2000)

repository.save(account)

saved_account = repository.get_by_id("ACC-1076")

if saved_account is not None:
    print(saved_account)
else:
    print("Account not found.")

### Layer separation keeps banking business rules independent from technical storage details. The domain layer contains the Account entity and its business validations, while the infrastructure layer implements data storage through InMemoryAccountRepository.
### This allows the storage technology to change without modifying the core banking logic.
# Out:
# ACC-1076 | Nafim | Balance: ₹11000

# %%
#Q77. Design a plugin-ready payment architecture for banking case 1; use sample reference ACC-1077 and explain the result.


class UPIPlugin:
    def pay(self, account_reference, amount):
        return (f"Payment successful: ₹{amount} paid through UPI for {account_reference}")


class CreditCardPlugin:
    def pay(self, account_reference, amount):
        return (f"Payment successful: ₹{amount} paid through Credit Card for {account_reference}")


class PaymentProcessor:
    def __init__(self):
        self.plugins = {}

    def register_plugin(self, payment_name, payment_plugin):
        self.plugins[payment_name.upper()] = payment_plugin

    def process_payment(self,payment_name,account_reference,amount):
        if amount <= 0:
            raise ValueError("Payment amount must be greater than zero.")

        payment_name = payment_name.upper()
        payment_plugin = self.plugins.get(payment_name)

        if payment_plugin is None:
            raise ValueError(f"Payment plugin '{payment_name}' is not registered.")

        return payment_plugin.pay(account_reference,amount)


# Create the payment processor
processor = PaymentProcessor()

# Register available payment plugins
processor.register_plugin("UPI",UPIPlugin())

processor.register_plugin("CREDIT_CARD",CreditCardPlugin())

# Process a payment
result = processor.process_payment(payment_name="UPI",account_reference="ACC-1077",amount=5000)

print(result)

### A plugin-ready payment architecture defines a common operation for all payment plugins and maintains a registry of available implementations. The processor selects the required plugin at runtime.
### New payment methods can be introduced by creating and registering additional plugin classes without changing the payment processor.
# Out:
# Payment successful: ₹5000 paid through UPI for ACC-1077

# %%
#Q78. Implement a descriptor for positive amounts for banking case 1; use sample reference ACC-1078 and explain the result.


class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name = "_" + name

    def __get__(self, instance, owner):
        return getattr(instance, self.name)

    def __set__(self, instance, value):
        if value <= 0:
            raise ValueError("Amount must be positive")

        setattr(instance, self.name, value)


class Account:
    balance = PositiveAmount()

    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def display(self):
        print("Account Number:", self.account_number)
        print("Balance       : ₹", self.balance)


account = Account("ACC-1078", 10000)

account.display()

### A descriptor is a Python object that defines methods such as __get__() and __set__() to control attribute access.
### In this example, the PositiveAmount descriptor ensures that balance values are always greater than zero, preventing invalid account amounts.
# Out:
# Account Number: ACC-1078
# Balance       : ₹ 10000

# %%
#Q79. Use cooperative inheritance with super for banking case 1; use sample reference ACC-1079 and explain the result.


class Base:
    def __init__(self, **kwargs):
        super().__init__(**kwargs)


class AccountInfo(Base):
    def __init__(self,account_number,account_name,**kwargs):
        self.account_number = account_number
        self.account_name = account_name

        super().__init__(**kwargs)


class BalanceMixin(Base):
    def __init__(self,balance,**kwargs):
        self.balance = balance

        super().__init__(**kwargs)


class BankingAccount(AccountInfo,BalanceMixin):
    def __init__(self,account_number,account_name,balance):
        super().__init__(account_number=account_number,account_name=account_name,balance=balance)

    def display(self):
        print(f"{self.account_number} | {self.account_name} | ₹{self.balance}")


account = BankingAccount("ACC-1079","Nafim",18000)

account.display()

### Cooperative inheritance uses super() so that all classes in a multiple inheritance hierarchy participate in initialization according to Python's Method Resolution Order (MRO).
### This avoids duplicate constructor calls and makes the inheritance chain easier to maintain.
# Out:
# ACC-1079 | Nafim | ₹18000

# %%
#Q80. Refactor a god object using solid for banking case 1; use sample reference ACC-1080 and explain the result.


# Domain Entity
class Account:
    def __init__(self, account_number, account_name, balance):
        if balance < 0:
            raise ValueError("Opening balance cannot be negative")

        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount must be positive")

        self.balance += amount


# Interest Strategy
class SavingsInterest:
    def calculate(self, balance):
        return balance * 0.05


# Repository Abstraction
class AccountRepository:
    def save(self, account):
        raise NotImplementedError

    def get_by_id(self, account_number):
        raise NotImplementedError


# Repository Implementation
class InMemoryAccountRepository(AccountRepository):
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self.accounts.get(account_number)


# Notification Abstraction
class Notifier:
    def send(self, message):
        raise NotImplementedError


# SMS Notification
class SMSNotifier(Notifier):
    def send(self, message):
        print(f"SMS Notification: {message}")


# Report Generator
class AccountReport:
    def generate(self, account, interest):
        return (
            f"Account Reference : {account.account_number}\n"
            f"Account Name      : {account.account_name}\n"
            f"Current Balance   : ₹{account.balance}\n"
            f"Interest          : ₹{interest}"
        )


# Application Service
class AccountService:
    def __init__(self,repository,interest_strategy,notifier,report_generator):
        self.repository = repository
        self.interest_strategy = interest_strategy
        self.notifier = notifier
        self.report_generator = report_generator

    def process_account(self,account,deposit_amount):
        account.deposit(deposit_amount)

        interest = self.interest_strategy.calculate(account.balance)

        self.repository.save(account)

        self.notifier.send(f"₹{deposit_amount} deposited into {account.account_number}")

        return self.report_generator.generate(account,interest)
repository = InMemoryAccountRepository()

interest_strategy = SavingsInterest()

notifier = SMSNotifier()

report_generator = AccountReport()

service = AccountService(repository,interest_strategy,notifier,report_generator)

account = Account("ACC-1080","Nafim",10000)

report = service.process_account(account,2000)

print(report)

### A God Object is a class that performs too many responsibilities. I refactored it using SOLID by separating the account entity, interest calculation, storage, notification, reporting, and workflow coordination into focused classes.
### The application service receives its dependencies from outside, making the solution easier to extend, test, and maintain.
# Out:
# SMS Notification: ₹2000 deposited into ACC-1080
# Account Reference : ACC-1080
# Account Name      : Nafim
# Current Balance   : ₹12000
# Interest          : ₹600.0

# %%
#Q81. Design an extensible pricing engine for banking case 2; use sample reference ACC-1081 and explain the result.


class RegularPricing:
    def calculate(self, amount):
        fee = amount * 0.02
        return fee

class PremiumPricing:
    def calculate(self, amount):
        fee = amount * 0.01
        return fee

class VIPPricing:
    def calculate(self, amount):
        return 0

class PricingEngine:
    def __init__(self, pricing_strategy):
        self.pricing_strategy = pricing_strategy

    def calculate_fee(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be greater than zero")

        return self.pricing_strategy.calculate(amount)


# Account details
account_reference = "ACC-1081"
transaction_amount = 10000

# Select a pricing rule
engine = PricingEngine(PremiumPricing())

# Calculate the transaction fee
fee = engine.calculate_fee(transaction_amount)
final_amount = transaction_amount + fee

print("Account Reference :", account_reference)
print("Transaction Amount:", transaction_amount)
print("Processing Fee    :", fee)
print("Final Amount       :", final_amount)

### An extensible pricing engine separates each pricing rule into its own class.
### The required pricing strategy is passed to the engine, allowing new pricing rules to be added without changing the engine's existing code.
# Out:
# Account Reference : ACC-1081
# Transaction Amount: 10000
# Processing Fee    : 100.0
# Final Amount       : 10100.0

# %%
#Q82. Implement an observer for low balance for banking case 2; use sample reference ACC-1082 and explain the result.


class SMSALERT:
  def update(self,Account_number,Balance):
    print(f"SMS Alert: {Account_number} has a low balance of {Balance}")

class EMAILAlert:
  def update(self,Account_number,Balance):
    print(f"Email Alert: {Account_number} has a low balance of {Balance}")

class Account:
  def __init__(self,Account_number,Balance,Minimum_balance):
    self.Account_number = Account_number
    self.Balance = Balance
    self.Minimum_balance = Minimum_balance
    self.observers = []

  def add_observers(self,observer):
    self.observers.append(observer)

  def remove_observers(self,observer):
    if observer in self.observers:
      self.observers.remove(observer)

  def Notify(self):
    for observer in self.observers:
      observer.update(self.Account_number,self.Balance)

  def withdraw(self,amount):
    if amount <= 0:
      print(" Amount should be greater than zero")
    elif amount > self.Balance:
      print("Insufficent Balance")
    else:
      self.Balance -= amount

      print(f"{amount} Withdrawn Successfully")
      print(f"Current Balance:{self.Balance}")

      if self.Balance < self.Minimum_balance:
        self.Notify()

account = Account("ACC-1082",100000,5000)

sms_alert = SMSALERT()
Email_alert = EMAILAlert()

account.add_observers(sms_alert)
account.add_observers(Email_alert)

account.withdraw(96000)

### The Observer Pattern creates a one-to-many relationship between objects. When the subject's state changes, all registered observers are notified automatically.
### Here, the Account is the subject, and SMSAlert and EmailAlert are observers that receive notifications when the account balance falls below the minimum balance.
# Out:
# 96000 Withdrawn Successfully
# Current Balance:4000
# SMS Alert: ACC-1082 has a low balance of 4000
# Email Alert: ACC-1082 has a low balance of 4000

# %%
#Q83. Build a state machine for transfer status for banking case 2; use sample reference ACC-1083 and explain the result.


class Transfer:
    def __init__(self, account_reference, amount):
        self.account_reference = account_reference
        self.amount = amount
        self.status = "PENDING"

    def start_processing(self):
        if self.status == "PENDING":
            self.status = "PROCESSING"
            print("Transfer processing started.")
        else:
            print(
                f"Cannot start processing when status is {self.status}."
            )

    def complete_transfer(self):
        if self.status == "PROCESSING":
            self.status = "COMPLETED"
            print("Transfer completed successfully.")
        else:
            print(
                f"Cannot complete transfer when status is {self.status}."
            )

    def fail_transfer(self):
        if self.status in ["PENDING", "PROCESSING"]:
            self.status = "FAILED"
            print("Transfer failed.")
        else:
            print(
                f"Cannot fail transfer when status is {self.status}."
            )

    def display(self):
        print(f"Account Reference : {self.account_reference}")
        print(f"Transfer Amount   : ₹{self.amount}")
        print(f"Transfer Status   : {self.status}")


# Create transfer
transfer = Transfer("ACC-1083", 5000)

print("Initial Transfer Details")
transfer.display()

print("\nStarting Transfer")
transfer.start_processing()
transfer.display()

print("\nCompleting Transfer")
transfer.complete_transfer()
transfer.display()

### A state machine controls how an object moves between different states.
### In this banking example, a transfer starts in the PENDING state, moves to PROCESSING,
### and finally becomes either COMPLETED or FAILED. Each method validates the current status before allowing the next transition.
# Out:
# Initial Transfer Details
# Account Reference : ACC-1083
# Transfer Amount   : ₹5000
# Transfer Status   : PENDING
#
# Starting Transfer
# Transfer processing started.
# Account Reference : ACC-1083
# Transfer Amount   : ₹5000
# Transfer Status   : PROCESSING
#
# Completing Transfer
# Transfer completed successfully.
# Account Reference : ACC-1083
# Transfer Amount   : ₹5000
# Transfer Status   : COMPLETED

# %%
#Q84. Create an immutable money value object for banking case 2; use sample reference ACC-1084 and explain the result.


from dataclasses import dataclass
from decimal import Decimal


@dataclass(frozen=True)
class Money:
    amount: Decimal
    currency: str

    def __post_init__(self):
        if self.amount < 0:
            raise ValueError("Money amount cannot be negative")

        if not self.currency:
            raise ValueError("Currency cannot be empty")

    def add(self, other):
        if self.currency != other.currency:
            raise ValueError("Cannot add different currencies")

        return Money(self.amount + other.amount,self.currency)

    def __str__(self):
        return f"{self.currency} {self.amount:.2f}"


class Account:
    def __init__(self, account_number, Opening_balance):
        self.account_number = account_number
        self.Opening_balance = Opening_balance

        self.balance = Opening_balance

    def deposit(self, money):
        self.balance = self.balance.add(money)

    def display(self):
        print("Opening Balance  :", self.Opening_balance)
        print("Account Reference:", self.account_number)
        print("Account Balance  :", self.balance)


opening_balance = Money(Decimal("10000.00"),"INR")

account = Account("ACC-1084",opening_balance)

deposit_amount = Money(Decimal("2500.00"),"INR")

account.deposit(deposit_amount)
account.display()

### An immutable money value object represents an amount together with its currency and does not allow its values to be changed after creation.
#### In Python, @dataclass(frozen=True) provides immutability and value-based equality. Money operations return new objects rather than modifying existing objects.
# Out:
# Opening Balance  : INR 10000.00
# Account Reference: ACC-1084
# Account Balance  : INR 12500.00

# %%
#Q85. Implement a unit-of-work transaction for banking case 2; use sample reference ACC-1085 and explain the result.


class Account:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    def __str__(self):
        return (f"{self.account_number} | {self.account_name} | Balance: ₹{self.balance}")


class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def add(self, account):
        self.accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self.accounts.get(account_number)

class UnitOfWork:
    def __init__(self, repository):
        self.repository = repository
        self.original_balances = {}
        self.is_committed = False

    def __enter__(self):
        # Save original balances before making changes
        for account_number, account in self.repository.accounts.items():
            self.original_balances[account_number] = account.balance

        print("Transaction started.")
        return self

    def commit(self):
        self.is_committed = True
        print("Transaction committed successfully.")

    def rollback(self):
        # Restore every account's original balance
        for account_number, original_balance in self.original_balances.items():
            account = self.repository.get_by_id(account_number)

            if account is not None:
                account.balance = original_balance

        print("Transaction rolled back.")

    def __exit__(self, exception_type, exception_value, traceback):
        if exception_type is not None or not self.is_committed:
            self.rollback()

        # False means Python will not hide an exception
        return False


class TransferService:
    def transfer(self, from_account, to_account, amount):
        if amount <= 0:
            raise ValueError("Transfer amount must be greater than zero.")

        if from_account.balance < amount:
            raise ValueError("Insufficient balance in sender account.")

        from_account.balance -= amount
        to_account.balance += amount

        print(f"₹{amount} transferred from {from_account.account_number} to {to_account.account_number}.")


# Create repository
repository = AccountRepository()

# Create accounts
sender = Account("ACC-1085","Nafim",10000)

receiver = Account("ACC-2001","Ruby",5000)

# Store accounts in repository
repository.add(sender)
repository.add(receiver)

print("Balances before transfer:")
print(sender)
print(receiver)

transfer_service = TransferService()

# Unit-of-work transaction
try:
    with UnitOfWork(repository) as unit_of_work:
        transfer_service.transfer(sender,receiver,3000)
        unit_of_work.commit()

except ValueError as error:
    print("Error:", error)

print("\nBalances after transfer:")
print(sender)
print(receiver)

### The Unit of Work pattern groups multiple data changes into a single transaction. It commits all changes when every operation succeeds and rolls them back when any operation fails.
### In this example, debiting ACC-1085 and crediting the receiver are treated as one atomic transaction.
# Out:
# Balances before transfer:
# ACC-1085 | Nafim | Balance: ₹10000
# ACC-2001 | Ruby | Balance: ₹5000
# Transaction started.
# ₹3000 transferred from ACC-1085 to ACC-2001.
# Transaction committed successfully.
#
# Balances after transfer:
# ACC-1085 | Nafim | Balance: ₹7000
# ACC-2001 | Ruby | Balance: ₹8000

# %%
#86. Separate domain and infrastructure layers for banking case 2; use sample reference ACC-1086 and explain the result.


# ==================================================
# DOMAIN LAYER
# Contains banking business rules
# ==================================================

class Account:
    def __init__(self, account_number, account_name, balance):
        if balance < 0:
            raise ValueError("Opening balance cannot be negative.")

        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount must be greater than zero.")

        self.balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Withdrawal amount must be greater than zero.")

        if amount > self.balance:
            raise ValueError("Insufficient balance.")

        self.balance -= amount

    def __str__(self):
        return (f"{self.account_number} | {self.account_name} | Balance: ₹{self.balance}")


class AccountRepository:
    """Domain-level repository abstraction."""

    def save(self, account):
        raise NotImplementedError("Subclass must implement save().")

    def get_by_id(self, account_number):
        raise NotImplementedError("Subclass must implement get_by_id().")


# ==================================================
# INFRASTRUCTURE LAYER
# Contains technical storage implementation
# ==================================================

class InMemoryAccountRepository(AccountRepository):
    def __init__(self):
        self._accounts = {}

    def save(self, account):
        self._accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self._accounts.get(account_number)


# ==================================================
# APPLICATION / EXECUTION LAYER
# Connects domain and infrastructure
# ==================================================

repository = InMemoryAccountRepository()

account = Account(account_number="ACC-1076",account_name="Nafim",balance=10000)

account.deposit(3000)
account.withdraw(2000)

repository.save(account)

saved_account = repository.get_by_id("ACC-1086")

if saved_account is not None:
    print(saved_account)
else:
    print("Account not found.")

### Layer separation keeps banking business rules independent from technical storage details. The domain layer contains the Account entity and its business validations, while the infrastructure layer implements data storage through InMemoryAccountRepository.
### This allows the storage technology to change without modifying the core banking logic.
# Out:
# Account not found.

# %%
#Q87. Design a plugin-ready payment architecture for banking case 2; use sample reference ACC-1087 and explain the result.


class UPIPlugin:
    def pay(self, account_reference, amount):
        return (f"Payment successful: ₹{amount} paid through UPI for {account_reference}")


class CreditCardPlugin:
    def pay(self, account_reference, amount):
        return (f"Payment successful: ₹{amount} paid through Credit Card for {account_reference}")


class PaymentProcessor:
    def __init__(self):
        self.plugins = {}

    def register_plugin(self, payment_name, payment_plugin):
        self.plugins[payment_name.upper()] = payment_plugin

    def process_payment(self,payment_name,account_reference,amount):
        if amount <= 0:
            raise ValueError("Payment amount must be greater than zero.")

        payment_name = payment_name.upper()
        payment_plugin = self.plugins.get(payment_name)

        if payment_plugin is None:
            raise ValueError(f"Payment plugin '{payment_name}' is not registered.")

        return payment_plugin.pay(account_reference,amount)


# Create the payment processor
processor = PaymentProcessor()

# Register available payment plugins
processor.register_plugin("UPI",UPIPlugin())

processor.register_plugin("CREDIT_CARD",CreditCardPlugin())

# Process a payment
result = processor.process_payment(payment_name="UPI",account_reference="ACC-1087",amount=5000)

print(result)

### A plugin-ready payment architecture defines a common operation for all payment plugins and maintains a registry of available implementations. The processor selects the required plugin at runtime.
### New payment methods can be introduced by creating and registering additional plugin classes without changing the payment processor.
# Out:
# Payment successful: ₹5000 paid through UPI for ACC-1087

# %%
#Q88. Implement a descriptor for positive amounts for banking case 2; use sample reference ACC-1088 and explain the result.


class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name = "_" + name

    def __get__(self, instance, owner):
        return getattr(instance, self.name)

    def __set__(self, instance, value):
        if value <= 0:
            raise ValueError("Amount must be positive")

        setattr(instance, self.name, value)


class Account:
    balance = PositiveAmount()

    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def display(self):
        print("Account Number:", self.account_number)
        print("Balance       : ₹", self.balance)


account = Account("ACC-1088", 10000)

account.display()

### A descriptor is a Python object that defines methods such as __get__() and __set__() to control attribute access.
### In this example, the PositiveAmount descriptor ensures that balance values are always greater than zero, preventing invalid account amounts.
# Out:
# Account Number: ACC-1088
# Balance       : ₹ 10000

# %%
#Q89. Use cooperative inheritance with super for banking case 2; use sample reference ACC-1089 and explain the result.


class Base:
    def __init__(self, **kwargs):
        super().__init__(**kwargs)


class AccountInfo(Base):
    def __init__(self,account_number,account_name,**kwargs):
        self.account_number = account_number
        self.account_name = account_name

        super().__init__(**kwargs)


class BalanceMixin(Base):
    def __init__(self,balance,**kwargs):
        self.balance = balance

        super().__init__(**kwargs)


class BankingAccount(AccountInfo,BalanceMixin):
    def __init__(self,account_number,account_name,balance):
        super().__init__(account_number=account_number,account_name=account_name,balance=balance)

    def display(self):
        print(f"{self.account_number} | {self.account_name} | ₹{self.balance}")


account = BankingAccount("ACC-1089","Nafim",18000)

account.display()

### Cooperative inheritance uses super() so that all classes in a multiple inheritance hierarchy participate in initialization according to Python's Method Resolution Order (MRO).
### This avoids duplicate constructor calls and makes the inheritance chain easier to maintain.
# Out:
# ACC-1089 | Nafim | ₹18000

# %%
#Q90. Refactor a god object using solid for banking case 2; use sample reference ACC-1090 and explain the result.


# Domain Entity
class Account:
    def __init__(self, account_number, account_name, balance):
        if balance < 0:
            raise ValueError("Opening balance cannot be negative")

        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount must be positive")

        self.balance += amount


# Interest Strategy
class SavingsInterest:
    def calculate(self, balance):
        return balance * 0.05


# Repository Abstraction
class AccountRepository:
    def save(self, account):
        raise NotImplementedError

    def get_by_id(self, account_number):
        raise NotImplementedError


# Repository Implementation
class InMemoryAccountRepository(AccountRepository):
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self.accounts.get(account_number)


# Notification Abstraction
class Notifier:
    def send(self, message):
        raise NotImplementedError


# SMS Notification
class SMSNotifier(Notifier):
    def send(self, message):
        print(f"SMS Notification: {message}")


# Report Generator
class AccountReport:
    def generate(self, account, interest):
        return (
            f"Account Reference : {account.account_number}\n"
            f"Account Name      : {account.account_name}\n"
            f"Current Balance   : ₹{account.balance}\n"
            f"Interest          : ₹{interest}"
        )


# Application Service
class AccountService:
    def __init__(self,repository,interest_strategy,notifier,report_generator):
        self.repository = repository
        self.interest_strategy = interest_strategy
        self.notifier = notifier
        self.report_generator = report_generator

    def process_account(self,account,deposit_amount):
        account.deposit(deposit_amount)

        interest = self.interest_strategy.calculate(account.balance)

        self.repository.save(account)

        self.notifier.send(f"₹{deposit_amount} deposited into {account.account_number}")

        return self.report_generator.generate(account,interest)
repository = InMemoryAccountRepository()

interest_strategy = SavingsInterest()

notifier = SMSNotifier()

report_generator = AccountReport()

service = AccountService(repository,interest_strategy,notifier,report_generator)

account = Account("ACC-1090","Nafim",10000)

report = service.process_account(account,2000)

print(report)

### A God Object is a class that performs too many responsibilities. I refactored it using SOLID by separating the account entity, interest calculation, storage, notification, reporting, and workflow coordination into focused classes.
### The application service receives its dependencies from outside, making the solution easier to extend, test, and maintain.
# Out:
# SMS Notification: ₹2000 deposited into ACC-1090
# Account Reference : ACC-1090
# Account Name      : Nafim
# Current Balance   : ₹12000
# Interest          : ₹600.0

# %%
#Q91. Design an extensible pricing engine for banking case 3; use sample reference ACC-1091 and explain the result.


class RegularPricing:
    def calculate(self, amount):
        fee = amount * 0.02
        return fee

class PremiumPricing:
    def calculate(self, amount):
        fee = amount * 0.01
        return fee

class VIPPricing:
    def calculate(self, amount):
        return 0

class PricingEngine:
    def __init__(self, pricing_strategy):
        self.pricing_strategy = pricing_strategy

    def calculate_fee(self, amount):
        if amount <= 0:
            raise ValueError("Amount must be greater than zero")

        return self.pricing_strategy.calculate(amount)


# Account details
account_reference = "ACC-1091"
transaction_amount = 10000

# Select a pricing rule
engine = PricingEngine(PremiumPricing())

# Calculate the transaction fee
fee = engine.calculate_fee(transaction_amount)
final_amount = transaction_amount + fee

print("Account Reference :", account_reference)
print("Transaction Amount:", transaction_amount)
print("Processing Fee    :", fee)
print("Final Amount       :", final_amount)
# Out:
# Account Reference : ACC-1091
# Transaction Amount: 10000
# Processing Fee    : 100.0
# Final Amount       : 10100.0

# %%
#Q92. Implement an observer for low balance for banking case 3; use sample reference ACC-1092 and explain the result.


class SMSALERT:
  def update(self,Account_number,Balance):
    print(f"SMS Alert: {Account_number} has a low balance of {Balance}")

class EMAILAlert:
  def update(self,Account_number,Balance):
    print(f"Email Alert: {Account_number} has a low balance of {Balance}")

class Account:
  def __init__(self,Account_number,Balance,Minimum_balance):
    self.Account_number = Account_number
    self.Balance = Balance
    self.Minimum_balance = Minimum_balance
    self.observers = []

  def add_observers(self,observer):
    self.observers.append(observer)

  def remove_observers(self,observer):
    if observer in self.observers:
      self.observers.remove(observer)

  def Notify(self):
    for observer in self.observers:
      observer.update(self.Account_number,self.Balance)

  def withdraw(self,amount):
    if amount <= 0:
      print(" Amount should be greater than zero")
    elif amount > self.Balance:
      print("Insufficent Balance")
    else:
      self.Balance -= amount

      print(f"{amount} Withdrawn Successfully")
      print(f"Current Balance:{self.Balance}")

      if self.Balance < self.Minimum_balance:
        self.Notify()

account = Account("ACC-1092",100000,5000)

sms_alert = SMSALERT()
Email_alert = EMAILAlert()

account.add_observers(sms_alert)
account.add_observers(Email_alert)

account.withdraw(96000)

### The Observer Pattern creates a one-to-many relationship between objects. When the subject's state changes, all registered observers are notified automatically.
### Here, the Account is the subject, and SMSAlert and EmailAlert are observers that receive notifications when the account balance falls below the minimum balance.
# Out:
# 96000 Withdrawn Successfully
# Current Balance:4000
# SMS Alert: ACC-1092 has a low balance of 4000
# Email Alert: ACC-1092 has a low balance of 4000

# %%
#Q93. Build a state machine for transfer status for banking case 3; use sample reference ACC-1093 and explain the result.


class Transfer:
    def __init__(self, account_reference, amount):
        self.account_reference = account_reference
        self.amount = amount
        self.status = "PENDING"

    def start_processing(self):
        if self.status == "PENDING":
            self.status = "PROCESSING"
            print("Transfer processing started.")
        else:
            print(
                f"Cannot start processing when status is {self.status}."
            )

    def complete_transfer(self):
        if self.status == "PROCESSING":
            self.status = "COMPLETED"
            print("Transfer completed successfully.")
        else:
            print(
                f"Cannot complete transfer when status is {self.status}."
            )

    def fail_transfer(self):
        if self.status in ["PENDING", "PROCESSING"]:
            self.status = "FAILED"
            print("Transfer failed.")
        else:
            print(
                f"Cannot fail transfer when status is {self.status}."
            )

    def display(self):
        print(f"Account Reference : {self.account_reference}")
        print(f"Transfer Amount   : ₹{self.amount}")
        print(f"Transfer Status   : {self.status}")


# Create transfer
transfer = Transfer("ACC-1093", 5000)

print("Initial Transfer Details")
transfer.display()

print("\nStarting Transfer")
transfer.start_processing()
transfer.display()

print("\nCompleting Transfer")
transfer.complete_transfer()
transfer.display()

### A state machine controls how an object moves between different states.
### In this banking example, a transfer starts in the PENDING state, moves to PROCESSING, and finally becomes either COMPLETED or FAILED.
### Each method validates the current status before allowing the next transition.
# Out:
# Initial Transfer Details
# Account Reference : ACC-1093
# Transfer Amount   : ₹5000
# Transfer Status   : PENDING
#
# Starting Transfer
# Transfer processing started.
# Account Reference : ACC-1093
# Transfer Amount   : ₹5000
# Transfer Status   : PROCESSING
#
# Completing Transfer
# Transfer completed successfully.
# Account Reference : ACC-1093
# Transfer Amount   : ₹5000
# Transfer Status   : COMPLETED

# %%
#Q94. Create an immutable money value object for banking case 3; use sample reference ACC-1094 and explain the result.


from dataclasses import dataclass
from decimal import Decimal


@dataclass(frozen=True)
class Money:
    amount: Decimal
    currency: str

    def __post_init__(self):
        if self.amount < 0:
            raise ValueError("Money amount cannot be negative")

        if not self.currency:
            raise ValueError("Currency cannot be empty")

    def add(self, other):
        if self.currency != other.currency:
            raise ValueError("Cannot add different currencies")

        return Money(self.amount + other.amount,self.currency)

    def __str__(self):
        return f"{self.currency} {self.amount:.2f}"


class Account:
    def __init__(self, account_number, Opening_balance):
        self.account_number = account_number
        self.Opening_balance = Opening_balance

        self.balance = Opening_balance

    def deposit(self, money):
        self.balance = self.balance.add(money)

    def display(self):
        print("Opening Balance  :", self.Opening_balance)
        print("Account Reference:", self.account_number)
        print("Account Balance  :", self.balance)


opening_balance = Money(Decimal("10000.00"),"INR")

account = Account("ACC-1094",opening_balance)

deposit_amount = Money(Decimal("2500.00"),"INR")

account.deposit(deposit_amount)
account.display()

### An immutable money value object represents an amount together with its currency and does not allow its values to be changed after creation.
#### In Python, @dataclass(frozen=True) provides immutability and value-based equality. Money operations return new objects rather than modifying existing objects.
# Out:
# Opening Balance  : INR 10000.00
# Account Reference: ACC-1094
# Account Balance  : INR 12500.00

# %%
#Q95. Implement a unit-of-work transaction for banking case 3; use sample reference ACC-1095 and explain the result.


class Account:
    def __init__(self, account_number, account_name, balance):
        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    def __str__(self):
        return (f"{self.account_number} | {self.account_name} | Balance: ₹{self.balance}")


class AccountRepository:
    def __init__(self):
        self.accounts = {}

    def add(self, account):
        self.accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self.accounts.get(account_number)

class UnitOfWork:
    def __init__(self, repository):
        self.repository = repository
        self.original_balances = {}
        self.is_committed = False

    def __enter__(self):
        # Save original balances before making changes
        for account_number, account in self.repository.accounts.items():
            self.original_balances[account_number] = account.balance

        print("Transaction started.")
        return self

    def commit(self):
        self.is_committed = True
        print("Transaction committed successfully.")

    def rollback(self):
        # Restore every account's original balance
        for account_number, original_balance in self.original_balances.items():
            account = self.repository.get_by_id(account_number)

            if account is not None:
                account.balance = original_balance

        print("Transaction rolled back.")

    def __exit__(self, exception_type, exception_value, traceback):
        if exception_type is not None or not self.is_committed:
            self.rollback()

        # False means Python will not hide an exception
        return False


class TransferService:
    def transfer(self, from_account, to_account, amount):
        if amount <= 0:
            raise ValueError("Transfer amount must be greater than zero.")

        if from_account.balance < amount:
            raise ValueError("Insufficient balance in sender account.")

        from_account.balance -= amount
        to_account.balance += amount

        print(f"₹{amount} transferred from {from_account.account_number} to {to_account.account_number}.")


# Create repository
repository = AccountRepository()

# Create accounts
sender = Account("ACC-1095","Nafim",10000)

receiver = Account("ACC-2001","Ruby",5000)

# Store accounts in repository
repository.add(sender)
repository.add(receiver)

print("Balances before transfer:")
print(sender)
print(receiver)

transfer_service = TransferService()

# Unit-of-work transaction
try:
    with UnitOfWork(repository) as unit_of_work:
        transfer_service.transfer(sender,receiver,3000)
        unit_of_work.commit()

except ValueError as error:
    print("Error:", error)

print("\nBalances after transfer:")
print(sender)
print(receiver)

### The Unit of Work pattern groups multiple data changes into a single transaction. It commits all changes when every operation succeeds and rolls them back when any operation fails.
### In this example, debiting ACC-1095 and crediting the receiver are treated as one atomic transaction.
# Out:
# Balances before transfer:
# ACC-1095 | Nafim | Balance: ₹10000
# ACC-2001 | Ruby | Balance: ₹5000
# Transaction started.
# ₹3000 transferred from ACC-1095 to ACC-2001.
# Transaction committed successfully.
#
# Balances after transfer:
# ACC-1095 | Nafim | Balance: ₹7000
# ACC-2001 | Ruby | Balance: ₹8000

# %%
#Q96. Separate domain and infrastructure layers for banking case 3; use sample reference ACC-1096 and explain the result.


# ==================================================
# DOMAIN LAYER
# Contains banking business rules
# ==================================================

class Account:
    def __init__(self, account_number, account_name, balance):
        if balance < 0:
            raise ValueError("Opening balance cannot be negative.")

        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount must be greater than zero.")

        self.balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Withdrawal amount must be greater than zero.")

        if amount > self.balance:
            raise ValueError("Insufficient balance.")

        self.balance -= amount

    def __str__(self):
        return (f"{self.account_number} | {self.account_name} | Balance: ₹{self.balance}")


class AccountRepository:
    """Domain-level repository abstraction."""

    def save(self, account):
        raise NotImplementedError("Subclass must implement save().")

    def get_by_id(self, account_number):
        raise NotImplementedError("Subclass must implement get_by_id().")


# ==================================================
# INFRASTRUCTURE LAYER
# Contains technical storage implementation
# ==================================================

class InMemoryAccountRepository(AccountRepository):
    def __init__(self):
        self._accounts = {}

    def save(self, account):
        self._accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self._accounts.get(account_number)


# ==================================================
# APPLICATION / EXECUTION LAYER
# Connects domain and infrastructure
# ==================================================

repository = InMemoryAccountRepository()

account = Account(account_number="ACC-1076",account_name="Yuvateja",balance=10000)

account.deposit(3000)
account.withdraw(2000)

repository.save(account)

saved_account = repository.get_by_id("ACC-1096")

if saved_account is not None:
    print(saved_account)
else:
    print("Account not found.")

### Layer separation keeps banking business rules independent from technical storage details. The domain layer contains the Account entity and its business validations, while the infrastructure layer implements data storage through InMemoryAccountRepository.
### This allows the storage technology to change without modifying the core banking logic.
# Out:
# Account not found.

# %%
#Q97. Design a plugin-ready payment architecture for banking case 3; use sample reference ACC-1097 and explain the result.


class UPIPlugin:
    def pay(self, account_reference, amount):
        return (f"Payment successful: ₹{amount} paid through UPI for {account_reference}")


class CreditCardPlugin:
    def pay(self, account_reference, amount):
        return (f"Payment successful: ₹{amount} paid through Credit Card for {account_reference}")


class PaymentProcessor:
    def __init__(self):
        self.plugins = {}

    def register_plugin(self, payment_name, payment_plugin):
        self.plugins[payment_name.upper()] = payment_plugin

    def process_payment(self,payment_name,account_reference,amount):
        if amount <= 0:
            raise ValueError("Payment amount must be greater than zero.")

        payment_name = payment_name.upper()
        payment_plugin = self.plugins.get(payment_name)

        if payment_plugin is None:
            raise ValueError(f"Payment plugin '{payment_name}' is not registered.")

        return payment_plugin.pay(account_reference,amount)


# Create the payment processor
processor = PaymentProcessor()

# Register available payment plugins
processor.register_plugin("UPI",UPIPlugin())

processor.register_plugin("CREDIT_CARD",CreditCardPlugin())

# Process a payment
result = processor.process_payment(payment_name="UPI",account_reference="ACC-1097",amount=5000)

print(result)

### A plugin-ready payment architecture defines a common operation for all payment plugins and maintains a registry of available implementations. The processor selects the required plugin at runtime.
### New payment methods can be introduced by creating and registering additional plugin classes without changing the payment processor.
# Out:
# Payment successful: ₹5000 paid through UPI for ACC-1097

# %%
#Q98. Implement a descriptor for positive amounts for banking case 3; use sample reference ACC-1098 and explain the result.


class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name = "_" + name

    def __get__(self, instance, owner):
        return getattr(instance, self.name)

    def __set__(self, instance, value):
        if value <= 0:
            raise ValueError("Amount must be positive")

        setattr(instance, self.name, value)


class Account:
    balance = PositiveAmount()

    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def display(self):
        print("Account Number:", self.account_number)
        print("Balance       : ₹", self.balance)


account = Account("ACC-1098", 10000)

account.display()

### A descriptor is a Python object that defines methods such as __get__() and __set__() to control attribute access.
### In this example, the PositiveAmount descriptor ensures that balance values are always greater than zero, preventing invalid account amounts.
# Out:
# Account Number: ACC-1098
# Balance       : ₹ 10000

# %%
#Q99. Use cooperative inheritance with super for banking case 3; use sample reference ACC-1099 and explain the result.


class Base:
    def __init__(self, **kwargs):
        super().__init__(**kwargs)


class AccountInfo(Base):
    def __init__(self,account_number,account_name,**kwargs):
        self.account_number = account_number
        self.account_name = account_name

        super().__init__(**kwargs)


class BalanceMixin(Base):
    def __init__(self,balance,**kwargs):
        self.balance = balance

        super().__init__(**kwargs)


class BankingAccount(AccountInfo,BalanceMixin):
    def __init__(self,account_number,account_name,balance):
        super().__init__(account_number=account_number,account_name=account_name,balance=balance)

    def display(self):
        print(f"{self.account_number} | {self.account_name} | ₹{self.balance}")


account = BankingAccount("ACC-1099","Nafim",15000)

account.display()

### Cooperative inheritance uses super() so that all classes in a multiple inheritance hierarchy participate in initialization according to Python's Method Resolution Order (MRO).
### This avoids duplicate constructor calls and makes the inheritance chain easier to maintain.
# Out:
# ACC-1099 | Nafim | ₹15000

# %%
#Q100. Refactor a god object using solid for banking case 3; use sample reference ACC-1100 and explain the result.


# Domain Entity
class Account:
    def __init__(self, account_number, account_name, balance):
        if balance < 0:
            raise ValueError("Opening balance cannot be negative")

        self.account_number = account_number
        self.account_name = account_name
        self.balance = balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount must be positive")

        self.balance += amount


# Interest Strategy
class SavingsInterest:
    def calculate(self, balance):
        return balance * 0.05


# Repository Abstraction
class AccountRepository:
    def save(self, account):
        raise NotImplementedError

    def get_by_id(self, account_number):
        raise NotImplementedError


# Repository Implementation
class InMemoryAccountRepository(AccountRepository):
    def __init__(self):
        self.accounts = {}

    def save(self, account):
        self.accounts[account.account_number] = account

    def get_by_id(self, account_number):
        return self.accounts.get(account_number)


# Notification Abstraction
class Notifier:
    def send(self, message):
        raise NotImplementedError


# SMS Notification
class SMSNotifier(Notifier):
    def send(self, message):
        print(f"SMS Notification: {message}")


# Report Generator
class AccountReport:
    def generate(self, account, interest):
        return (
            f"Account Reference : {account.account_number}\n"
            f"Account Name      : {account.account_name}\n"
            f"Current Balance   : ₹{account.balance}\n"
            f"Interest          : ₹{interest}"
        )


# Application Service
class AccountService:
    def __init__(self,repository,interest_strategy,notifier,report_generator):
        self.repository = repository
        self.interest_strategy = interest_strategy
        self.notifier = notifier
        self.report_generator = report_generator

    def process_account(self,account,deposit_amount):
        account.deposit(deposit_amount)

        interest = self.interest_strategy.calculate(account.balance)

        self.repository.save(account)

        self.notifier.send(f"₹{deposit_amount} deposited into {account.account_number}")

        return self.report_generator.generate(account,interest)
repository = InMemoryAccountRepository()

interest_strategy = SavingsInterest()

notifier = SMSNotifier()

report_generator = AccountReport()

service = AccountService(repository,interest_strategy,notifier,report_generator)

account = Account("ACC-1100","Nafim",10000)

report = service.process_account(account,2000)

print(report)

### A God Object is a class that performs too many responsibilities. I refactored it using SOLID by separating the account entity, interest calculation, storage, notification, reporting, and workflow coordination into focused classes.
### The application service receives its dependencies from outside, making the solution easier to extend, test, and maintain.
# Out:
# SMS Notification: ₹2000 deposited into ACC-1100
# Account Reference : ACC-1100
# Account Name      : Nafim
# Current Balance   : ₹12000
# Interest          : ₹600.0
