# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafimunnisa/nafimunnisa-2026/blob/main/Nafim2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
print(a)
type(a)
# Out:
# 10
# int

# %%
a=10.2
type(a)
# Out:
# float

# %%
a=(2+3j)
type(a)
# Out:
# complex

# %%
a="data Science"
print(a)
print(type(a))
# Out:
# data Science
# <class 'str'>

# %%
a=[1,2,3]
print(a)
type(a)
# Out:
# [1, 2, 3]
# list

# %%
a=(1,2,3,"data")
print(a)
type(a)
# Out:
# (1, 2, 3, 'data')
# tuple

# %%
b={1,2,3}
print(b)
type(b)
# Out:
# {1, 2, 3}
# set

# %%
a=2+3j
a.real
# Out:
# 2.0

# %%
x="data science"
print(x)
# Out:
# data science

# %%
x[-4:-2]
print(x[-11:])
print(x[:4])
# Out:
# ata science
# data

# %%
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[0:7])
# Out:
# Edukron

# %%
print(text[8:12])
# Out:
# Data

# %%
print(text[13:20])
# Out:
# Science

# %%
print(text[21:24])
# Out:
# and

# %%
print(text[25:41])
# Out:
# Data Engineering

# %%
print(text[30:41])
# Out:
# Engineering

# %%
print(text[42:47])
# Out:
# Batch

# %%
print(text[48:52])
# Out:
# 2026

# %%
print(text[13:29])
# Out:
# Science and Data

# %%
print(text[8:47])
# Out:
# Data Science and Data Engineering Batch

# %%
age=20
if age<=18:
  print("you are an adult")
else:
  print("you are not adult")
# Out:
# you are not adult

# %%
score=50
if score >= 90:
    print("New Score Grade: A")
elif score >= 80:
    print("New Score Grade: B")
elif score >= 70:
    print("New Score Grade: C")
elif score >= 60:
    print("New Score Grade: D")
else:
    print("New Score Grade: F")
# Out:
# New Score Grade: F

# %%
row=5
for i in range(row):
  for j in range(row):
    print("*",end='')
  print("")
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
number=1
row=5
for i in range(row):
  for j in range(i+1):
    print(number,end="")
  print(" ")
# Out:
# 1
# 11
# 111
# 1111
# 11111

# %%
row=5
for i in range(rows):
for j in range(rows - i - 1):
     print(" ", end="")
  for j in range(2 * i + 1):
      print("*", end="")
    print()
# Out:
#   File "<tokenize>", line 5
#     for j in range(2 * i + 1):
#     ^
# IndentationError: unindent does not match any outer indentation level
