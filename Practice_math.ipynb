# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafimunnisa/nafimunnisa-2026/blob/main/Practice_math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
math.factorial(5)
# Out:
# 120

# %%
math.gcd(18,24)  ##grestest common divisor
# Out:
# 6

# %%
math.sqrt(81)  ##sqare root
# Out:
# 9.0

# %%
math.pow(64,0.5)  ## exponent of a value
# Out:
# 8.0

# %%
math.cbrt(56)  ##cube root
# Out:
# 3.8258623655447788

# %%
math.pow(27,1/3)
# Out:
# 3.0

# %%
print(math.log(10))
print(math.log2(10))
print(math.log10(10))
# Out:
# 2.302585092994046
# 3.321928094887362
# 1.0

# %%
print(math.sin(90))
print(math.cos(90))
print(math.tan(90))
# Out:
# 0.8939966636005579
# -0.4480736161291701
# -1.995200412208242

# %%
print(math.asin(90))
print(math.acos(90))
print(math.atan(90))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_417/3471003346.py in <cell line: 0>()
# ----> 1 print(math.asin(90))
#       2 print(math.acos(90))
#       3 print(math.atan(90))
#
# ValueError: math domain error

# %%
print(math.asin(1))
print(math.acos(1))
print(math.atan(1))
# Out:
# 1.5707963267948966
# 0.0
# 0.7853981633974483

# %%
### hypot
math.hypot(3,4)  ### distnce from the origin to the specific point
# Out:
# 5.0

# %%
math.isnan(math.nan)   ###null value
# Out:
# True

# %%
math.inf
# Out:
# inf

# %%
math.isinf
# Out:
# <function math.isinf(x, /)>

# %%
math.isinf(math.inf)
# Out:
# True

# %%
math.remainder(10,3)
# Out:
# 1.0

# %%
math.remainder(121,3)
# Out:
# 1.0

# %%
math.dist((1,2),(4,6))
# Out:
# 5.0

# %%
x=[[10.20],[30,40],[50,60]]
for i in x:
  for j in x:
    if i!=j:
      print(math.dist(i,j))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_417/1548627013.py in <cell line: 0>()
#       3   for j in x:
#       4     if i!=j:
# ----> 5       print(math.dist(i,j))
#
# ValueError: both points must have the same number of dimensions

# %%
x=[[10.20],[30,40],[50,60]]
# for i in range(0,len(x))
#  for j in range(i+1)
for i in x:
  for j in x:
    if i!=j:
print(math.dist(i,j))
# Out:
#   File "/tmp/ipykernel_417/1566088342.py", line 7
#     print(math.dist(i,j))
#                          ^
# IndentationError: expected an indented block after 'if' statement on line 6

# %%
math.perm(5,2)
# Out:
# 20

# %%
math.comb(5,2)
# Out:
# 10

# %%
def add(x,y,z):
 return x*y*z
add(40,20,20)
# Out:
# 16000

# %%
def add(x,y):
  print(x+y)
add(10,20)
add("data","science")
# Out:
# 30
# datascience
