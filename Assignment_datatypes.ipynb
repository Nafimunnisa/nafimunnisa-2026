# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafimunnisa/nafimunnisa-2026/blob/main/Assignment_datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hours_worked = 40

# %%
print(type(hours_worked))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1106/602449042.py in <cell line: 0>()
# ----> 1 print(type(hours_worked))
#
# NameError: name 'hours_worked' is not defined

# %%
hours_worked = '40'
print(type(hours_worked))
# Out:
# <class 'str'>

# %%
hours_worked =40
print(type(hours_worked))
# Out:
# <class 'int'>

# %%
hourly_wages =120.60
print(type(hourly_wages))
# Out:
# <class 'float'>

# %%
company_name = "Optum"
print(type(company_name))
# Out:
# <class 'str'>

# %%
payment_completed = True
print(type(payment_completed))
# Out:
# <class 'bool'>

# %%
num_str = '45'
print(f"Type before conversion: {(num_str)}")
# Out:
# Type before conversion: 45

# %%
num_int = int(num_str)
print(f"Type after conversion: {(num_int)}")
# Out:
# Type after conversion: 45

# %%
num_float = 99.9
print(f"Type before conversion: {(num_float)}")
num_int = int(num_float)
print(f"Type after conversion: {(num_int)}")
# Out:
# Type before conversion: 99.9
# Type after conversion: 99

# %%
num_int = 100
num_float = float(num_int)
print(f"Type before conversion: {(num_float)}")
# Out:
# Type before conversion: 100.0

# %%
num_bool = True
num_int = int(num_bool)
print(f"Type after conversion: {(num_int)}")
# Out:
# Type after conversion: 1

# %%
num_bool = False
num_int = int(num_bool)
print(f"Type after conversion: {(num_int)}")
# Out:
# Type after conversion: 0

# %%
product_name = "Product A"
cost = 10.5
in_stock = True

sentence = f"{product_name} costs ${cost} and is in stock: {in_stock}"
print(sentence)
# Out:
# Product A costs $10.5 and is in stock: True
