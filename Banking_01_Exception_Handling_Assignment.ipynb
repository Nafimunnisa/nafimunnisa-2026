# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafimunnisa/nafimunnisa-2026/blob/main/Banking_01_Exception_Handling_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Banking Assignment — Exception Handling (100 Questions with Hints)

# %%
#Q1. Parse a deposit amount for banking case 1; use sample reference ACC-1001 and explain the result.

account_num = "ACC-1001"

try:
    deposit_amount = int(input("Enter the Deposit Amount: "))

    if deposit_amount > 0:
        print(f"Account: {account_num}")
        print(f"Deposit Amount: {deposit_amount}")
    else:
        print("Deposit amount must be greater than 0.")

except ValueError:
    print("Invalid input. Please enter a valid integer amount.")
# Out:
# Enter the Deposit Amount: 155
# Account: ACC-1001
# Deposit Amount: 155

# %%
#Q2. Handle a missing account key for banking case 1; use sample reference ACC-1002 and explain the result.

account_details = {
    "account_number" : "ACC-1002",
    "Holder_name" : "Yuvateja"}

try:
  print("Account Number:",{account_details["account_number"]})
  print("Balance:",{account_details["balance"]})


except KeyError:
  print("Missing account details key: 'balance'")
# Out:
# Account Number: {'ACC-1002'}
# Missing account details key: 'balance'

# %%
#Q3. Prevent division by zero in average balance for banking case 1; use sample reference ACC-1003 and explain the result.

account_number = "ACC-1003"
total_balance = 50000
no_of_accounts = 0

try:
  avg_balance = total_balance/no_of_accounts
  print("Average Balnce",avg_balance)

except ZeroDivisionError:
  print("Account Number ", account_number)
  print("Cannot calculate average balance because the number of accounts is zero.")
# Out:
# Account Number  ACC-1003
# Cannot calculate average balance because the number of accounts is zero.

# %%
#Q4. Open a transaction file safely for banking case 1; use sample reference ACC-1004 and explain the result.

account_number = "ACC-1004"

try:
  file = open("Account_Number.txt",'r')
  print("Account Number",account_number)
  print(file.read)

except FileNotFoundError:
  print("Account Number",account_number)
  print("Transaction file not found.")
# Out:
# Account Number ACC-1004
# Transaction file not found.

# %%
#Q5. Reject a negative withdrawal for banking case 1; use sample reference ACC-1005 and explain the result.


account_number = "ACC-1005"

try:
  withdrawal_amount = int(input("Enter withdraw amount:"))
  if withdrawal_amount < 0:
    raise ValueError("Withdraw amount should not be negative")

  print("Account Number",account_number)
  print("Withdraw Amount", withdrawal_amount)

except ValueError as e:
  print(e)

## Here we are assigning the value error with some text and xalling it with e so that what ever the error msg it throw to input msg.
# Out:
# Enter withdraw amount:2500
# Account Number ACC-1005
# Withdraw Amount 2500

# %%
#Q6. Catch invalid tenure input for banking case 1; use sample reference ACC-1006 and explain the result.


account_number = "ACC-1006"
tenture = -10

try:
  if tenture < 0:
    raise ValueError("Tenture should be greater than 0")

  print("Account Number:",account_number)
  print("Tenture:",tenture)

except ValueError as e:
  print("Account Number:",account_number)
  print(e)

##  same as previous example we are raising the error if tenture is invalid
# Out:
# Account Number: ACC-1006
# Tenture should be greater than 0

# %%
#Q7. Use else after pin-format validation for banking case 1; use sample reference ACC-1007 and explain the result.


account_number = "ACC-1007"

pin = input("Enter the pin:")

try:
  if len(pin) != 4:
    raise ValueError("Pin should be 4 digits")

except ValueError as e:
  print("Account number",account_number)
  print(e)

else:
  print("Account number",account_number)
  print("Pin Entered Correctly")

### here lenth of pin not equal to 4 it will throw error and we are calling that error as e, if pin is entered correctly it will dispaly else condition.
# Out:
# Enter the pin:2165
# Account number ACC-1007
# Pin Entered Correctly

# %%
#Q8. Use finally to close a session for banking case 1; use sample reference ACC-1008 and explain the result.


acc_number = "ACC-1008"

try:
  print("session started")
  print("Account Number", acc_number)
  Balance = 10000
  withdraw = 2000
  if withdraw < 0 and Balance > withdraw:
    raise ValueError("withdraw should be greater than 0 and it should be greater than balance ")
  Remaining_balance = Balance - withdraw
  print("Balance",Remaining_balance)

except ValueError as e:
  print(e)

finally:
  print("Session Closed")
# Out:
# session started
# Account Number ACC-1008
# Balance 8000
# Session Closed

# %%
#Q9. Catch multiple numeric conversion errors for banking case 1; use sample reference ACC-1009 and explain the result.


account_number = "ACC-1009"

try:
    deposit_amount = int(input("Enter Deposit Amount: "))
    tenure = int(input("Enter Tenure (Years): "))

    print(f"Account Number: {account_number}")
    print(f"Deposit Amount: {deposit_amount}")
    print(f"Tenure: {tenure} years")

except ValueError:
    print("Invalid input. Please enter numeric values only.")
# Out:
# Enter Deposit Amount: 15000
# Enter Tenure (Years): 2015
# Account Number: ACC-1009
# Deposit Amount: 15000
# Tenure: 2015 years

# %%
#Q10. Raise a clear valueerror for banking case 1; use sample reference ACC-1010 and explain the result.


account_number = "ACC-1010"

try:
    withdrawal_amount = -500

    if withdrawal_amount < 0:
        raise ValueError("Withdrawal amount cannot be negative.")

    print(f"Account Number: {account_number}")
    print(f"Withdrawal Amount: {withdrawal_amount}")

except ValueError as e:
    print(e)
# Out:
# Withdrawal amount cannot be negative.

# %%
#Q11. Parse a deposit amount for banking case 2; use sample reference ACC-1011 and explain the result.


account_number = "ACC-1011"

try:
    deposit_amount = int(input("Enter Deposit Amount: "))

    if deposit_amount > 0:
        print(f"Account Number: {account_number}")
        print(f"Deposit Amount: {deposit_amount}")
    else:
        print("Deposit amount must be greater than 0.")

except ValueError:
    print("Invalid deposit amount. Please enter a valid number.")
# Out:
# Enter Deposit Amount: 80000
# Account Number: ACC-1011
# Deposit Amount: 80000

# %%
#Q12. Handle a missing account key for banking case 2; use sample reference ACC-1012 and explain the result.


account = {
    "account_number": "ACC-1012",
    "customer_name": "Rahul"
}

try:
    print(f"Account Number: {account['account_number']}")
    print(f"Balance: {account['balance']}")

except KeyError:
    print("Account key 'balance' is missing.")
# Out:
# Account Number: ACC-1012
# Account key 'balance' is missing.

# %%
#Q13. Prevent division by zero in average balance for banking case 2; use sample reference ACC-1013 and explain the result.


account_number = "ACC-1013"

try:
    total_balance = 25000
    number_of_accounts = 0

    average_balance = total_balance / number_of_accounts

    print(f"Account Number: {account_number}")
    print(f"Average Balance: {average_balance}")

except ZeroDivisionError:
    print(f"Account Number: {account_number}")
    print("Cannot calculate average balance because the number of accounts is zero.")
# Out:
# Account Number: ACC-1013
# Cannot calculate average balance because the number of accounts is zero.

# %%
#Q14. Open a transaction file safely for banking case 2; use sample reference ACC-1014 and explain the result.


account_number = "ACC-1014"

try:
    file = open("transactions_ACC-1014.txt", "r")

    print(f"Account Number: {account_number}")
    print(file.read())

    file.close()

except FileNotFoundError:
    print(f"Account Number: {account_number}")
    print("Transaction file not found.")
# Out:
# Account Number: ACC-1014
# Transaction file not found.

# %%
#Q15. Reject a negative withdrawal for banking case 2; use sample reference ACC-1015 and explain the result.


account_number = "ACC-1015"

try:
    withdrawal_amount = -2000

    if withdrawal_amount < 0:
        raise ValueError("Withdrawal amount cannot be negative.")

    print(f"Account Number: {account_number}")
    print(f"Withdrawal Amount: {withdrawal_amount}")

except ValueError as e:
    print(f"Account Number: {account_number}")
    print(e)
# Out:
# Account Number: ACC-1015
# Withdrawal amount cannot be negative.

# %%
#Q16. Catch invalid tenure input for banking case 2; use sample reference ACC-1016 and explain the result.


account_number = "ACC-1016"
tenture = -10

try:
  if tenture < 0:
    raise ValueError("Tenture should be greater than 0")

  print("Account Number:",account_number)
  print("Tenture:",tenture)

except ValueError as e:
  print("Account Number:",account_number)
  print(e)
# Out:
# Account Number: ACC-1016
# Tenture should be greater than 0

# %%
#Q17. Use else after pin-format validation for banking case 2; use sample reference ACC-1017 and explain the result.


account_number = "ACC-1017"
pin = input("Enter the pin:")

try:
  if len(pin) != 4:
    raise ValueError("Pin should be 4 digits")

except ValueError as e:
  print("Account number",account_number)
  print(e)

else:
  print("Account number",account_number)
  print("Pin Entered Correctly")
# Out:
# Enter the pin:002165
# Account number ACC-1017
# Pin should be 4 digits

# %%
#Q18. Use finally to close a session for banking case 2; use sample reference ACC-1018 and explain the result.


acc_number = "ACC-1018"

try:
  print("session started")
  print("Account Number", acc_number)
  Balance = 10000
  withdraw = 2000
  if withdraw < 0 and Balance > withdraw:
    raise ValueError("withdraw should be greater than 0 and it should be greater than balance ")
  Remaining_balance = Balance - withdraw
  print("Balance",Remaining_balance)

except ValueError as e:
  print(e)

finally:
  print("Session Closed")
# Out:
# session started
# Account Number ACC-1018
# Balance 8000
# Session Closed

# %%
#Q19. Catch multiple numeric conversion errors for banking case 2; use sample reference ACC-1019 and explain the result.


account_number = "ACC-1019"

try:
    deposit_amount = int(input("Enter Deposit Amount: "))
    tenure = int(input("Enter Tenure (Years): "))

    print(f"Account Number: {account_number}")
    print(f"Deposit Amount: {deposit_amount}")
    print(f"Tenure: {tenure} years")

except ValueError:
    print("Invalid input. Please enter numeric values only.")
# Out:
# Enter Deposit Amount: 18000
# Enter Tenure (Years): 2026
# Account Number: ACC-1019
# Deposit Amount: 18000
# Tenure: 2026 years

# %%
#Q20. Raise a clear valueerror for banking case 2; use sample reference ACC-1020 and explain the result.


account_number = "ACC-1020"

try:
    withdrawal_amount = -500

    if withdrawal_amount < 0:
        raise ValueError("Withdrawal amount cannot be negative.")

    print(f"Account Number: {account_number}")
    print(f"Withdrawal Amount: {withdrawal_amount}")

except ValueError as e:
    print(e)
# Out:
# Withdrawal amount cannot be negative.

# %%
# Q21. Parse a deposit amount for banking case 3; use sample reference ACC-1021 and explain the result.


account_number = "ACC-1021"

try:
    deposit_amount = int(input("Enter Deposit Amount: "))

    if deposit_amount > 0:
        print(f"Account Number: {account_number}")
        print(f"Deposit Amount: {deposit_amount}")
    else:
        print("Deposit amount must be greater than 0.")

except ValueError:
    print("Invalid deposit amount. Please enter a valid number.")
# Out:
# Enter Deposit Amount: 5000
# Account Number: ACC-1021
# Deposit Amount: 5000

# %%
#Q22. Handle a missing account key for banking case 3; use sample reference ACC-1022 and explain the result.


account = {
    "account_number": "ACC-1012",
    "customer_name": "Rahul"
}

try:
    print(f"Account Number: {account['account_number']}")
    print(f"Balance: {account['balance']}")

except KeyError:
    print("Account key 'balance' is missing.")
# Out:
# Account Number: ACC-1012
# Account key 'balance' is missing.

# %%
#Q23. Prevent division by zero in average balance for banking case 3; use sample reference ACC-1023 and explain the result.


account_number = "ACC-1023"

try:
    total_balance = 25000
    number_of_accounts = 0

    average_balance = total_balance / number_of_accounts

    print(f"Account Number: {account_number}")
    print(f"Average Balance: {average_balance}")

except ZeroDivisionError:
    print(f"Account Number: {account_number}")
    print("Cannot calculate average balance because the number of accounts is zero.")
# Out:
# Account Number: ACC-1023
# Cannot calculate average balance because the number of accounts is zero.

# %%
#Q24. Open a transaction file safely for banking case 3; use sample reference ACC-1024 and explain the result.


account_number = "ACC-1024"

try:
    file = open("transactions_ACC-1014.txt", "r")

    print(f"Account Number: {account_number}")
    print(file.read())

    file.close()

except FileNotFoundError:
    print(f"Account Number: {account_number}")
    print("Transaction file not found.")
# Out:
# Account Number: ACC-1024
# Transaction file not found.

# %%
#Q25. Reject a negative withdrawal for banking case 3; use sample reference ACC-1025 and explain the result.


account_number = "ACC-1025"

try:
    withdrawal_amount = -2000

    if withdrawal_amount < 0:
        raise ValueError("Withdrawal amount cannot be negative.")

    print(f"Account Number: {account_number}")
    print(f"Withdrawal Amount: {withdrawal_amount}")

except ValueError as e:
    print(f"Account Number: {account_number}")
    print(e)
# Out:
# Account Number: ACC-1025
# Withdrawal amount cannot be negative.

# %%
#Q26. Catch invalid tenure input for banking case 3; use sample reference ACC-1026 and explain the result.


account_number = "ACC-1026"
tenture = -10

try:
  if tenture < 0:
    raise ValueError("Tenture should be greater than 0")

  print("Account Number:",account_number)
  print("Tenture:",tenture)

except ValueError as e:
  print("Account Number:",account_number)
  print(e)
# Out:
# Account Number: ACC-1026
# Tenture should be greater than 0

# %%
#Q27. Use else after pin-format validation for banking case 3; use sample reference ACC-1027 and explain the result.


account_number = "ACC-1027"
pin = input("Enter the pin:")

try:
  if len(pin) != 4:
    raise ValueError("Pin should be 4 digits")

except ValueError as e:
  print("Account number",account_number)
  print(e)

else:
  print("Account number",account_number)
  print("Pin Entered Correctly")
# Out:
# Enter the pin:76548
# Account number ACC-1027
# Pin should be 4 digits

# %%
#Q28. Use finally to close a session for banking case 3; use sample reference ACC-1028 and explain the result.


acc_number = "ACC-1028"

try:
  print("session started")
  print("Account Number", acc_number)
  Balance = 10000
  withdraw = 2000
  if withdraw < 0 and Balance > withdraw:
    raise ValueError("withdraw should be greater than 0 and it should be greater than balance ")
  Remaining_balance = Balance - withdraw
  print("Balance",Remaining_balance)

except ValueError as e:
  print(e)

finally:
  print("Session Closed")
# Out:
# session started
# Account Number ACC-1028
# Balance 8000
# Session Closed

# %%
#Q29. Catch multiple numeric conversion errors for banking case 3; use sample reference ACC-1029 and explain the result.


account_number = "ACC-1029"

try:
    deposit_amount = int(input("Enter Deposit Amount: "))
    tenure = int(input("Enter Tenure (Years): "))

    print(f"Account Number: {account_number}")
    print(f"Deposit Amount: {deposit_amount}")
    print(f"Tenure: {tenure} years")

except ValueError:
    print("Invalid input. Please enter numeric values only.")
# Out:
# Enter Deposit Amount: 6000
# Enter Tenure (Years): 2017
# Account Number: ACC-1029
# Deposit Amount: 6000
# Tenure: 2017 years

# %%
#Q30. Raise a clear valueerror for banking case 3; use sample reference ACC-1030 and explain the result.


account_number = "ACC-1030"

try:
    withdrawal_amount = -500

    if withdrawal_amount < 0:
        raise ValueError("Withdrawal amount cannot be negative.")

    print(f"Account Number: {account_number}")
    print(f"Withdrawal Amount: {withdrawal_amount}")

except ValueError as e:
    print(e)
# Out:
# Withdrawal amount cannot be negative.

# %%
#Q31. Create insufficientfundserror for banking case 1; use sample reference ACC-1031 and explain the result.


class InsufficientFundsError(Exception):
  pass
account_number = "ACC-1031"
Balance_amount = 1500
Withdraw_amount = 50000

try:
  if Withdraw_amount > Balance_amount:
    raise InsufficientFundsError('Insufficient Funds')

  Balance_amount -= Withdraw_amount
  print("Remaining Balance:",Balance_amount)

except InsufficientFundsError as e:
  print("Account Balance:",Balance_amount)
  print(e)

### Since there is InsufficientFundsError we are cresting a class for the exception and calling it.
# Out:
# Account Balance: 1500
# Insufficient Funds

# %%
#Q32. Chain invalidtransactionerror from valueerror for banking case 1; use sample reference ACC-1032 and explain the result.


class InvalidTransactionError(Exception):
  pass
Account_number = "ACC-1032"
Amount = "YUVA"
try:
  try:
    int(Amount)
  except ValueError as e:
    raise InvalidTransactionError("Invalid Transaction") from e
except InvalidTransactionError as e:
  print('Account Number:',Account_number)
  print(e)
# Out:
# Account Number: ACC-1032
# Invalid Transaction

# %%
#Q33. Process transfers while isolating bad rows for banking case 1; use sample reference ACC-1033 and explain the result.


account_number = "Acc-1033"
transfers = [1000,"Yuva",800,"Teja"]

print("Account Number:",account_number)

for i in transfers:
  try:
    i = int(i)
    print("Transfer Processed:",i)
  except ValueError:
    print("Bad Row:",i)
# Out:
# Account Number: Acc-1033
# Transfer Processed: 1000
# Bad Row: Yuva
# Transfer Processed: 800
# Bad Row: Teja

# %%
#Q34. Retry a transient payment gateway for banking case 1; use sample reference ACC-1034 and explain the result.


account_number = "Acc-1034"

for attempt in range(3):
  try:
    if attempt < 2:
      raise ConnectionError("Bad transient payment gateway - Try again")

    print("Payment Successfully ")
    break

  except ConnectionError as e:
    print("Attempt",attempt+1, "-" ,e)
# Out:
# Attempt 1 - Bad transient payment gateway - Try again
# Attempt 2 - Bad transient payment gateway - Try again
# Payment Successfully

# %%
#Q35. Log failed standing instructions for banking case 1; use sample reference ACC-1035 and explain the result.


account_number = "Acc-1035"

try:
  raise Exception("Standing instructions Failed")
except Exception as e:
  print("Account Number:",account_number)
  print(e)
# Out:
# Account Number: Acc-1035
# Standing instructions Failed

# %%
#Q36. Return a structured failure result for banking case 1; use sample reference ACC-1036 and explain the result.


account_number = "ACC-1036"
withdraw = -1000

try:
  if withdraw < 0:
    raise ValueError("Invalid Withdraw amount")
except ValueError as e:
  print("Account number:",account_number)
  print("Status:","Failed")
  print("Error Message:",e)
# Out:
# Account number: ACC-1036
# Status: Failed
# Error Message: Invalid Withdraw amount

# %%
#Q37. Validate a nested beneficiary record for banking case 1; use sample reference ACC-1037 and explain the result.


account_number = "Acc-1037"
beneficiary = {"Name":"Yuvateja",
                   "Account_Type":"Savings",
                   "Account_Details":{}
                   }

try:
  if not beneficiary["Account_Details"]:
    raise KeyError("Beneficiary Account Details Missing")

except KeyError as e:
  print("Account Number:",account_number)
  print(e)
# Out:
# Account Number: Acc-1037
# 'Beneficiary Account Details Missing'

# %%
#Q38. Use a context manager for an audit file for banking case 1; use sample reference ACC-1038 and explain the result.


account_number = "Acc-1038"

try:
  with open("audit.txt","w") as file:
    file.write("Account Number:" + account_number)
    file.write("\nAudit Completed")
  print("Audit File Updated Successfully")
except Exception as e:
  print("Error:",e)
# Out:
# Audit File Updated Successfully

# %%
#Q39. Separate validation and recovery for banking case 1; use sample reference ACC-1039 and explain the result.


account_number = "Acc-1039"
withdraw_amount = -500

try:
  if withdraw_amount < 0:
    raise ValueError("Invalid Withdraw amount")

except ValueError as e:
  print("Account Number:",account_number)
  print(e)

  withdraw_amount = 0
  print("Recovery Withdraw amount set to ",withdraw_amount)
# Out:
# Account Number: Acc-1039
# Invalid Withdraw amount
# Recovery Withdraw amount set to  0

# %%
#Q40. Collect all kyc validation errors for banking case 1; use sample reference ACC-1040 and explain the result.


account_number = "Acc-1040"
KYC_Details = {"Name":"","PAN":"","DOB":"","Aadhar":""}
errors = []

try:
  for key,value in KYC_Details.items():
    if not value:
      errors.append(f"{key} value Missing in KYC Details")
  if errors:
    raise ValueError("\n".join(errors))

except ValueError as e:
  print("Account Number:",account_number)
  print("KYC Validation Errors:")
  print(e)
# Out:
# Account Number: Acc-1040
# KYC Validation Errors:
# Name value Missing in KYC Details
# PAN value Missing in KYC Details
# DOB value Missing in KYC Details
# Aadhar value Missing in KYC Details

# %%
#Q41. Create insufficientfundserror for banking case 2; use sample reference ACC-1041 and explain the result.


class InsufficientFundsError(Exception):
  pass
account_number = "ACC-1041"
Balance_amount = 1500
Withdraw_amount = 50000

try:
  if Withdraw_amount > Balance_amount:
    raise InsufficientFundsError('Insufficient Funds')

  Balance_amount -= Withdraw_amount
  print("Remaining Balance:",Balance_amount)

except InsufficientFundsError as e:
  print("Account Balance:",Balance_amount)
  print(e)
# Out:
# Account Balance: 1500
# Insufficient Funds

# %%
#Q42. Chain invalidtransactionerror from valueerror for banking case 2; use sample reference ACC-1042 and explain the result. Hints


class InvalidTransactionError(Exception):
  pass
Account_number = "ACC-1042"
Amount = "YUVA"
try:
  try:
    int(Amount)
  except ValueError as e:
    raise InvalidTransactionError("Invalid Transaction") from e
except InvalidTransactionError as e:
  print('Account Number:',Account_number)
  print(e)
# Out:
# Account Number: ACC-1042
# Invalid Transaction

# %%
#Q43. Process transfers while isolating bad rows for banking case 2; use sample reference ACC-1043 and explain the result.


account_number = "Acc-1043"
transfers = [1000,"Yuva",800,"Teja"]

print("Account Number:",account_number)

for i in transfers:
  try:
    i = int(i)
    print("Transfer Processed:",i)
  except ValueError:
    print("Bad Row:",i)
# Out:
# Account Number: Acc-1043
# Transfer Processed: 1000
# Bad Row: Yuva
# Transfer Processed: 800
# Bad Row: Teja

# %%
#Q44. Retry a transient payment gateway for banking case 2; use sample reference ACC-1044 and explain the result.


account_number = "Acc-1044"

for attempt in range(3):
  try:
    if attempt < 2:
      raise ConnectionError("Bad transient payment gateway - Try again")

    print("Payment Successfully ")
    break

  except ConnectionError as e:
    print("Attempt",attempt+1, "-" ,e)
# Out:
# Attempt 1 - Bad transient payment gateway - Try again
# Attempt 2 - Bad transient payment gateway - Try again
# Payment Successfully

# %%
#Q45. Log failed standing instructions for banking case 2; use sample reference ACC-1045 and explain the result.


account_number = "Acc-1045"

try:
  raise Exception("Standing instructions Failed")
except Exception as e:
  print("Account Number:",account_number)
  print(e)
# Out:
# Account Number: Acc-1045
# Standing instructions Failed

# %%
#Q46. Return a structured failure result for banking case 2; use sample reference ACC-1046 and explain the result.


account_number = "ACC-1046"
withdraw = -1000

try:
  if withdraw < 0:
    raise ValueError("Invalid Withdraw amount")
except ValueError as e:
  print("Account number:",account_number)
  print("Status:","Failed")
  print("Error Message:",e)
# Out:
# Account number: ACC-1046
# Status: Failed
# Error Message: Invalid Withdraw amount

# %%
#Q47. Validate a nested beneficiary record for banking case 2; use sample reference ACC-1047 and explain the result.


account_number = "Acc-1047"
beneficiary = {"Name":"Yuvateja",
                   "Account_Type":"Savings",
                   "Account_Details":{}
                   }

try:
  if not beneficiary["Account_Details"]:
    raise KeyError("Beneficiary Account Details Missing")

except KeyError as e:
  print("Account Number:",account_number)
  print(e)
# Out:
# Account Number: Acc-1047
# 'Beneficiary Account Details Missing'

# %%
#Q48. Use a context manager for an audit file for banking case 2; use sample reference ACC-1048 and explain the result.


account_number = "Acc-1048"

try:
  with open("audit.txt","w") as file:
    file.write("Account Number:" + account_number)
    file.write("\nAudit Completed")
  print("Audit File Updated Successfully")
except Exception as e:
  print("Error:",e)
# Out:
# Audit File Updated Successfully

# %%
#Q49. Separate validation and recovery for banking case 2; use sample reference ACC-1049 and explain the result.


account_number = "Acc-1049"
withdraw_amount = -500

try:
  if withdraw_amount < 0:
    raise ValueError("Invalid Withdraw amount")

except ValueError as e:
  print("Account Number:",account_number)
  print(e)

  withdraw_amount = 0
  print("Recovery Withdraw amount set to ",withdraw_amount)
# Out:
# Account Number: Acc-1049
# Invalid Withdraw amount
# Recovery Withdraw amount set to  0

# %%
#Q50. Collect all kyc validation errors for banking case 2; use sample reference ACC-1050 and explain the result.


account_number = "Acc-1050"
KYC_Details = {"Name":"","PAN":"","DOB":"","Aadhar":""}
errors = []

try:
  for key,value in KYC_Details.items():
    if not value:
      errors.append(f"{key} value Missing in KYC Details")
  if errors:
    raise ValueError("\n".join(errors))

except ValueError as e:
  print("Account Number:",account_number)
  print("KYC Validation Errors:")
  print(e)
# Out:
# Account Number: Acc-1050
# KYC Validation Errors:
# Name value Missing in KYC Details
# PAN value Missing in KYC Details
# DOB value Missing in KYC Details
# Aadhar value Missing in KYC Details

# %%
#Q51. Create insufficientfundserror for banking case 3; use sample reference ACC-1051 and explain the result


class InsufficientFundsError(Exception):
  pass
account_number = "ACC-1051"
Balance_amount = 1500
Withdraw_amount = 50000

try:
  if Withdraw_amount > Balance_amount:
    raise InsufficientFundsError('Insufficient Funds')

  Balance_amount -= Withdraw_amount
  print("Remaining Balance:",Balance_amount)

except InsufficientFundsError as e:
  print("Account Balance:",Balance_amount)
  print(e)
# Out:
# Account Balance: 1500
# Insufficient Funds

# %%
#Q52. Chain invalidtransactionerror from valueerror for banking case 3; use sample reference ACC-1052 and explain the result.


class InvalidTransactionError(Exception):
  pass
Account_number = "ACC-1052"
Amount = "YUVA"
try:
  try:
    int(Amount)
  except ValueError as e:
    raise InvalidTransactionError("Invalid Transaction") from e
except InvalidTransactionError as e:
  print('Account Number:',Account_number)
  print(e)
# Out:
# Account Number: ACC-1052
# Invalid Transaction

# %%
#Q53. Process transfers while isolating bad rows for banking case 3; use sample reference ACC-1053 and explain the result.


account_number = "Acc-1053"
transfers = [1000,"Yuva",800,"Teja"]

print("Account Number:",account_number)

for i in transfers:
  try:
    i = int(i)
    print("Transfer Processed:",i)
  except ValueError:
    print("Bad Row:",i)
# Out:
# Account Number: Acc-1053
# Transfer Processed: 1000
# Bad Row: Yuva
# Transfer Processed: 800
# Bad Row: Teja

# %%
#Q54. Retry a transient payment gateway for banking case 3; use sample reference ACC-1054 and explain the result.


account_number = "Acc-1054"

for attempt in range(3):
  try:
    if attempt < 2:
      raise ConnectionError("Bad transient payment gateway - Try again")

    print("Payment Successfully ")
    break

  except ConnectionError as e:
    print("Attempt",attempt+1, "-" ,e)
# Out:
# Attempt 1 - Bad transient payment gateway - Try again
# Attempt 2 - Bad transient payment gateway - Try again
# Payment Successfully

# %%
#Q55. Log failed standing instructions for banking case 3; use sample reference ACC-1055 and explain the result.


account_number = "Acc-1055"

try:
  raise Exception("Standing instructions Failed")
except Exception as e:
  print("Account Number:",account_number)
  print(e)
# Out:
# Account Number: Acc-1055
# Standing instructions Failed

# %%
#Q56. Return a structured failure result for banking case 3; use sample reference ACC-1056 and explain the result.


account_number = "ACC-1056"
withdraw = -1000

try:
  if withdraw < 0:
    raise ValueError("Invalid Withdraw amount")
except ValueError as e:
  print("Account number:",account_number)
  print("Status:","Failed")
  print("Error Message:",e)
# Out:
# Account number: ACC-1056
# Status: Failed
# Error Message: Invalid Withdraw amount

# %%
#Q57. Validate a nested beneficiary record for banking case 3; use sample reference ACC-1057 and explain the result.


account_number = "Acc-1057"
beneficiary = {"Name":"Yuvateja",
                   "Account_Type":"Savings",
                   "Account_Details":{}
                   }

try:
  if not beneficiary["Account_Details"]:
    raise KeyError("Beneficiary Account Details Missing")

except KeyError as e:
  print("Account Number:",account_number)
  print(e)
# Out:
# Account Number: Acc-1057
# 'Beneficiary Account Details Missing'

# %%
#Q58. Use a context manager for an audit file for banking case 3; use sample reference ACC-1058 and explain the result.


account_number = "Acc-1058"

try:
  with open("audit.txt","w") as file:
    file.write("Account Number:" + account_number)
    file.write("\nAudit Completed")
  print("Audit File Updated Successfully")
except Exception as e:
  print("Error:",e)
# Out:
# Audit File Updated Successfully

# %%
#Q59. Separate validation and recovery for banking case 3; use sample reference ACC-1059 and explain the result.


account_number = "Acc-1059"
withdraw_amount = -500

try:
  if withdraw_amount < 0:
    raise ValueError("Invalid Withdraw amount")

except ValueError as e:
  print("Account Number:",account_number)
  print(e)

  withdraw_amount = 0
  print("Recovery Withdraw amount set to ",withdraw_amount)
# Out:
# Account Number: Acc-1059
# Invalid Withdraw amount
# Recovery Withdraw amount set to  0

# %%
#Q60. Collect all kyc validation errors for banking case 3; use sample reference ACC-1060 and explain the result.


account_number = "Acc-1060"
KYC_Details = {"Name":"","PAN":"","DOB":"","Aadhar":""}
errors = []

try:
  for key,value in KYC_Details.items():
    if not value:
      errors.append(f"{key} value Missing in KYC Details")
  if errors:
    raise ValueError("\n".join(errors))

except ValueError as e:
  print("Account Number:",account_number)
  print("KYC Validation Errors:")
  print(e)
# Out:
# Account Number: Acc-1060
# KYC Validation Errors:
# Name value Missing in KYC Details
# PAN value Missing in KYC Details
# DOB value Missing in KYC Details
# Aadhar value Missing in KYC Details

# %%
#Q61. Create insufficientfundserror for banking case 4; use sample reference ACC-1061 and explain the result.


class InsufficientFundsError(Exception):
  pass
account_number = "ACC-1061"
Balance_amount = 1500
Withdraw_amount = 50000

try:
  if Withdraw_amount > Balance_amount:
    raise InsufficientFundsError('Insufficient Funds')

  Balance_amount -= Withdraw_amount
  print("Remaining Balance:",Balance_amount)

except InsufficientFundsError as e:
  print("Account Balance:",Balance_amount)
  print(e)
# Out:
# Account Balance: 1500
# Insufficient Funds

# %%
#Q62. Chain invalidtransactionerror from valueerror for banking case 4; use sample reference ACC-1062 and explain the result.


class InvalidTransactionError(Exception):
  pass
Account_number = "ACC-1062"
Amount = "YUVA"
try:
  try:
    int(Amount)
  except ValueError as e:
    raise InvalidTransactionError("Invalid Transaction") from e
except InvalidTransactionError as e:
  print('Account Number:',Account_number)
  print(e)
# Out:
# Account Number: ACC-1062
# Invalid Transaction

# %%
#Q63. Process transfers while isolating bad rows for banking case 4; use sample reference ACC-1063 and explain the result.


account_number = "Acc-1063"
transfers = [1000,"Yuva",800,"Teja"]

print("Account Number:",account_number)

for i in transfers:
  try:
    i = int(i)
    print("Transfer Processed:",i)
  except ValueError:
    print("Bad Row:",i)
# Out:
# Account Number: Acc-1063
# Transfer Processed: 1000
# Bad Row: Yuva
# Transfer Processed: 800
# Bad Row: Teja

# %%
#Q64. Retry a transient payment gateway for banking case 4; use sample reference ACC-1064 and explain the result.


account_number = "Acc-1064"

for attempt in range(3):
  try:
    if attempt < 2:
      raise ConnectionError("Bad transient payment gateway - Try again")

    print("Payment Successfully ")
    break

  except ConnectionError as e:
    print("Attempt",attempt+1, "-" ,e)
# Out:
# Attempt 1 - Bad transient payment gateway - Try again
# Attempt 2 - Bad transient payment gateway - Try again
# Payment Successfully

# %%
#Q65. Log failed standing instructions for banking case 4; use sample reference ACC-1065 and explain the result.


account_number = "Acc-1065"

try:
  raise Exception("Standing instructions Failed")
except Exception as e:
  print("Account Number:",account_number)
  print(e)
# Out:
# Account Number: Acc-1065
# Standing instructions Failed

# %%
#Q66. Return a structured failure result for banking case 4; use sample reference ACC-1066 and explain the result.


account_number = "ACC-1066"
withdraw = -1000

try:
  if withdraw < 0:
    raise ValueError("Invalid Withdraw amount")
except ValueError as e:
  print("Account number:",account_number)
  print("Status:","Failed")
  print("Error Message:",e)
# Out:
# Account number: ACC-1066
# Status: Failed
# Error Message: Invalid Withdraw amount

# %%
#Q67. Validate a nested beneficiary record for banking case 4; use sample reference ACC-1067 and explain the result.


account_number = "Acc-1067"
beneficiary = {"Name":"Yuvateja",
                   "Account_Type":"Savings",
                   "Account_Details":{}
                   }

try:
  if not beneficiary["Account_Details"]:
    raise KeyError("Beneficiary Account Details Missing")

except KeyError as e:
  print("Account Number:",account_number)
  print(e)
# Out:
# Account Number: Acc-1067
# 'Beneficiary Account Details Missing'

# %%
#Q68. Use a context manager for an audit file for banking case 4; use sample reference ACC-1068 and explain the result.


account_number = "Acc-1068"

try:
  with open("audit.txt","w") as file:
    file.write("Account Number:" + account_number)
    file.write("\nAudit Completed")
  print("Audit File Updated Successfully")
except Exception as e:
  print("Error:",e)
# Out:
# Audit File Updated Successfully

# %%
#Q69. Separate validation and recovery for banking case 4; use sample reference ACC-1069 and explain the result.


account_number = "Acc-1069"
withdraw_amount = -500

try:
  if withdraw_amount < 0:
    raise ValueError("Invalid Withdraw amount")

except ValueError as e:
  print("Account Number:",account_number)
  print(e)

  withdraw_amount = 0
  print("Recovery Withdraw amount set to ",withdraw_amount)
# Out:
# Account Number: Acc-1069
# Invalid Withdraw amount
# Recovery Withdraw amount set to  0

# %%
#Q70. Collect all kyc validation errors for banking case 4; use sample reference ACC-1070 and explain the result.


account_number = "Acc-1070"
KYC_Details = {"Name":"","PAN":"","DOB":"","Aadhar":""}
errors = []

try:
  for key,value in KYC_Details.items():
    if not value:
      errors.append(f"{key} value Missing in KYC Details")
  if errors:
    raise ValueError("\n".join(errors))

except ValueError as e:
  print("Account Number:",account_number)
  print("KYC Validation Errors:")
  print(e)
# Out:
# Account Number: Acc-1070
# KYC Validation Errors:
# Name value Missing in KYC Details
# PAN value Missing in KYC Details
# DOB value Missing in KYC Details
# Aadhar value Missing in KYC Details

# %%
#Q71. Design a banking exception hierarchy for banking case 1; use sample reference ACC-1071 and explain the result.


class BankingErrors(Exception):   # parent
  pass
class InvalidFundError(BankingErrors): # child
  pass
class InvalidAccountError(BankingErrors): # child
  pass

Account_number = "Acc-1071"
balance_amount = 100000
withdraw_amount = 50000
Account_status = "Inactive"

try:
  if withdraw_amount > balance_amount:
    raise InvalidFundError("Insufficient funds")
  balance_amount -= withdraw_amount
  print("Withdraw Successful",balance_amount)

  if Account_status == "Inactive":
    raise InvalidAccountError("Account status is not Active")
  print("Account status is active")

except BankingErrors as e:
  print("Account Number:",Account_number)
  print(e)
# Out:
# Withdraw Successful 50000
# Account Number: Acc-1071
# Account status is not Active

# %%
#Q72. Make a transfer rollback-safe for banking case 1; use sample reference ACC-1072 and explain the result.


Account_number = "Acc-1072"

sender_balance = 10000
receiver_balance = 2900
transfer_amount = 30000

original_sender_balance = sender_balance
original_receiver_balance = receiver_balance

try:
  if transfer_amount > sender_balance:
    raise ValueError("Insufficient Fund")

    sender_balance -= transfer_amount
    receiver_balance += transfer_amount
  print("Transction Successful")

except Exception as e:
  sender_balance = original_sender_balance
  receiver_balance = original_receiver_balance

  print("Account Number:", Account_number)
  print("Transcation Failed:",e)
  print("Transcation Rolled Back")

print("After transction Sender Balance",sender_balance)
print("After Transction Receiver Balance",receiver_balance)
# Out:
# Account Number: Acc-1072
# Transcation Failed: Insufficient Fund
# Transcation Rolled Back
# After transction Sender Balance 10000
# After Transction Receiver Balance 2900

# %%
#Q73. Preserve causes across service layers for banking case 1; use sample reference ACC-1073 and explain the result.


account_number = "Acc-1073"

try:
  try:
    balance = "YUVA"
    balance = int(balance) # throws value error

  except ValueError as e:
    raise Exception("Service Layer Issue") from e

except Exception as e:
  print("Account Number:",account_number)
  print("Error - ",e)
  print("Original Error - ",e.__cause__)
# Out:
# Account Number: Acc-1073
# Error -  Service Layer Issue
# Original Error -  invalid literal for int() with base 10: 'YUVA'

# %%
#Q74. Implement bounded exponential retry for banking case 1; use sample reference ACC-1074 and explain the result.


import time
account_number = "Acc-1074"
max_tries = 6

for attempt in range(max_tries):
  try:
    if attempt < 2:
      raise ConnectionError("payment gateway Not Available")
    print("Account Number",account_number)
    print("Trasnction Completed")
    break
  except ConnectionError as e:
    print("Attempt",attempt+1,"Failed:",e)

    if attempt < max_tries -1:
      wait_time = 2 ** attempt
      print("Retrying in",wait_time,"Seconds....")
      time.sleep(wait_time)
    else:
      print("Transaction Failed After Maximum Retries")
# Out:
# Attempt 1 Failed: payment gateway Not Available
# Retrying in 1 Seconds....
# Attempt 2 Failed: payment gateway Not Available
# Retrying in 2 Seconds....
# Account Number Acc-1074
# Trasnction Completed

# %%
#Q75. Create a transaction context manager for banking case 1; use sample reference ACC-1075 and explain the result.


account_Number = "Acc-1075"
class Transction:

  def __enter__(self):
    print("Transaction Started")
    return self
  def __exit__(self,exc_type,exc_value,traceback):

    if exc_type:
      print("Transction Rolled back")
      print("Error:",exc_value)
    else:
      print("Trasnction Committed")

    print("Transction Closed")
    return True

try:
  with Transction():
    withdraw_amount = 500

    if withdraw_amount > 3000:
      raise ValueError("Withdrawal Limit Exceeded")
    print("Account Number:",account_number)
except Exception as e:
  print(e)
# Out:
# Transaction Started
# Account Number: Acc-1074
# Trasnction Committed
# Transction Closed

# %%
#Q76. Build a dead-letter queue for payment events for banking case 1; use sample reference ACC-1076 and explain the result.


account_number = "Acc-1076"

Payment_details = [{"ID":"BNGLR123","Amount":500},{"ID":"BNGLR456","Amount":-900}]

Dead_letter_que = []

for payment in Payment_details:
  try:
    if payment["Amount"] <= 0:
      raise ValueError("Invalid payment Amount")

    print("Payment Process:",payment["ID"])

  except ValueError as e:
    print("Payment Failed:",payment["ID"])

    Dead_letter_que.append({"Account_number":account_number,
                            "ID":payment["ID"],
                            "Error": e})
print("\nDead letter Que:")
print()
print(Dead_letter_que)
# Out:
# Payment Process: BNGLR123
# Payment Failed: BNGLR456
#
# Dead letter Que:
#
# [{'Account_number': 'Acc-1076', 'ID': 'BNGLR456', 'Error': ValueError('Invalid payment Amount')}]

# %%
#Q77. Make batch settlement failure-isolated for banking case 1; use sample reference ACC-1077 and explain the result.


Account_number = "Acc-1077"

settlement_amount = [1000,2000,-900,500,9000,-9000]

failed_settlements = []

for amount in settlement_amount:
  try:
    if amount <= 0:
      raise ValueError("Invalid Settlement Amount")
    print("\nSettlement Successful")
    print("Account Number:",Account_number)
    print("Amount:",amount)
  except ValueError as e:
    print("\nFailed Settlements")
    print("Account Number:",Account_number)
    print("Amound Failed",amount)
    print("Error:",e)

    failed_settlements.append(amount)

print("\nFailed Settlements",failed_settlements)
# Out:
# Settlement Successful
# Account Number: Acc-1077
# Amount: 1000
#
# Settlement Successful
# Account Number: Acc-1077
# Amount: 2000
#
# Failed Settlements
# Account Number: Acc-1077
# Amound Failed -900
# Error: Invalid Settlement Amount
#
# Settlement Successful
# Account Number: Acc-1077
# Amount: 500
#
# Settlement Successful
# Account Number: Acc-1077
# Amount: 9000
#
# Failed Settlements
# Account Number: Acc-1077
# Amound Failed -9000
# Error: Invalid Settlement Amount
#
# Failed Settlements [-900, -9000]

# %%
#Q78. Report exact paths in nested statements for banking case 1; use sample reference ACC-1078 and explain the result.


account_number = "ACC-1078"

customer = {"Customer":{"KYC":{"PAN":"","Aadhar":""}}}
Errors = []

try:

    for key, value in customer["Customer"]["KYC"].items():

        if not value:
          Errors.append(f"Customer.KYC.{key} is Missing")

    if Errors:
      raise ValueError("\n".join(Errors))


    print("Account Number:", account_number)
    print("All details fetched")

except ValueError as e:
    print("Account Number :", account_number)
    print("Errors:")
    print(e)
# Out:
# Account Number : ACC-1078
# Errors:
# Customer.KYC.PAN is Missing
# Customer.KYC.Aadhar is Missing

# %%
#Q79. Design idempotent recovery after timeout for banking case 1; use sample reference ACC-1079 and explain the result.


account_number = "ACC-1079"

processed_transactions = []

transaction_id = "BNGLR123"

try:

    if transaction_id in processed_transactions:
        print("Transaction Already Processed")

    else:

        raise TimeoutError("Transaction Timed Out")

except TimeoutError as e:

    print("Account Number :", account_number)
    print("Transaction ID :", transaction_id)
    print("Error :", e)

    print("\nRecovering Transaction...")

    if transaction_id not in processed_transactions:

        processed_transactions.append(transaction_id)

        print("Transaction Processed Successfully")

print("\nProcessed Transactions :", processed_transactions)
# Out:
# Account Number : ACC-1079
# Transaction ID : BNGLR123
# Error : Transaction Timed Out
#
# Recovering Transaction...
# Transaction Processed Successfully
#
# Processed Transactions : ['BNGLR123']

# %%
#Q80. Build an exception-safe reconciliation pipeline for banking case 1; use sample reference ACC-1080 and explain the result.


account_number = "ACC-1080"

transactions = [
    {"Transaction_ID": "BNG1001", "Bank_Amount": 5000, "Gateway_Amount": 5000},
    {"Transaction_ID": "BNG1002", "Bank_Amount": 3000, "Gateway_Amount": 2500},
    {"Transaction_ID": "BNG1003", "Bank_Amount": 7000, "Gateway_Amount": 7000}
]

failed_reconciliations = []

for transaction in transactions:

    try:

        if transaction["Bank_Amount"] != transaction["Gateway_Amount"]:
            raise ValueError("Amount Mismatch")

        print("\nReconciliation Successful")
        print("Account Number :", account_number)
        print("Transaction ID :", transaction["Transaction_ID"])

    except ValueError as e:

        print("\nReconciliation Failed")
        print("Account Number :", account_number)
        print("Transaction ID :", transaction["Transaction_ID"])
        print("Error :", e)

        failed_reconciliations.append(transaction["Transaction_ID"])

print("\nFailed Reconciliations :", failed_reconciliations)
# Out:
# Reconciliation Successful
# Account Number : ACC-1080
# Transaction ID : BNG1001
#
# Reconciliation Failed
# Account Number : ACC-1080
# Transaction ID : BNG1002
# Error : Amount Mismatch
#
# Reconciliation Successful
# Account Number : ACC-1080
# Transaction ID : BNG1003
#
# Failed Reconciliations : ['BNG1002']

# %%
#Q81. Design a banking exception hierarchy for banking case 2; use sample reference ACC-1081 and explain the result.


class BankingErrors(Exception):   # parent
  pass
class InvalidFundError(BankingErrors): # child
  pass
class InvalidAccountError(BankingErrors): # child
  pass

Account_number = "Acc-1081"
balance_amount = 100000
withdraw_amount = 50000
Account_status = "Inactive"

try:
  if withdraw_amount > balance_amount:
    raise InvalidFundError("Insufficient funds")
  balance_amount -= withdraw_amount
  print("Withdraw Successful",balance_amount)

  if Account_status == "Inactive":
    raise InvalidAccountError("Account status is not Active")
  print("Account status is active")

except BankingErrors as e:
  print("Account Number:",Account_number)
  print(e)
# Out:
# Withdraw Successful 50000
# Account Number: Acc-1081
# Account status is not Active

# %%
#Q82. Make a transfer rollback-safe for banking case 2; use sample reference ACC-1082 and explain the result.


Account_number = "Acc-1082"

sender_balance = 10000
receiver_balance = 2900
transfer_amount = 30000

original_sender_balance = sender_balance
original_receiver_balance = receiver_balance

try:
  if transfer_amount > sender_balance:
    raise ValueError("Insufficient Fund")

    sender_balance -= transfer_amount
    receiver_balance += transfer_amount
  print("Transction Successful")

except Exception as e:
  sender_balance = original_sender_balance
  receiver_balance = original_receiver_balance

  print("Account Number:", Account_number)
  print("Transcation Failed:",e)
  print("Transcation Rolled Back")

print("After transction Sender Balance",sender_balance)
print("After Transction Receiver Balance",receiver_balance)
# Out:
# Account Number: Acc-1082
# Transcation Failed: Insufficient Fund
# Transcation Rolled Back
# After transction Sender Balance 10000
# After Transction Receiver Balance 2900

# %%
#Q83. Preserve causes across service layers for banking case 2; use sample reference ACC-1083 and explain the result.


account_number = "Acc-1083"

try:
  try:
    balance = "YUVA"
    balance = int(balance) # throws value error

  except ValueError as e:
    raise Exception("Service Layer Issue") from e

except Exception as e:
  print("Account Number:",account_number)
  print("Error - ",e)
  print("Original Error - ",e.__cause__)
# Out:
# Account Number: Acc-1083
# Error -  Service Layer Issue
# Original Error -  invalid literal for int() with base 10: 'YUVA'

# %%
#Q84. Implement bounded exponential retry for banking case 2; use sample reference ACC-1084 and explain the result.


import time
account_number = "Acc-1084"
max_tries = 6

for attempt in range(max_tries):
  try:
    if attempt < 2:
      raise ConnectionError("payment gateway Not Available")
    print("Account Number",account_number)
    print("Trasnction Completed")
    break
  except ConnectionError as e:
    print("Attempt",attempt+1,"Failed:",e)

    if attempt < max_tries -1:
      wait_time = 2 ** attempt
      print("Retrying in",wait_time,"Seconds....")
      time.sleep(wait_time)
    else:
      print("Transaction Failed After Maximum Retries")
# Out:
# Attempt 1 Failed: payment gateway Not Available
# Retrying in 1 Seconds....
# Attempt 2 Failed: payment gateway Not Available
# Retrying in 2 Seconds....
# Account Number Acc-1084
# Trasnction Completed

# %%
#Q85. Create a transaction context manager for banking case 2; use sample reference ACC-1085 and explain the result.


account_Number = "Acc-1085"
class Transction:

  def __enter__(self):
    print("Transaction Started")
    return self
  def __exit__(self,exc_type,exc_value,traceback):

    if exc_type:
      print("Transction Rolled back")
      print("Error:",exc_value)
    else:
      print("Trasnction Committed")

    print("Transction Closed")
    return True

try:
  with Transction():
    withdraw_amount = 500

    if withdraw_amount > 3000:
      raise ValueError("Withdrawal Limit Exceeded")
    print("Account Number:",account_number)
except Exception as e:
  print(e)
# Out:
# Transaction Started
# Account Number: Acc-1084
# Trasnction Committed
# Transction Closed

# %%
#Q86. Build a dead-letter queue for payment events for banking case 2; use sample reference ACC-1086 and explain the result.


account_number = "Acc-1086"

Payment_details = [{"ID":"BNGLR123","Amount":500},{"ID":"BNGLR456","Amount":-900}]

Dead_letter_que = []

for payment in Payment_details:
  try:
    if payment["Amount"] <= 0:
      raise ValueError("Invalid payment Amount")

    print("Payment Process:",payment["ID"])

  except ValueError as e:
    print("Payment Failed:",payment["ID"])

    Dead_letter_que.append({"Account_number":account_number,
                            "ID":payment["ID"],
                            "Error": e})
print("\nDead letter Que:")
print()
print(Dead_letter_que)
# Out:
# Payment Process: BNGLR123
# Payment Failed: BNGLR456
#
# Dead letter Que:
#
# [{'Account_number': 'Acc-1086', 'ID': 'BNGLR456', 'Error': ValueError('Invalid payment Amount')}]

# %%
#Q87. Make batch settlement failure-isolated for banking case 2; use sample reference ACC-1087 and explain the result.


Account_number = "Acc-1087"

settlement_amount = [1000,2000,-900,500,9000,-9000]

failed_settlements = []

for amount in settlement_amount:
  try:
    if amount <= 0:
      raise ValueError("Invalid Settlement Amount")
    print("\nSettlement Successful")
    print("Account Number:",Account_number)
    print("Amount:",amount)
  except ValueError as e:
    print("\nFailed Settlements")
    print("Account Number:",Account_number)
    print("Amound Failed",amount)
    print("Error:",e)

    failed_settlements.append(amount)

print("\nFailed Settlements",failed_settlements)
# Out:
# Settlement Successful
# Account Number: Acc-1087
# Amount: 1000
#
# Settlement Successful
# Account Number: Acc-1087
# Amount: 2000
#
# Failed Settlements
# Account Number: Acc-1087
# Amound Failed -900
# Error: Invalid Settlement Amount
#
# Settlement Successful
# Account Number: Acc-1087
# Amount: 500
#
# Settlement Successful
# Account Number: Acc-1087
# Amount: 9000
#
# Failed Settlements
# Account Number: Acc-1087
# Amound Failed -9000
# Error: Invalid Settlement Amount
#
# Failed Settlements [-900, -9000]

# %%
#Q88. Report exact paths in nested statements for banking case 2; use sample reference ACC-1088 and explain the result.


account_number = "ACC-1088"

customer = {"Customer":{"KYC":{"PAN":"","Aadhar":""}}}
Errors = []

try:

    for key, value in customer["Customer"]["KYC"].items():

        if not value:
          Errors.append(f"Customer.KYC.{key} is Missing")

    if Errors:
      raise ValueError("\n".join(Errors))


    print("Account Number:", account_number)
    print("All details fetched")

except ValueError as e:
    print("Account Number :", account_number)
    print("Errors:")
    print(e)
# Out:
# Account Number : ACC-1088
# Errors:
# Customer.KYC.PAN is Missing
# Customer.KYC.Aadhar is Missing

# %%
#Q89. Design idempotent recovery after timeout for banking case 2; use sample reference ACC-1089 and explain the result.


account_number = "ACC-1089"

processed_transactions = []

transaction_id = "BNGLR123"

try:

    if transaction_id in processed_transactions:
        print("Transaction Already Processed")

    else:

        raise TimeoutError("Transaction Timed Out")

except TimeoutError as e:

    print("Account Number :", account_number)
    print("Transaction ID :", transaction_id)
    print("Error :", e)

    print("\nRecovering Transaction...")

    if transaction_id not in processed_transactions:

        processed_transactions.append(transaction_id)

        print("Transaction Processed Successfully")

print("\nProcessed Transactions :", processed_transactions)
# Out:
# Account Number : ACC-1089
# Transaction ID : BNGLR123
# Error : Transaction Timed Out
#
# Recovering Transaction...
# Transaction Processed Successfully
#
# Processed Transactions : ['BNGLR123']

# %%
#Q90. Build an exception-safe reconciliation pipeline for banking case 2; use sample reference ACC-1090 and explain the result.


account_number = "ACC-1090"

transactions = [
    {"Transaction_ID": "BNG1001", "Bank_Amount": 5000, "Gateway_Amount": 5000},
    {"Transaction_ID": "BNG1002", "Bank_Amount": 3000, "Gateway_Amount": 2500},
    {"Transaction_ID": "BNG1003", "Bank_Amount": 7000, "Gateway_Amount": 7000}
]

failed_reconciliations = []

for transaction in transactions:

    try:

        if transaction["Bank_Amount"] != transaction["Gateway_Amount"]:
            raise ValueError("Amount Mismatch")

        print("\nReconciliation Successful")
        print("Account Number :", account_number)
        print("Transaction ID :", transaction["Transaction_ID"])

    except ValueError as e:

        print("\nReconciliation Failed")
        print("Account Number :", account_number)
        print("Transaction ID :", transaction["Transaction_ID"])
        print("Error :", e)

        failed_reconciliations.append(transaction["Transaction_ID"])

print("\nFailed Reconciliations :", failed_reconciliations)
# Out:
# Reconciliation Successful
# Account Number : ACC-1090
# Transaction ID : BNG1001
#
# Reconciliation Failed
# Account Number : ACC-1090
# Transaction ID : BNG1002
# Error : Amount Mismatch
#
# Reconciliation Successful
# Account Number : ACC-1090
# Transaction ID : BNG1003
#
# Failed Reconciliations : ['BNG1002']

# %%
#Q91. Design a banking exception hierarchy for banking case 3; use sample reference ACC-1091 and explain the result.


class BankingErrors(Exception):   # parent
  pass
class InvalidFundError(BankingErrors): # child
  pass
class InvalidAccountError(BankingErrors): # child
  pass

Account_number = "Acc-1091"
balance_amount = 100000
withdraw_amount = 50000
Account_status = "Inactive"

try:
  if withdraw_amount > balance_amount:
    raise InvalidFundError("Insufficient funds")
  balance_amount -= withdraw_amount
  print("Withdraw Successful",balance_amount)

  if Account_status == "Inactive":
    raise InvalidAccountError("Account status is not Active")
  print("Account status is active")

except BankingErrors as e:
  print("Account Number:",Account_number)
  print(e)
# Out:
# Withdraw Successful 50000
# Account Number: Acc-1091
# Account status is not Active

# %%
#Q92. Make a transfer rollback-safe for banking case 3; use sample reference ACC-1092 and explain the result.


Account_number = "Acc-1092"

sender_balance = 10000
receiver_balance = 2900
transfer_amount = 30000

original_sender_balance = sender_balance
original_receiver_balance = receiver_balance

try:
  if transfer_amount > sender_balance:
    raise ValueError("Insufficient Fund")

    sender_balance -= transfer_amount
    receiver_balance += transfer_amount
  print("Transction Successful")

except Exception as e:
  sender_balance = original_sender_balance
  receiver_balance = original_receiver_balance

  print("Account Number:", Account_number)
  print("Transcation Failed:",e)
  print("Transcation Rolled Back")

print("After transction Sender Balance",sender_balance)
print("After Transction Receiver Balance",receiver_balance)
# Out:
# Account Number: Acc-1092
# Transcation Failed: Insufficient Fund
# Transcation Rolled Back
# After transction Sender Balance 10000
# After Transction Receiver Balance 2900

# %%
#Q93. Preserve causes across service layers for banking case 3; use sample reference ACC-1093 and explain the result.


account_number = "Acc-1093"

try:
  try:
    balance = "YUVA"
    balance = int(balance) # throws value error

  except ValueError as e:
    raise Exception("Service Layer Issue") from e

except Exception as e:
  print("Account Number:",account_number)
  print("Error - ",e)
  print("Original Error - ",e.__cause__)
# Out:
# Account Number: Acc-1093
# Error -  Service Layer Issue
# Original Error -  invalid literal for int() with base 10: 'YUVA'

# %%
#Q94. Implement bounded exponential retry for banking case 3; use sample reference ACC-1094 and explain the result.


import time
account_number = "Acc-1094"
max_tries = 6

for attempt in range(max_tries):
  try:
    if attempt < 2:
      raise ConnectionError("payment gateway Not Available")
    print("Account Number",account_number)
    print("Trasnction Completed")
    break
  except ConnectionError as e:
    print("Attempt",attempt+1,"Failed:",e)

    if attempt < max_tries -1:
      wait_time = 2 ** attempt
      print("Retrying in",wait_time,"Seconds....")
      time.sleep(wait_time)
    else:
      print("Transaction Failed After Maximum Retries")
# Out:
# Attempt 1 Failed: payment gateway Not Available
# Retrying in 1 Seconds....
# Attempt 2 Failed: payment gateway Not Available
# Retrying in 2 Seconds....
# Account Number Acc-1094
# Trasnction Completed

# %%
#Q95. Create a transaction context manager for banking case 3; use sample reference ACC-1095 and explain the result.


account_Number = "Acc-1095"
class Transction:

  def __enter__(self):
    print("Transaction Started")
    return self
  def __exit__(self,exc_type,exc_value,traceback):

    if exc_type:
      print("Transction Rolled back")
      print("Error:",exc_value)
    else:
      print("Trasnction Committed")

    print("Transction Closed")
    return True

try:
  with Transction():
    withdraw_amount = 500

    if withdraw_amount > 3000:
      raise ValueError("Withdrawal Limit Exceeded")
    print("Account Number:",account_number)
except Exception as e:
  print(e)
# Out:
# Transaction Started
# Account Number: Acc-1094
# Trasnction Committed
# Transction Closed

# %%
#Q96. Build a dead-letter queue for payment events for banking case 3; use sample reference ACC-1096 and explain the result.


account_number = "Acc-1096"

Payment_details = [{"ID":"BNGLR123","Amount":500},{"ID":"BNGLR456","Amount":-900}]

Dead_letter_que = []

for payment in Payment_details:
  try:
    if payment["Amount"] <= 0:
      raise ValueError("Invalid payment Amount")

    print("Payment Process:",payment["ID"])

  except ValueError as e:
    print("Payment Failed:",payment["ID"])

    Dead_letter_que.append({"Account_number":account_number,
                            "ID":payment["ID"],
                            "Error": e})
print("\nDead letter Que:")
print()
print(Dead_letter_que)
# Out:
# Payment Process: BNGLR123
# Payment Failed: BNGLR456
#
# Dead letter Que:
#
# [{'Account_number': 'Acc-1096', 'ID': 'BNGLR456', 'Error': ValueError('Invalid payment Amount')}]

# %%
#Q97. Make batch settlement failure-isolated for banking case 3; use sample reference ACC-1097 and explain the result.


Account_number = "Acc-1097"

settlement_amount = [1000,2000,-900,500,9000,-9000]

failed_settlements = []

for amount in settlement_amount:
  try:
    if amount <= 0:
      raise ValueError("Invalid Settlement Amount")
    print("\nSettlement Successful")
    print("Account Number:",Account_number)
    print("Amount:",amount)
  except ValueError as e:
    print("\nFailed Settlements")
    print("Account Number:",Account_number)
    print("Amound Failed",amount)
    print("Error:",e)

    failed_settlements.append(amount)

print("\nFailed Settlements",failed_settlements)
# Out:
# Settlement Successful
# Account Number: Acc-1097
# Amount: 1000
#
# Settlement Successful
# Account Number: Acc-1097
# Amount: 2000
#
# Failed Settlements
# Account Number: Acc-1097
# Amound Failed -900
# Error: Invalid Settlement Amount
#
# Settlement Successful
# Account Number: Acc-1097
# Amount: 500
#
# Settlement Successful
# Account Number: Acc-1097
# Amount: 9000
#
# Failed Settlements
# Account Number: Acc-1097
# Amound Failed -9000
# Error: Invalid Settlement Amount
#
# Failed Settlements [-900, -9000]

# %%
#Q98. Report exact paths in nested statements for banking case 3; use sample reference ACC-1098 and explain the result.


account_number = "ACC-1098"

customer = {"Customer":{"KYC":{"PAN":"","Aadhar":""}}}
Errors = []

try:

    for key, value in customer["Customer"]["KYC"].items():

        if not value:
          Errors.append(f"Customer.KYC.{key} is Missing")

    if Errors:
      raise ValueError("\n".join(Errors))


    print("Account Number:", account_number)
    print("All details fetched")

except ValueError as e:
    print("Account Number :", account_number)
    print("Errors:")
    print(e)
# Out:
# Account Number : ACC-1098
# Errors:
# Customer.KYC.PAN is Missing
# Customer.KYC.Aadhar is Missing

# %%
#Q99. Design idempotent recovery after timeout for banking case 3; use sample reference ACC-1099 and explain the result.


account_number = "ACC-1099"

processed_transactions = []

transaction_id = "BNGLR123"

try:

    if transaction_id in processed_transactions:
        print("Transaction Already Processed")

    else:

        raise TimeoutError("Transaction Timed Out")

except TimeoutError as e:

    print("Account Number :", account_number)
    print("Transaction ID :", transaction_id)
    print("Error :", e)

    print("\nRecovering Transaction...")

    if transaction_id not in processed_transactions:

        processed_transactions.append(transaction_id)

        print("Transaction Processed Successfully")

print("\nProcessed Transactions :", processed_transactions)
# Out:
# Account Number : ACC-1099
# Transaction ID : BNGLR123
# Error : Transaction Timed Out
#
# Recovering Transaction...
# Transaction Processed Successfully
#
# Processed Transactions : ['BNGLR123']

# %%
#Q100. Build an exception-safe reconciliation pipeline for banking case 3; use sample reference ACC-1100 and explain the result.


account_number = "ACC-1100"

transactions = [
    {"Transaction_ID": "BNG1001", "Bank_Amount": 5000, "Gateway_Amount": 5000},
    {"Transaction_ID": "BNG1002", "Bank_Amount": 3000, "Gateway_Amount": 2500},
    {"Transaction_ID": "BNG1003", "Bank_Amount": 7000, "Gateway_Amount": 7000}
]

failed_reconciliations = []

for transaction in transactions:

    try:

        if transaction["Bank_Amount"] != transaction["Gateway_Amount"]:
            raise ValueError("Amount Mismatch")

        print("\nReconciliation Successful")
        print("Account Number :", account_number)
        print("Transaction ID :", transaction["Transaction_ID"])

    except ValueError as e:

        print("\nReconciliation Failed")
        print("Account Number :", account_number)
        print("Transaction ID :", transaction["Transaction_ID"])
        print("Error :", e)

        failed_reconciliations.append(transaction["Transaction_ID"])

print("\nFailed Reconciliations :", failed_reconciliations)
# Out:
# Reconciliation Successful
# Account Number : ACC-1100
# Transaction ID : BNG1001
#
# Reconciliation Failed
# Account Number : ACC-1100
# Transaction ID : BNG1002
# Error : Amount Mismatch
#
# Reconciliation Successful
# Account Number : ACC-1100
# Transaction ID : BNG1003
#
# Failed Reconciliations : ['BNG1002']
