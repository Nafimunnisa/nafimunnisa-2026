# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafimunnisa/nafimunnisa-2026/blob/main/Banking_03_Regular_Expressions_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Banking Assignment — Regular Expressions (100 Questions with Hints)

# %%
#Q1. Find a account code for banking case 1; use sample reference ACC-1001 and explain the result.


import re

account_number = ["ACC-1001","ABC-1001","ACC1001","ACC-9876"]

pattern = r"^ACC-\d{4}$"

Vaild_Account_Numbers = [i for i in account_number if re.match(pattern,i)]
print("Valid Account Numbers:",Vaild_Account_Numbers)
# Out:
# Valid Account Numbers: ['ACC-1001', 'ACC-9876']

# %%
#Q2. Validate a six-digit pin for banking case 1; use sample reference ACC-1002 and explain the result.


import re

Account_number = "ACC-1002"
pin = "123456"

pattern = r"^\d{6}$"

if re.match(pattern,pin):
  print("Account Number:",Account_number)
  print("pin:",pin)
  print("Vaild Pin")
else:
  print("Account Number:",Account_number)
  print("pin:",pin)
  print("Not Vaild pin")
# Out:
# Account Number: ACC-1002
# pin: 123456
# Vaild Pin

# %%
#Q3. Extract all amounts for banking case 1; use sample reference ACC-1003 and explain the result.


import re

Account_number = "ACC-1003"
text = "Nafim Deposited 20000 in the account,charges applied is 34.897 and he trasnferred 4000 to her friend"

pattern = r"\d+\d.\d+"
extract = re.findall(pattern,text)
print(extract)
# Out:
# ['20000', '34.897', '4000']

# %%
#Q4. Match a receipt date for banking case 1; use sample reference ACC-1004 and explain the result.


import re

Account_Number = "Acc-1004"

Receipt_Details = """ Nafim Account is created on 09/09/2026
                       and it got activated on 10-09-2026. """

pattern = r"\d{2}/\d{2}/\d{4}|\d{2}-\d{2}-\d{4}"

receipt_date = re.findall(pattern,Receipt_Details)
print("Dates as per the Receipt Details:",receipt_date)
# Out:
# Dates as per the Receipt Details: ['09/09/2026', '10-09-2026']

# %%
#Q5. Find uppercase account references for banking case 1; use sample reference ACC-1005 and explain the result.


import re

Account_numbers = " ACC-1005 ABC-1004 ACC-1003 Acc-1002 acc-1001 "

pattern = r"ACC-\d{4}"

upper_case = re.findall(pattern,Account_numbers)
print("Account Numbers:",Account_numbers)
print(upper_case)
# Out:
# Account Numbers:  ACC-1005 ABC-1004 ACC-1003 Acc-1002 acc-1001
# ['ACC-1005', 'ACC-1003']

# %%
#Q6. Remove extra spaces for banking case 1; use sample reference ACC-1006 and explain the result.


import re

Account_number = "ACC-1006"

text = "Nafim's Account is created on 09/09/2026 and it got activated on  10-09-2026"

clean_text = re.sub(r"\s+"," ",text)
print("Account Number:",Account_number)
print("Before clean:",text)
print("After clean:",clean_text)
# Out:
# Account Number: ACC-1006
# Before clean: Nafim's Account is created on 09/09/2026 and it got activated on  10-09-2026
# After clean: Nafim's Account is created on 09/09/2026 and it got activated on 10-09-2026

# %%
#Q7. Split a comma-separated tag list for banking case 1; use sample reference ACC-1007 and explain the result.


import re

Account_number = "ACC-1007"

text = "Nafim deposited amount of 10000,Transferred 2000 to friend via online banking,withdrawn 3000 using ATM "

final_output = re.split(r",",text)
print("Account Number:",Account_number)
print("Before clean:", text)
print("split by comma:",final_output)
# Out:
# Account Number: ACC-1007
# Before clean: Nafim deposited amount of 10000,Transferred 2000 to friend via online banking,withdrawn 3000 using ATM
# split by comma: ['Nafim deposited amount of 10000', 'Transferred 2000 to friend via online banking', 'withdrawn 3000 using ATM ']

# %%
#Q8. Check a phone number for banking case 1; use sample reference ACC-1008 and explain the result.


import re

Account_number = "ACC-1008"

phonenumbers = """ 9866419847
80976543214
098765432135678
908766
12345589 """

Vaild_phonenumers = re.findall(r"\d{10}",phonenumbers)
print("Vaild Phonenumbers:",Vaild_phonenumers)
# Out:
# Vaild Phonenumbers: ['9866419847', '8097654321', '0987654321']

# %%
#Q9. Find fee waiver codes for banking case 1; use sample reference ACC-1009 and explain the result.


import re

Account_number = "ACC-1009"

text = "ACC-1009 got few waiver code which are ABCD345,FWC1009,xyz009,FWC2009 and ABCFE3T "

Fee_waiver_codes = re.findall(r"[A-Z]{3}\d{4}",text)

print("Fee Waiver Codes from text","\n",Fee_waiver_codes)
# Out:
# Fee Waiver Codes from text
#  ['FWC1009', 'FWC2009']

# %%
#Q10. Replace masked card digits for banking case 1; use sample reference ACC-1010 and explain the result.


import re

Account_Number = "ACC-1010"

Card_number = "1234-2345-3456-4567"

Masked_card_number = re.sub(r"\d","*",Card_number[:-4]) + Card_number[-4:]

print("Account NUmber:",Account_Number)
print('Card number:',Card_number)
print("Masked Card Number:",Masked_card_number)
# Out:
# Account NUmber: ACC-1010
# Card number: 1234-2345-3456-4567
# Masked Card Number: ****-****-****-4567

# %%
#Q11. Extract quantities for banking case 1; use sample reference ACC-1011 and explain the result.


import re

Account_number = "ACC-1011"

text = " Nafim brought 5 buns, 3 oero biscuits, 10 pens and 200 dairymilks "

quantities = re.findall(r"\d+",text)

print("Account Number:",Account_number)
print("Original text:",text)
print("Quantities in list:",quantities)
# Out:
# Account Number: ACC-1011
# Original text:  Nafim brought 5 buns, 3 oero biscuits, 10 pens and 200 dairymilks
# Quantities in list: ['5', '3', '10', '200']

# %%
#Q12. Match branch ids for banking case 1; use sample reference ACC-1012 and explain the result.


import re

Acc_num = "ACC-1012"

Details = "EDUKRON have different branches in different location few are below BNGM123,BNGW456,BNGE789 and BNGE789098  from Banglore."

sample_Branch = "Start with BNG, ends with 3 digits, between allowed one charcter from A-z "

Match_Branch_id = re.findall(r"\bBNG[A-Z]{1}\d{3}\b",Details)  ### \b used to set boundary so it will display only asked values

print("Account Number:",Acc_num)
print("Matched Branch ID's:",Match_Branch_id)
# Out:
# Account Number: ACC-1012
# Matched Branch ID's: ['BNGM123', 'BNGW456', 'BNGE789']

# %%
#Q13. Find email addresses for banking case 1; use sample reference ACC-1013 and explain the result.


import re

Acc_num = "ACC-1013"

details = """
Customer Emails:
john@gmail.com
teja.k123@outlook.com
support@banking.co.in
invalid@email
test@.com """

pattern = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
Vaild_email_id = re.findall(pattern,details)
print("Account Number:",Acc_num)
print("Vaild Email ID's:",Vaild_email_id)
# Out:
# Account Number: ACC-1013
# Vaild Email ID's: ['john@gmail.com', 'teja.k123@outlook.com', 'support@banking.co.in']

# %%
#Q14. Validate a postcode for banking case 1; use sample reference ACC-1014 and explain the result.


import re

Acc_num = "ACC1014"

text = """
Customer Records
Ramesh - Bengaluru - 560001
Suresh - Hyderabad - 500081
Mahesh - Chennai - 600001
Rajesh - Delhi - 110001
Bengaluru - 56001
Mumbai - 4000012
Pune - 41A001
"""
Postcode_vaild = re.findall(r"\b\d{6}\b",text)
print("Account Number:",Acc_num)
print("Pin codes from text:",Postcode_vaild)
# Out:
# Account Number: ACC1014
# Pin codes from text: ['560001', '500081', '600001', '110001']

# %%
#Q15. Detect the word sale for banking case 1; use sample reference ACC-1015 and explain the result.


import re

Acc_num = "ACC-1015"

text = """
The bank announced a sale on locker services this month.
Customers participating in the sale can get a fee waiver.
A special SAle event is available for premium account holders.
"""

Detect_sale = re.findall(r"\bsale\b",text,)  ### for case sentitvive we use re.IGNORECASE
print("Account Number:",Acc_num)
print("Sales dected in text:",Detect_sale)
# Out:
# Account Number: ACC-1015
# Sales dected in text: ['sale', 'sale']

# %%
#Q16. Find a account code for banking case 2; use sample reference ACC-1016 and explain the result.


import re

account_number = ["ACC-1016","ABC-1016","ACC1016","ACC-9876"]

pattern = r"^ACC-\d{4}$"

Vaild_Account_Numbers = [i for i in account_number if re.match(pattern,i)]
print("Valid Account Numbers:",Vaild_Account_Numbers)
# Out:
# Valid Account Numbers: ['ACC-1016', 'ACC-9876']

# %%
#Q17. Validate a six-digit pin for banking case 2; use sample reference ACC-1017 and explain the result.


import re

Account_number = "ACC-1017"
pin = "123456"

pattern = r"^\d{6}$"

if re.match(pattern,pin):
  print("Account Number:",Account_number)
  print("pin:",pin)
  print("Vaild Pin")
else:
  print("Account Number:",Account_number)
  print("pin:",pin)
  print("Not Vaild pin")
# Out:
# Account Number: ACC-1017
# pin: 123456
# Vaild Pin

# %%
#Q18. Extract all amounts for banking case 2; use sample reference ACC-1018 and explain the result.


import re

Account_number = "ACC-1018"
text = "Nafim Deppsited 20000 in the account,charges applied is 34.897 and he trasnferred 4000 to his friend"

pattern = r"\d+\d.\d+"
extract = re.findall(pattern,text)
print(extract)
# Out:
# ['20000', '34.897', '4000']

# %%
#Q19. Match a receipt date for banking case 2; use sample reference ACC-1019 and explain the result.


import re

Account_Number = "Acc-1019"

Receipt_Details = """ Nafim's Account is created on 09/09/2026
                       and it got activated on 10-09-2026. """

pattern = r"\d{2}/\d{2}/\d{4}|\d{2}-\d{2}-\d{4}"

receipt_date = re.findall(pattern,Receipt_Details)
print("Account Number:",Account_Number)
print("Dates as per the Receipt Details:",receipt_date)
# Out:
# Account Number: Acc-1019
# Dates as per the Receipt Details: ['09/09/2026', '10-09-2026']

# %%
#Q20. Find uppercase account references for banking case 2; use sample reference ACC-1020 and explain the result.


import re

Account_numbers = " ACC-1020 ABC-1020 ACC-1003 Acc-1002 acc-1001 "

pattern = r"ACC-\d{4}"

upper_case = re.findall(pattern,Account_numbers)
print("Account Numbers:",Account_numbers)
print(upper_case)
# Out:
# Account Numbers:  ACC-1020 ABC-1020 ACC-1003 Acc-1002 acc-1001
# ['ACC-1020', 'ACC-1003']

# %%
#Q21. Remove extra spaces for banking case 2; use sample reference ACC-1021 and explain the result.


import re

Account_number = "ACC-1021"

text = "Nafim's     Account is    created on 09/09/2026   and it got    activated on    10-09-2026"

clean_text = re.sub(r"\s+"," ",text)
print("Account Number:",Account_number)
print("Before clean:",text)
print("After clean:",clean_text)
# Out:
# Account Number: ACC-1021
# Before clean: Nafim's     Account is    created on 09/09/2026   and it got    activated on    10-09-2026
# After clean: Nafim's Account is created on 09/09/2026 and it got activated on 10-09-2026

# %%
#Q22. Split a comma-separated tag list for banking case 2; use sample reference ACC-1022 and explain the result.


import re

Account_number = "ACC-1022"

text = "Nafim deposited amount of 10000,Transferred 2000 to friend via online banking,withdrawn 3000 using ATM "

final_output = re.split(r",",text)
print("Account Number:",Account_number)
print("Before clean:", text)
print("split by comma:",final_output)
# Out:
# Account Number: ACC-1022
# Before clean: Nafim deposited amount of 10000,Transferred 2000 to friend via online banking,withdrawn 3000 using ATM
# split by comma: ['Nafim deposited amount of 10000', 'Transferred 2000 to friend via online banking', 'withdrawn 3000 using ATM ']

# %%
#Q23. Check a phone number for banking case 2; use sample reference ACC-1023 and explain the result.


import re

Account_number = "ACC-1023"

phonenumbers = """ 9866419847
80976543214
098765432135678
908766
12345589 """

Vaild_phonenumers = re.findall(r"\d{10}",phonenumbers)
print("Vaild Phonenumbers:",Vaild_phonenumers)
# Out:
# Vaild Phonenumbers: ['9866419847', '8097654321', '0987654321']

# %%
#Q24. Find fee waiver codes for banking case 2; use sample reference ACC-1024 and explain the result.


import re

Account_number = "ACC-1024"

text = "ACC-1009 got few waiver code which are ABCD345,FWC1009,xyz009,FWC2009 and ABCFE3T "

Fee_waiver_codes = re.findall(r"[A-Z]{3}\d{4}",text)

print("Fee Waiver Codes from text","\n",Fee_waiver_codes)
# Out:
# Fee Waiver Codes from text
#  ['FWC1009', 'FWC2009']

# %%
#Q25. Replace masked card digits for banking case 2; use sample reference ACC-1025 and explain the result.


import re

Account_Number = "ACC-1025"

Card_number = "1234-2345-3456-4567"

Masked_card_number = re.sub(r"\d","*",Card_number[:-4]) + Card_number[-4:]

print("Account NUmber:",Account_Number)
print('Card number:',Card_number)
print("Masked Card Number:",Masked_card_number)
# Out:
# Account NUmber: ACC-1025
# Card number: 1234-2345-3456-4567
# Masked Card Number: ****-****-****-4567

# %%
#Q26. Extract quantities for banking case 2; use sample reference ACC-1026 and explain the result.


import re

Account_number = "ACC-1026"

text = " Nafim brought 5 buns, 3 oero biscuits, 10 pens and 200 KitKat "

quantities = re.findall(r"\d+",text)

print("Account Number:",Account_number)
print("Original text:",text)
print("Quantities in list:",quantities)
# Out:
# Account Number: ACC-1026
# Original text:  Nafim brought 5 buns, 3 oero biscuits, 10 pens and 200 KitKat
# Quantities in list: ['5', '3', '10', '200']

# %%
#Q27. Match branch ids for banking case 2; use sample reference ACC-1027 and explain the result.


import re

Acc_num = "ACC-1027"

Details = "EDUKRON have different branches in different location few are below BNGM123,BNGW456,BNGE789 and BNGE789098  from Banglore."

sample_Branch = "Start with BNG, ends with 3 digits, between allowed one charcter from A-z "

Match_Branch_id = re.findall(r"\bBNG[A-Z]{1}\d{3}\b",Details)  ### \b used to set boundary so it will display only asked values

print("Account Number:",Acc_num)
print("Matched Branch ID's:",Match_Branch_id)
# Out:
# Account Number: ACC-1027
# Matched Branch ID's: ['BNGM123', 'BNGW456', 'BNGE789']

# %%
#Q28. Find email addresses for banking case 2; use sample reference ACC-1028 and explain the result.


import re

Acc_num = "ACC-1028"

details = """
Customer Emails:
Nafim@gmail.com
nafimunnisa@outlook.com
ICICI@banking.co.in
invalid@email
test@.com """

pattern = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b"
Vaild_email_id = re.findall(pattern,details)
print("Account Number:",Acc_num)
print("Vaild Email ID's:",Vaild_email_id)
# Out:
# Account Number: ACC-1028
# Vaild Email ID's: ['Nafim@gmail.com', 'nafimunnisa@outlook.com', 'ICICI@banking.co.in']

# %%
#Q29. Validate a postcode for banking case 2; use sample reference ACC-1029 and explain the result.


import re

Acc_num = "ACC1029"

text = """
Customer Records
Ramesh - Bengaluru - 560001
Suresh - Hyderabad - 500081
Mahesh - Chennai - 600001
Rajesh - Delhi - 110001
Bengaluru - 56001
Mumbai - 4000012
Pune - 41A001
"""
Postcode_vaild = re.findall(r"\b\d{6}\b",text)
print("Account Number:",Acc_num)
print("Pin codes from text:",Postcode_vaild)
# Out:
# Account Number: ACC1029
# Pin codes from text: ['560001', '500081', '600001', '110001']

# %%
#Q30. Detect the word sale for banking case 2; use sample reference ACC-1030 and explain the result.


import re

Acc_num = "ACC-1030"

text = """
The bank announced a sale on locker services this month.
Customers participating in the sale can get a fee waiver.
A special SAle event is available for premium account holders.
"""

Detect_sale = re.findall(r"\bsale\b",text,)  ### for case sentitvive we use re.IGNORECASE
print("Account Number:",Acc_num)
print("Sales dected in text:",Detect_sale)
# Out:
# Account Number: ACC-1030
# Sales dected in text: ['sale', 'sale']

# %%
#Q31. Parse a receipt line into named groups for banking case 1; use sample reference ACC-1031 and explain the result.


import re

Receipt_line = "ACC-1031 | DEPOSIT | 6000.98 | 09-09-2026"

pattern = r"^(?P<account>ACC-\d{4})\s*\|\s*(?P<transactiontype>[A-Z]+)\s*\|\s*(?P<amount>\d+(?:\.\d{1,2})?)\s*\|\s*(?P<date>\d{2}-\d{2}-\d{4})$"

match = re.fullmatch(pattern,Receipt_line)

if match:
  print("Receipt Passed Successfully")
  print("Account     :",match.group("account"))
  print("Transaction :", match.group("transactiontype"))
  print("Amount      :", match.group("amount"))
  print("Date        :", match.group("date"))

  print("\nNamed groups:", match.groupdict())
else:
  print("Invalid receipt format")
# Out:
# Receipt Passed Successfully
# Account     : ACC-1031
# Transaction : DEPOSIT
# Amount      : 6000.98
# Date        : 09-09-2026
#
# Named groups: {'account': 'ACC-1031', 'transactiontype': 'DEPOSIT', 'amount': '6000.98', 'date': '09-09-2026'}

# %%
#Q32. Validate an account reference with optional category prefix for banking case 1; use sample reference ACC-1032 and explain the result.


import re

account_references = [
    "ACC-1032",
    "SAV-ACC-1032",
    "CUR-ACC-1032",
    "VIP-ACC-1032",
    "SAV-ACC-103",
    "ACC1032"
]

pattern = r"^(?:[A-Z]{3}-)?ACC-\d{4}$"

for account in account_references:
    if re.fullmatch(pattern, account):
        print(account, "-> Valid")
    else:
        print(account, "-> Invalid")
# Out:
# ACC-1032 -> Valid
# SAV-ACC-1032 -> Valid
# CUR-ACC-1032 -> Valid
# VIP-ACC-1032 -> Valid
# SAV-ACC-103 -> Invalid
# ACC1032 -> Invalid

# %%
#Q33. Extract currency and amount for banking case 1; use sample reference ACC-1033 and explain the result.


import re

account_code = "ACC-1033"

text = """
USD 5000.75
INR 4500
EUR 1200.50
"""

pattern = r"(?P<currency>[A-Z]{3})\s+(?P<amount>\d+(?:\.\d{1,2})?)"

matches = re.finditer(pattern, text)

for match in matches:
    print("Currency :", match.group("currency"))
    print("Amount   :", match.group("amount"))
    print("-" * 20)
# Out:
# Currency : USD
# Amount   : 5000.75
# --------------------
# Currency : INR
# Amount   : 4500
# --------------------
# Currency : EUR
# Amount   : 1200.50
# --------------------

# %%
#Q34. Normalize account holder phone numbers for banking case 1; use sample reference ACC-1034 and explain the result.


import re

Acc_num = "ACC-1034"

phones = ["9876543210","98765-43210","(987) 654-3210","+91 9876543210","98765 43210","+91-98765-43210"]

for i in phones:
  normalized = re.sub(r"\D","",i)

  if len(normalized) > 10:
    normalized = normalized[-10:]

  print("Account Number:",Acc_num)
  print("Original Phone Number:",i)
  print("Normalized:",normalized)
  print()
# Out:
# Account Number: ACC-1034
# Original Phone Number: 9876543210
# Normalized: 9876543210
#
# Account Number: ACC-1034
# Original Phone Number: 98765-43210
# Normalized: 9876543210
#
# Account Number: ACC-1034
# Original Phone Number: (987) 654-3210
# Normalized: 9876543210
#
# Account Number: ACC-1034
# Original Phone Number: +91 9876543210
# Normalized: 9876543210
#
# Account Number: ACC-1034
# Original Phone Number: 98765 43210
# Normalized: 9876543210
#
# Account Number: ACC-1034
# Original Phone Number: +91-98765-43210
# Normalized: 9876543210

# %%
#Q35. Find repeated account words for banking case 1; use sample reference ACC-1035 and explain the result.


import re

Acc_num = "ACC-1035"

details = """
account account created successfully
customer customer updated
balance verified
loan loan approved
"""

pattern = r"\b(\w+)\s+\1\b"  # \1 - used for Same word captured earlier

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Repeated Words:", matches)
# Out:
# Account Number: ACC-1035
# Repeated Words: ['account', 'customer', 'loan']

# %%
#Q36. Validate fee waiver start and end anchors for banking case 1; use sample reference ACC-1036 and explain the result.


import re

Acc_num = "ACC-1036"

fee_codes = ["FW-1001","FW-2500","FW-9999","FW1001","AB-1234","FW-12345"]

pattern = r"^FW-\d{4}$"

for code in fee_codes:
    if re.fullmatch(pattern, code):
        print("Account Number:", Acc_num)
        print("Valid Fee Waiver Code:", code)
        print()
# Out:
# Account Number: ACC-1036
# Valid Fee Waiver Code: FW-1001
#
# Account Number: ACC-1036
# Valid Fee Waiver Code: FW-2500
#
# Account Number: ACC-1036
# Valid Fee Waiver Code: FW-9999

# %%
#Q37. Redact emails from support text for banking case 1; use sample reference ACC-1037 and explain the result.


import re

Acc_num = "ACC-1037"

details = """
Customer query received from john@gmail.com
Escalation sent to support@banking.co.in
Backup email: teja.k123@outlook.com
"""

pattern = r"\b[A-Za-z0-9._%+-]+@[a-zA-Z0-9.-]+.[a-zA-Z]{2,}\b"

redact_text = re.sub(pattern,"[REDACT]",details)

print("Account Number:",Acc_num)
print(redact_text)
# Out:
# Account Number: ACC-1037
#
# Customer query received from [REDACT]
# Escalation sent to [REDACT]
# Backup email: [REDACT]

# %%
#Q38. Extract transfer ids without partial matches for banking case 1; use sample reference ACC-1038 and explain the result.


import re

Acc_num = "ACC-1038"

details = """
Valid Transfers:TRF-1001 TRF-2500 TRF-9999
Invalid Transfers:TRF-10012 XTRF-2001 TRF-300A """

pattern = r"\bTRF-\d{4}\b"

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Transfer IDs:", matches)
# Out:
# Account Number: ACC-1038
# Transfer IDs: ['TRF-1001', 'TRF-2500', 'TRF-9999']

# %%
#Q39. Parse inventory key-value pairs for banking case 1; use sample reference ACC-1039 and explain the result.


import re

Acc_num = "ACC-1039"

details = """Cards=150 ChequeBooks=75
Passbooks=200 LoanFiles=50
"""

pattern = r"(\w+)=(\d+)"

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)

for key, value in matches:
    print("Item:", key)
    print("Quantity:", value)
    print()
# Out:
# Account Number: ACC-1039
# Item: Cards
# Quantity: 150
#
# Item: ChequeBooks
# Quantity: 75
#
# Item: Passbooks
# Quantity: 200
#
# Item: LoanFiles
# Quantity: 50

# %%
#Q40. Use lookahead for strong fee waiver tokens for banking case 1; use sample reference ACC-1040 and explain the result.


import re

Acc_num = "ACC-1040"

details = """FWA HIGH FWB LOW
FWC HIGH FWD MEDIUM FWE HIGH
"""

pattern = r"\bFW\w+(?=\s+HIGH)"   ## Positive lookahead which means after FW w+ it will see ig HIGH is there or not    re.IGNORECASE is used for case sententive

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Strong Fee Waiver Tokens:", matches)
# Out:
# Account Number: ACC-1040
# Strong Fee Waiver Tokens: ['FWA', 'FWC', 'FWE']

# %%
#Q41. Use negative lookahead to reject test account references for banking case 1; use sample reference ACC-1041 and explain the result.


import re

Acc_num = "ACC-1041"

details = """
ACC-1001
ACC-1002
TEST-ACC-9999
ACC-1003
TEST-ACC-8888
"""

pattern = r"\bACC-\d{4}\b"

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Valid Account References:", matches)
# Out:
# Account Number: ACC-1041
# Valid Account References: ['ACC-1001', 'ACC-1002', 'ACC-9999', 'ACC-1003', 'ACC-8888']

# %%
#Q42. Extract account names between delimiters for banking case 1; use sample reference ACC-1042 and explain the result.

import re

Acc_num = "ACC-1042"

details = """
"""

pattern = r"<(.*)>"

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)

for name in matches:
    print("Account Holder:", name)
# Out:
# Account Number: ACC-1042

# %%
#Q43. Replace dates with iso format for banking case 1; use sample reference ACC-1043 and explain the result.


import re

Acc_num = "ACC-1043"

details = """
Transaction Date : 10/09/2026
Loan Date        : 25/12/2025
Renewal Date     : 01/01/2027
"""

pattern = r"(\d{2})/(\d{2})/(\d{4})"

iso_text = re.sub(pattern, r"\3-\2-\1", details)   #### pattern values stores in groups so if we call \3 it means years\d{4}which is year,\2 means
                                                                                        ###\d{2} which is month and \1 means \d{2} which is day

print("Account Number:", Acc_num)
print(iso_text)
# Out:
# Account Number: ACC-1043
#
# Transaction Date : 2026-09-10
# Loan Date        : 2025-12-25
# Renewal Date     : 2027-01-01

# %%
#Q44. Compile a reusable account pattern for banking case 1; use sample reference ACC-1044 and explain the result.


import re

Acc_num = "ACC-1044"

accounts = [
    "ACC-1001",
    "ACC-2050",
    "ACC-9999",
    "ACC1001",
    "acc-1234",
    "ACC-12"
]

account_pattern = re.compile(r"^ACC-\d{4}$")

print("Reference:", Acc_num)
print("-" * 30)

for acc in accounts:
    if account_pattern.fullmatch(acc):
        print(acc, "-> Valid Account")
    else:
        print(acc, "-> Invalid Account")
#### Pattern is compiled once and reused multiple times, which is cleaner and faster when validating many account references.

### Use re.compile() when the same regex will be used repeatedly inside loops, validations, log parsing, or data-processing pipelines.
# Out:
# Reference: ACC-1044
# ------------------------------
# ACC-1001 -> Valid Account
# ACC-2050 -> Valid Account
# ACC-9999 -> Valid Account
# ACC1001 -> Invalid Account
# acc-1234 -> Invalid Account
# ACC-12 -> Invalid Account

# %%
#Q45. Use case-insensitive matching for brand search for banking case 1; use sample reference ACC-1045 and explain the result.


import re

Acc_num = "ACC-1045"

details = """
Customer used VISA debit card.
Another transaction used visa credit card.
Premium customer used ViSa rewards card.
MasterCard transaction also found.
"""

pattern = r"visa"

matches = re.findall(pattern, details, re.IGNORECASE)

print("Reference:", Acc_num)
print("Matched Brands:", matches)
# Out:
# Reference: ACC-1045
# Matched Brands: ['VISA', 'visa', 'ViSa']

# %%
#Q46. Parse a receipt line into named groups for banking case 2; use sample reference ACC-1046 and explain the result.


import re

Receipt_line = "ACC-1046 | DEPOSIT | 6000.98 | 09-09-2026"

pattern = r"^(?P<account>ACC-\d{4})\s*\|\s*(?P<transactiontype>[A-Z]+)\s*\|\s*(?P<amount>\d+(?:\.\d{1,2})?)\s*\|\s*(?P<date>\d{2}-\d{2}-\d{4})$"

# \d+ → one or more digits
# (?:...) → non-capturing group
# \. → decimal point
# \d{1,2} → one or two decimal digits
# ? → makes the decimal portion optional

# pattern = (
#     r"^(?PACC-\d{4})\s*\|\s*"
#     r"(?P[A-Z]+)\s*\|\s*"
#     r"(?P\d+(?:\.\d{1,2})?)\s*\|\s*"
#     r"(?P\d{2}-\d{2}-\d{4})$"
# )

match = re.fullmatch(pattern,Receipt_line)

if match:
  print("Receipt Parsed Successfully")
  print("Account     :",match.group("account"))
  print("Transaction :", match.group("transactiontype"))
  print("Amount      :", match.group("amount"))
  print("Date        :", match.group("date"))

  print("\nNamed groups:", match.groupdict())
else:
  print("Invalid receipt format")
# Out:
# Receipt Parsed Successfully
# Account     : ACC-1046
# Transaction : DEPOSIT
# Amount      : 6000.98
# Date        : 09-09-2026
#
# Named groups: {'account': 'ACC-1046', 'transactiontype': 'DEPOSIT', 'amount': '6000.98', 'date': '09-09-2026'}

# %%
#Q47. Validate an account reference with optional category prefix for banking case 2; use sample reference ACC-1047 and explain the result.


import re

account_references = [
    "ACC-1047",
    "SAV-ACC-1032",
    "CUR-ACC-1032",
    "VIP-ACC-1032",
    "SAV-ACC-103",
    "ACC1032"
]

pattern = r"^(?:[A-Z]{3}-)?ACC-\d{4}$"

for account in account_references:
    if re.fullmatch(pattern, account):
        print(account, "-> Valid")
    else:
        print(account, "-> Invalid")
# Out:
# ACC-1047 -> Valid
# SAV-ACC-1032 -> Valid
# CUR-ACC-1032 -> Valid
# VIP-ACC-1032 -> Valid
# SAV-ACC-103 -> Invalid
# ACC1032 -> Invalid

# %%
#Q48. Extract currency and amount for banking case 2; use sample reference ACC-1048 and explain the result.


import re

account_code = "ACC-1048"

text = """
USD 5000.75
INR 4500
EUR 1200.50
"""

pattern = r"(?P<currency>[A-Z]{3})\s+(?P<amount>\d+(?:\.\d{1,2})?)"

matches = re.finditer(pattern, text)

for match in matches:
    print("Currency :", match.group("currency"))
    print("Amount   :", match.group("amount"))
    print("-" * 20)
# Out:
# Currency : USD
# Amount   : 5000.75
# --------------------
# Currency : INR
# Amount   : 4500
# --------------------
# Currency : EUR
# Amount   : 1200.50
# --------------------

# %%
#Q49. Normalize account holder phone numbers for banking case 2; use sample reference ACC-1049 and explain the result.


import re

Acc_num = "ACC-1049"

phones = ["9876543210","98765-43210","(987) 654-3210","+91 9876543210","98765 43210","+91-98765-43210"]

for i in phones:
  normalized = re.sub(r"\D","",i)

  if len(normalized) > 10:
    normalized = normalized[-10:]

  print("Account Number:",Acc_num)
  print("Original Phone Number:",i)
  print("Normalized:",normalized)
  print()
# Out:
# Account Number: ACC-1049
# Original Phone Number: 9876543210
# Normalized: 9876543210
#
# Account Number: ACC-1049
# Original Phone Number: 98765-43210
# Normalized: 9876543210
#
# Account Number: ACC-1049
# Original Phone Number: (987) 654-3210
# Normalized: 9876543210
#
# Account Number: ACC-1049
# Original Phone Number: +91 9876543210
# Normalized: 9876543210
#
# Account Number: ACC-1049
# Original Phone Number: 98765 43210
# Normalized: 9876543210
#
# Account Number: ACC-1049
# Original Phone Number: +91-98765-43210
# Normalized: 9876543210

# %%
#Q50. Find repeated account words for banking case 2; use sample reference ACC-1050 and explain the result.


import re

Acc_num = "ACC-1050"

details = """
account account created successfully
customer customer updated
balance verified
loan loan approved
"""

pattern = r"\b(\w+)\s+\1\b"  # \1 - used for Same word captured earlier

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Repeated Words:", matches)
# Out:
# Account Number: ACC-1050
# Repeated Words: ['account', 'customer', 'loan']

# %%
#Q51. Validate fee waiver start and end anchors for banking case 2; use sample reference ACC-1051 and explain the result.


import re

Acc_num = "ACC-1051"

fee_codes = ["FW-1001","FW-2500","FW-9999","FW1001","AB-1234","FW-12345"]

pattern = r"^FW-\d{4}$"

for code in fee_codes:
    if re.fullmatch(pattern, code):
        print("Account Number:", Acc_num)
        print("Valid Fee Waiver Code:", code)
        print()
# Out:
# Account Number: ACC-1051
# Valid Fee Waiver Code: FW-1001
#
# Account Number: ACC-1051
# Valid Fee Waiver Code: FW-2500
#
# Account Number: ACC-1051
# Valid Fee Waiver Code: FW-9999

# %%
#Q52. Redact emails from support text for banking case 2; use sample reference ACC-1052 and explain the result.


import re

Acc_num = "ACC-1052"

details = """
Customer query received from john@gmail.com
Escalation sent to support@banking.co.in
Backup email: teja.k123@outlook.com
"""

pattern = r"\b[A-Za-z0-9._%+-]+@[a-zA-Z0-9.-]+.[a-zA-Z]{2,}\b"

redact_text = re.sub(pattern,"[REDACT]",details)

print("Account Number:",Acc_num)
print(redact_text)
# Out:
# Account Number: ACC-1052
#
# Customer query received from [REDACT]
# Escalation sent to [REDACT]
# Backup email: [REDACT]

# %%
#Q53. Extract transfer ids without partial matches for banking case 2; use sample reference ACC-1053 and explain the result.


import re

Acc_num = "ACC-1053"

details = """
Valid Transfers:TRF-1001 TRF-2500 TRF-9999
Invalid Transfers:TRF-10012 XTRF-2001 TRF-300A """

pattern = r"\bTRF-\d{4}\b"

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Transfer IDs:", matches)
# Out:
# Account Number: ACC-1053
# Transfer IDs: ['TRF-1001', 'TRF-2500', 'TRF-9999']

# %%
#Q54. Parse inventory key-value pairs for banking case 2; use sample reference ACC-1054 and explain the result.


import re

Acc_num = "ACC-1054"

details = """Cards=150 ChequeBooks=75
Passbooks=200 LoanFiles=50
"""

pattern = r"(\w+)=(\d+)"

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)

for key, value in matches:
    print("Item:", key)
    print("Quantity:", value)
    print()
# Out:
# Account Number: ACC-1054
# Item: Cards
# Quantity: 150
#
# Item: ChequeBooks
# Quantity: 75
#
# Item: Passbooks
# Quantity: 200
#
# Item: LoanFiles
# Quantity: 50

# %%
#Q55. Use lookahead for strong fee waiver tokens for banking case 2; use sample reference ACC-1055 and explain the result.


import re

Acc_num = "ACC-1055"

details = """FWA HIGH FWB LOW
FWC HIGH FWD MEDIUM FWE HIGH
"""

pattern = r"\bFW\w+(?=\s+HIGH)"   ## Positive lookahead which means after FW w+ it will see ig HIGH is there or not    re.IGNORECASE is used for case sententive

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Strong Fee Waiver Tokens:", matches)
# Out:
# Account Number: ACC-1055
# Strong Fee Waiver Tokens: ['FWA', 'FWC', 'FWE']

# %%
#Q56. Use negative lookahead to reject test account references for banking case 2; use sample reference ACC-1056 and explain the result.


import re

Acc_num = "ACC-1056"

details = """
ACC-1001
ACC-1002
TEST-ACC-9999
ACC-1003
TEST-ACC-8888
"""

pattern = r"\bACC-\d{4}\b"

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Valid Account References:", matches)
# Out:
# Account Number: ACC-1056
# Valid Account References: ['ACC-1001', 'ACC-1002', 'ACC-9999', 'ACC-1003', 'ACC-8888']

# %%
#Q57. Extract account names between delimiters for banking case 2; use sample reference ACC-1057 and explain the result.


import re

Acc_num = "ACC-1042"

details = """




"""

pattern = r"<(.*)>"

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)

for name in matches:
    print("Account Holder:", name)
# Out:
# Account Number: ACC-1042

# %%
#Q58. Replace dates with iso format for banking case 2; use sample reference ACC-1058 and explain the result.


import re

Acc_num = "ACC-1058"

details = """
Transaction Date : 10/09/2026
Loan Date        : 25/12/2025
Renewal Date     : 01/01/2027
"""

pattern = r"(\d{2})/(\d{2})/(\d{4})"

iso_text = re.sub(pattern, r"\3-\2-\1", details)   #### pattern values stores in groups so if we call \3 it means years\d{4}which is year,\2 means
                                                                                        ###\d{2} which is month and \1 means \d{2} which is day

print("Account Number:", Acc_num)
print(iso_text)
# Out:
# Account Number: ACC-1058
#
# Transaction Date : 2026-09-10
# Loan Date        : 2025-12-25
# Renewal Date     : 2027-01-01

# %%
#Q59. Compile a reusable account pattern for banking case 2; use sample reference ACC-1059 and explain the result.


import re

Acc_num = "ACC-1059"

accounts = [
    "ACC-1001",
    "ACC-2050",
    "ACC-9999",
    "ACC1001",
    "acc-1234",
    "ACC-12"
]

account_pattern = re.compile(r"^ACC-\d{4}$")

print("Reference:", Acc_num)
print("-" * 30)

for acc in accounts:
    if account_pattern.fullmatch(acc):
        print(acc, "-> Valid Account")
    else:
        print(acc, "-> Invalid Account")
#### Pattern is compiled once and reused multiple times, which is cleaner and faster when validating many account references.

### Use re.compile() when the same regex will be used repeatedly inside loops, validations, log parsing, or data-processing pipelines.
# Out:
# Reference: ACC-1059
# ------------------------------
# ACC-1001 -> Valid Account
# ACC-2050 -> Valid Account
# ACC-9999 -> Valid Account
# ACC1001 -> Invalid Account
# acc-1234 -> Invalid Account
# ACC-12 -> Invalid Account

# %%
#Q60. Use case-insensitive matching for brand search for banking case 2; use sample reference ACC-1060 and explain the result.


import re

Acc_num = "ACC-1060"

details = """FWA HIGH FWB LOW
FWC HIGH FWD MEDIUM FWE HIGH
"""

pattern = r"\bFW\w+(?=\s+HIGH)"   ## Positive lookahead which means after FW w+ it will see ig HIGH is there or not    re.IGNORECASE is used for case sententive

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Strong Fee Waiver Tokens:", matches)
# Out:
# Account Number: ACC-1060
# Strong Fee Waiver Tokens: ['FWA', 'FWC', 'FWE']

# %%
#Q61. Parse a receipt line into named groups for banking case 3; use sample reference ACC-1061 and explain the result.


import re

Receipt_line = "ACC-1061 | DEPOSIT | 6000.98 | 09-09-2026"

pattern = r"^(?P<account>ACC-\d{4})\s*\|\s*(?P<transactiontype>[A-Z]+)\s*\|\s*(?P<amount>\d+(?:\.\d{1,2})?)\s*\|\s*(?P<date>\d{2}-\d{2}-\d{4})$"

# \d+ → one or more digits
# (?:...) → non-capturing group
# \. → decimal point
# \d{1,2} → one or two decimal digits
# ? → makes the decimal portion optional

# pattern = (
#     r"^(?PACC-\d{4})\s*\|\s*"
#     r"(?P[A-Z]+)\s*\|\s*"
#     r"(?P\d+(?:\.\d{1,2})?)\s*\|\s*"
#     r"(?P\d{2}-\d{2}-\d{4})$"
# )

match = re.fullmatch(pattern,Receipt_line)

if match:
  print("Receipt Parsed Successfully")
  print("Account     :",match.group("account"))
  print("Transaction :", match.group("transactiontype"))
  print("Amount      :", match.group("amount"))
  print("Date        :", match.group("date"))

  print("\nNamed groups:", match.groupdict())
else:
  print("Invalid receipt format")
# Out:
# Receipt Parsed Successfully
# Account     : ACC-1061
# Transaction : DEPOSIT
# Amount      : 6000.98
# Date        : 09-09-2026
#
# Named groups: {'account': 'ACC-1061', 'transactiontype': 'DEPOSIT', 'amount': '6000.98', 'date': '09-09-2026'}

# %%
#Q62. Validate an account reference with optional category prefix for banking case 3; use sample reference ACC-1062 and explain the result.


import re

account_references = [
    "ACC-1062",
    "SAV-ACC-1032",
    "CUR-ACC-1032",
    "VIP-ACC-1032",
    "SAV-ACC-103",
    "ACC1032"
]

pattern = r"^(?:[A-Z]{3}-)?ACC-\d{4}$"

for account in account_references:
    if re.fullmatch(pattern, account):
        print(account, "-> Valid")
    else:
        print(account, "-> Invalid")
# Out:
# ACC-1062 -> Valid
# SAV-ACC-1032 -> Valid
# CUR-ACC-1032 -> Valid
# VIP-ACC-1032 -> Valid
# SAV-ACC-103 -> Invalid
# ACC1032 -> Invalid

# %%
#Q63. Extract currency and amount for banking case 3; use sample reference ACC-1063 and explain the result.


import re

account_code = "ACC-1063"

text = """
USD 5000.75
INR 4500
EUR 1200.50
"""

pattern = r"(?P<currency>[A-Z]{3})\s+(?P<amount>\d+(?:\.\d{1,2})?)"

matches = re.finditer(pattern, text)

for match in matches:
    print("Currency :", match.group("currency"))
    print("Amount   :", match.group("amount"))
    print("-" * 20)
# Out:
# Currency : USD
# Amount   : 5000.75
# --------------------
# Currency : INR
# Amount   : 4500
# --------------------
# Currency : EUR
# Amount   : 1200.50
# --------------------

# %%
#Q64. Normalize account holder phone numbers for banking case 3; use sample reference ACC-1064 and explain the result.


import re

Acc_num = "ACC-1064"

phones = ["9876543210","98765-43210","(987) 654-3210","+91 9876543210","98765 43210","+91-98765-43210"]

for i in phones:
  normalized = re.sub(r"\D","",i)

  if len(normalized) > 10:
    normalized = normalized[-10:]

  print("Account Number:",Acc_num)
  print("Original Phone Number:",i)
  print("Normalized:",normalized)
  print()
# Out:
# Account Number: ACC-1064
# Original Phone Number: 9876543210
# Normalized: 9876543210
#
# Account Number: ACC-1064
# Original Phone Number: 98765-43210
# Normalized: 9876543210
#
# Account Number: ACC-1064
# Original Phone Number: (987) 654-3210
# Normalized: 9876543210
#
# Account Number: ACC-1064
# Original Phone Number: +91 9876543210
# Normalized: 9876543210
#
# Account Number: ACC-1064
# Original Phone Number: 98765 43210
# Normalized: 9876543210
#
# Account Number: ACC-1064
# Original Phone Number: +91-98765-43210
# Normalized: 9876543210

# %%
#Q65. Find repeated account words for banking case 3; use sample reference ACC-1065 and explain the result.


import re

Acc_num = "ACC-1065"

details = """
account account created successfully
customer customer updated
balance verified
loan loan approved
"""

pattern = r"\b(\w+)\s+\1\b"  # \1 - used for Same word captured earlier

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Repeated Words:", matches)
# Out:
# Account Number: ACC-1065
# Repeated Words: ['account', 'customer', 'loan']

# %%
#Q66. Validate fee waiver start and end anchors for banking case 3; use sample reference ACC-1066 and explain the result.


import re

Acc_num = "ACC-1066"

fee_codes = ["FW-1001","FW-2500","FW-9999","FW1001","AB-1234","FW-12345"]

pattern = r"^FW-\d{4}$"

for code in fee_codes:
    if re.fullmatch(pattern, code):
        print("Account Number:", Acc_num)
        print("Valid Fee Waiver Code:", code)
        print()
# Out:
# Account Number: ACC-1066
# Valid Fee Waiver Code: FW-1001
#
# Account Number: ACC-1066
# Valid Fee Waiver Code: FW-2500
#
# Account Number: ACC-1066
# Valid Fee Waiver Code: FW-9999

# %%
#Q67. Redact emails from support text for banking case 3; use sample reference ACC-1067 and explain the result.


import re

Acc_num = "ACC-1067"

details = """
Customer query received from john@gmail.com
Escalation sent to support@banking.co.in
Backup email: teja.k123@outlook.com
"""

pattern = r"\b[A-Za-z0-9._%+-]+@[a-zA-Z0-9.-]+.[a-zA-Z]{2,}\b"

redact_text = re.sub(pattern,"[REDACT]",details)

print("Account Number:",Acc_num)
print(redact_text)
# Out:
# Account Number: ACC-1067
#
# Customer query received from [REDACT]
# Escalation sent to [REDACT]
# Backup email: [REDACT]

# %%
#Q68. Extract transfer ids without partial matches for banking case 3; use sample reference ACC-1068 and explain the result.


import re

Acc_num = "ACC-1068"

details = """
Valid Transfers:TRF-1001 TRF-2500 TRF-9999
Invalid Transfers:TRF-10012 XTRF-2001 TRF-300A """

pattern = r"\bTRF-\d{4}\b"

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Transfer IDs:", matches)
# Out:
# Account Number: ACC-1068
# Transfer IDs: ['TRF-1001', 'TRF-2500', 'TRF-9999']

# %%
#Q69. Parse inventory key-value pairs for banking case 3; use sample reference ACC-1069 and explain the result.


import re

Acc_num = "ACC-1069"

details = """Cards=150 ChequeBooks=75
Passbooks=200 LoanFiles=50
"""

pattern = r"(\w+)=(\d+)"

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)

for key, value in matches:
    print("Item:", key)
    print("Quantity:", value)
    print()
# Out:
# Account Number: ACC-1069
# Item: Cards
# Quantity: 150
#
# Item: ChequeBooks
# Quantity: 75
#
# Item: Passbooks
# Quantity: 200
#
# Item: LoanFiles
# Quantity: 50

# %%
#Q70. Use lookahead for strong fee waiver tokens for banking case 3; use sample reference ACC-1070 and explain the result.


import re

Acc_num = "ACC-1070"

details = """FWA HIGH FWB LOW
FWC HIGH FWD MEDIUM FWE HIGH
"""

pattern = r"\bFW\w+(?=\s+HIGH)"   ## Positive lookahead which means after FW w+ it will see ig HIGH is there or not    re.IGNORECASE is used for case sententive

matches = re.findall(pattern, details)

print("Account Number:", Acc_num)
print("Strong Fee Waiver Tokens:", matches)
# Out:
# Account Number: ACC-1070
# Strong Fee Waiver Tokens: ['FWA', 'FWC', 'FWE']

# %%
#Q71. Tokenize a messy receipt safely for banking case 1; use sample reference ACC-1071 and explain the result.


import re

Acc_num = "ACC-1071"

receipt = """
Item: Laptop, Qty=2 | Price=55000;
Item: Mouse , Qty=3 || Price=600;
Payment: CARD-1234 ; Status: SUCCESS
"""

tokens = re.findall(r"\w+(?:-\w+)?", receipt)

print("Account:", Acc_num)
print("Tokens:", tokens)
# Out:
# Account: ACC-1071
# Tokens: ['Item', 'Laptop', 'Qty', '2', 'Price', '55000', 'Item', 'Mouse', 'Qty', '3', 'Price', '600', 'Payment', 'CARD-1234', 'Status', 'SUCCESS']

# %%
#Q72. Validate a multi-part warehouse location for banking case 1; use sample reference ACC-1072 and explain the result.


import re

Acc_num = "ACC-1072"

locations = [
    "WH-BNG-A1",
    "WH-HYD-B2",
    "WH-DEL-C10",
    "WH-MUM-12",
    "WH-BNG-AA1",
    "WH-bng-A1"
]

pattern = r"^WH-[A-Z]{3}-[A-Z]\d+$"

print("Account:", Acc_num)

for loc in locations:
    if re.fullmatch(pattern, loc):
        print(loc, "-> Valid")
    else:
        print(loc, "-> Invalid")
# Out:
# Account: ACC-1072
# WH-BNG-A1 -> Valid
# WH-HYD-B2 -> Valid
# WH-DEL-C10 -> Valid
# WH-MUM-12 -> Invalid
# WH-BNG-AA1 -> Invalid
# WH-bng-A1 -> Invalid

# %%
#Q73. Extract nested-looking account annotations within a defined limit for banking case 1; use sample reference ACC-1073 and explain the result.


import re

Acc_num = "ACC-1073"

details = """
Customer Rahul (Premium Customer)
Account ACC-1073 (VIP Level 2)
Branch (BNG Zone A)
Status (Active)
"""

pattern = r".*"

matches = re.findall(pattern, details)

print("Account:", Acc_num)

for m in matches:
    print(m)
# Out:
# Account: ACC-1073
#
# Customer Rahul (Premium Customer)
#
# Account ACC-1073 (VIP Level 2)
#
# Branch (BNG Zone A)
#
# Status (Active)

# %%
#74. Find duplicate adjacent account reference tokens with backreferences for banking case 1; use sample reference ACC-1074 and explain the result.


import re

Acc_num = "ACC-1074"

details = """
ACC1001 ACC1001
ACC2002 ACC3003
ACC4004 ACC4004
ACC5005 ACC5005
"""

pattern = r"\b(ACC\d+)\s+\1\b"

matches = re.findall(pattern, details)
### for replace that repeated value --- cleaned = re.sub(pattern, r"\1", details)  ------ r"\1" it will replace the value which is captured by 1st itraction

print("Account:", Acc_num)
print("Duplicate Adjacent References:")


for match in matches:
    print(match)
# Out:
# Account: ACC-1074
# Duplicate Adjacent References:
# ACC1001
# ACC4004
# ACC5005

# %%
#75. Redact card-like numbers while preserving last four digits for banking case 1; use sample reference ACC-1075 and explain the result.


import re

Acc_num = "ACC-1075"

details = """
Customer Rahul
Card: 1234-5678-9012-3456

Customer Priya
Card: 9876-1111-2222-4444

Customer Amit
Card: 5555-6666-7777-8888
"""

pattern = r"\b\d{4}-\d{4}-\d{4}-(\d{4})\b"

masked = re.sub(pattern,r"****-****-****-\1",details)

print("Account:", Acc_num)
print(masked)
# Out:
# Account: ACC-1075
#
# Customer Rahul
# Card: ****-****-****-3456
#
# Customer Priya
# Card: ****-****-****-4444
#
# Customer Amit
# Card: ****-****-****-8888

# %%
#Q76. Parse audit log entries with named groups for banking case 1; use sample reference ACC-1076 and explain the result.


import re

Acc_num = "ACC-1076"

logs = """
2026-09-11 | Rahul | LOGIN
2026-09-11 | Priya | TRANSFER
2026-09-11 | Amit | LOGOUT
"""

pattern = r"(?P<date>\d{4}-\d{2}-\d{2})\s*\|\s*(?P<user>[A-Za-z]+)\s*\|\s*(?P<action>[A-Z]+)"

for match in re.finditer(pattern, logs):
    print(match.groupdict())
# Out:
# {'date': '2026-09-11', 'user': 'Rahul', 'action': 'LOGIN'}
# {'date': '2026-09-11', 'user': 'Priya', 'action': 'TRANSFER'}
# {'date': '2026-09-11', 'user': 'Amit', 'action': 'LOGOUT'}

# %%
#Q77. Build a verbose-mode pattern for account holder ids for banking case 1; use sample reference ACC-1077 and explain the result.


import re

Acc_num = "ACC-1077"

holder_ids = [
    "AH-1001-IN",
    "AH-2002-US",
    "AH-3003-UK",
    "AH1004-IN",
    "AH-5005-IND"
]

pattern = re.compile(r"""
    ^               # Start of string
    AH              # Account Holder prefix
    -               # Hyphen
    \d{4}           # Exactly 4 digits
    -               # Hyphen
    [A-Z]{2}        # 2 uppercase country letters
    $               # End of string
""", re.VERBOSE)

for holder_id in holder_ids:
    if pattern.fullmatch(holder_id):
        print(holder_id, "-> Valid")
    else:
        print(holder_id, "-> Invalid")
### re.VERBOSE allows us to write a regex across multiple lines and include comments.
### It improves readability and maintainability of complex regular expressions by ignoring whitespace and comments inside the pattern.
# Out:
# AH-1001-IN -> Valid
# AH-2002-US -> Valid
# AH-3003-UK -> Valid
# AH1004-IN -> Invalid
# AH-5005-IND -> Invalid

# %%
#Q78. Avoid catastrophic backtracking in a interest offer pattern for banking case 1; use sample reference ACC-1078 and explain the result.


import re

Acc_num = "ACC-1078"

offer = "INTEREST-OFFER-15"

pattern = r"^[A-Z]+(?:-[A-Z]+)*-\d+$"

result = re.fullmatch(pattern, offer)

if result:
    print(f"{Acc_num} : Valid Interest Offer")
else:
    print(f"{Acc_num} : Invalid Interest Offer")

 ### Catastrophic backtracking occurs when a regex contains nested or overlapping quantifiers, causing excessive retry attempts during matching.
 ### To avoid it, use specific character classes, anchors, and non-ambiguous repetitions instead of patterns like (.+)+ or (.*)*.
  ### For ACC-1078, ^[A-Z]+(?:-[A-Z]+)*-\d+$ is a safe and efficient interest-offer validation pattern.
# Out:
# ACC-1078 : Valid Interest Offer

# %%
#Q79. Validate amount formats across supported currencies for banking case 1; use sample reference ACC-1079 and explain the result.


import re

Acc_num = "ACC-1079"

amount = "USD 1000.50"

pattern = r"^(USD|INR|EUR|GBP)\s\d+(?:\.\d{2})?$"

result = re.fullmatch(pattern, amount)

if result:
    print(f"{Acc_num} : Valid Amount Format")
else:
    print(f"{Acc_num} : Invalid Amount Format")
# Out:
# ACC-1079 : Valid Amount Format

# %%
#Q80. Create a regex-based data quality report for banking case 1; use sample reference ACC-1080 and explain the result.


import re

Acc_num = "ACC-1080"

records = [
    {
        "account": "ACC-1001",
        "email": "john@gmail.com",
        "phone": "9876543210"
    },
    {
        "account": "ACC1002",
        "email": "invalid@email",
        "phone": "98765"
    },
    {
        "account": "ACC-1003",
        "email": "support@banking.co.in",
        "phone": "9123456789"
    }
]

account_pattern = r"^ACC-\d{4}$"
email_pattern = r"^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$"
phone_pattern = r"^[6-9]\d{9}$"

valid_records = 0

for record in records:

    account_valid = bool(re.fullmatch(account_pattern, record["account"]))

    email_valid = bool(re.fullmatch(email_pattern, record["email"]))

    phone_valid = bool(re.fullmatch(phone_pattern, record["phone"]))

    status = (account_valid and email_valid and phone_valid)

    if status:
        valid_records += 1

    print("\nRecord:", record)
    print("Account :", account_valid)
    print("Email   :", email_valid)
    print("Phone   :", phone_valid)
    print("Status  :", "PASS" if status else "FAIL")

print("\n----- DATA QUALITY REPORT -----")
print("Total Records :", len(records))
print("Valid Records :", valid_records)
print("Invalid Records :", len(records) - valid_records)
# Out:
# Record: {'account': 'ACC-1001', 'email': 'john@gmail.com', 'phone': '9876543210'}
# Account : True
# Email   : True
# Phone   : True
# Status  : PASS
#
# Record: {'account': 'ACC1002', 'email': 'invalid@email', 'phone': '98765'}
# Account : False
# Email   : False
# Phone   : False
# Status  : FAIL
#
# Record: {'account': 'ACC-1003', 'email': 'support@banking.co.in', 'phone': '9123456789'}
# Account : True
# Email   : True
# Phone   : True
# Status  : PASS
#
# ----- DATA QUALITY REPORT -----
# Total Records : 3
# Valid Records : 2
# Invalid Records : 1

# %%
#Q81. Tokenize a messy receipt safely for banking case 2; use sample reference ACC-1081 and explain the result


import re

Acc_num = "ACC-1081"

receipt = """
Item: Laptop, Qty=2 | Price=55000;
Item: Mouse , Qty=3 || Price=600;
Payment: CARD-1234 ; Status: SUCCESS
"""

tokens = re.findall(r"\w+(?:-\w+)?", receipt)

print("Account:", Acc_num)
print("Tokens:", tokens)
# Out:
# Account: ACC-1081
# Tokens: ['Item', 'Laptop', 'Qty', '2', 'Price', '55000', 'Item', 'Mouse', 'Qty', '3', 'Price', '600', 'Payment', 'CARD-1234', 'Status', 'SUCCESS']

# %%
#Q82. Validate a multi-part warehouse location for banking case 2; use sample reference ACC-1082 and explain the result.


import re

Acc_num = "ACC-1082"

locations = [
    "WH-BNG-A1",
    "WH-HYD-B2",
    "WH-DEL-C10",
    "WH-MUM-12",
    "WH-BNG-AA1",
    "WH-bng-A1"
]

pattern = r"^WH-[A-Z]{3}-[A-Z]\d+$"

print("Account:", Acc_num)

for loc in locations:
    if re.fullmatch(pattern, loc):
        print(loc, "-> Valid")
    else:
        print(loc, "-> Invalid")
# Out:
# Account: ACC-1082
# WH-BNG-A1 -> Valid
# WH-HYD-B2 -> Valid
# WH-DEL-C10 -> Valid
# WH-MUM-12 -> Invalid
# WH-BNG-AA1 -> Invalid
# WH-bng-A1 -> Invalid

# %%
#Q83. Extract nested-looking account annotations within a defined limit for banking case 2; use sample reference ACC-1083 and explain the result.


import re

Acc_num = "ACC-1083"

details = """
Customer Rahul (Premium Customer)
Account ACC-1073 (VIP Level 2)
Branch (BNG Zone A)
Status (Active)
"""

pattern = r".*"

matches = re.findall(pattern, details)

print("Account:", Acc_num)

for m in matches:
    print(m)
# Out:
# Account: ACC-1083
#
# Customer Rahul (Premium Customer)
#
# Account ACC-1073 (VIP Level 2)
#
# Branch (BNG Zone A)
#
# Status (Active)

# %%
#Q84. Find duplicate adjacent account reference tokens with backreferences for banking case 2; use sample reference ACC-1084 and explain the result.


import re

Acc_num = "ACC-1084"

details = """
ACC1001 ACC1001
ACC2002 ACC3003
ACC4004 ACC4004
ACC5005 ACC5005
"""

pattern = r"\b(ACC\d+)\s+\1\b"

matches = re.findall(pattern, details)
### for replace that repeated value --- cleaned = re.sub(pattern, r"\1", details)  ------ r"\1" it will replace the value which is captured by 1st itraction

print("Account:", Acc_num)
print("Duplicate Adjacent References:")


for match in matches:
    print(match)
# Out:
# Account: ACC-1084
# Duplicate Adjacent References:
# ACC1001
# ACC4004
# ACC5005

# %%
#Q85. Redact card-like numbers while preserving last four digits for banking case 2; use sample reference ACC-1085 and explain the result.


import re

Acc_num = "ACC-1085"

details = """
Customer Rahul
Card: 1234-5678-9012-3456

Customer Priya
Card: 9876-1111-2222-4444

Customer Amit
Card: 5555-6666-7777-8888
"""

pattern = r"\b\d{4}-\d{4}-\d{4}-(\d{4})\b"

masked = re.sub(pattern,r"****-****-****-\1",details)

print("Account:", Acc_num)
print(masked)
# Out:
# Account: ACC-1085
#
# Customer Rahul
# Card: ****-****-****-3456
#
# Customer Priya
# Card: ****-****-****-4444
#
# Customer Amit
# Card: ****-****-****-8888

# %%
#Q86. Parse audit log entries with named groups for banking case 2; use sample reference ACC-1086 and explain the result.


import re

Acc_num = "ACC-1086"

logs = """
2026-09-11 | Rahul | LOGIN
2026-09-11 | Priya | TRANSFER
2026-09-11 | Amit | LOGOUT
"""

pattern = r"(?P<date>\d{4}-\d{2}-\d{2})\s*\|\s*(?P<user>[A-Za-z]+)\s*\|\s*(?P<action>[A-Z]+)"

for match in re.finditer(pattern, logs):
    print(match.groupdict())
# Out:
# {'date': '2026-09-11', 'user': 'Rahul', 'action': 'LOGIN'}
# {'date': '2026-09-11', 'user': 'Priya', 'action': 'TRANSFER'}
# {'date': '2026-09-11', 'user': 'Amit', 'action': 'LOGOUT'}

# %%
#Q87. Build a verbose-mode pattern for account holder ids for banking case 2; use sample reference ACC-1087 and explain the result.


import re

Acc_num = "ACC-1087"

holder_ids = [
    "AH-1001-IN",
    "AH-2002-US",
    "AH-3003-UK",
    "AH1004-IN",
    "AH-5005-IND"
]

pattern = re.compile(r"""
    ^               # Start of string
    AH              # Account Holder prefix
    -               # Hyphen
    \d{4}           # Exactly 4 digits
    -               # Hyphen
    [A-Z]{2}        # 2 uppercase country letters
    $               # End of string
""", re.VERBOSE)

for holder_id in holder_ids:
    if pattern.fullmatch(holder_id):
        print(holder_id, "-> Valid")
    else:
        print(holder_id, "-> Invalid")
### re.VERBOSE allows us to write a regex across multiple lines and include comments.
### It improves readability and maintainability of complex regular expressions by ignoring whitespace and comments inside the pattern.
# Out:
# AH-1001-IN -> Valid
# AH-2002-US -> Valid
# AH-3003-UK -> Valid
# AH1004-IN -> Invalid
# AH-5005-IND -> Invalid

# %%
#Q88. Avoid catastrophic backtracking in a interest offer pattern for banking case 2; use sample reference ACC-1088 and explain the result.


import re

Acc_num = "ACC-1088"

offer = "INTEREST-OFFER-15"

pattern = r"^[A-Z]+(?:-[A-Z]+)*-\d+$"

result = re.fullmatch(pattern, offer)

if result:
    print(f"{Acc_num} : Valid Interest Offer")
else:
    print(f"{Acc_num} : Invalid Interest Offer")

 ### Catastrophic backtracking occurs when a regex contains nested or overlapping quantifiers, causing excessive retry attempts during matching.
 ### To avoid it, use specific character classes, anchors, and non-ambiguous repetitions instead of patterns like (.+)+ or (.*)*.
  ### For ACC-1078, ^[A-Z]+(?:-[A-Z]+)*-\d+$ is a safe and efficient interest-offer validation pattern.
# Out:
# ACC-1088 : Valid Interest Offer

# %%
#Q89. Validate amount formats across supported currencies for banking case 2; use sample reference ACC-1089 and explain the result.


import re

Acc_num = "ACC-1089"

amount = "USD 1000.50"

pattern = r"^(USD|INR|EUR|GBP)\s\d+(?:\.\d{2})?$"

result = re.fullmatch(pattern, amount)

if result:
    print(f"{Acc_num} : Valid Amount Format")
else:
    print(f"{Acc_num} : Invalid Amount Format")
# Out:
# ACC-1089 : Valid Amount Format

# %%
#Q90. Create a regex-based data quality report for banking case 2; use sample reference ACC-1090 and explain the result.


import re

Acc_num = "ACC-1090"

records = [
    {
        "account": "ACC-1001",
        "email": "john@gmail.com",
        "phone": "9876543210"
    },
    {
        "account": "ACC1002",
        "email": "invalid@email",
        "phone": "98765"
    },
    {
        "account": "ACC-1003",
        "email": "support@banking.co.in",
        "phone": "9123456789"
    }
]

account_pattern = r"^ACC-\d{4}$"
email_pattern = r"^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$"
phone_pattern = r"^[6-9]\d{9}$"

valid_records = 0

for record in records:

    account_valid = bool(re.fullmatch(account_pattern, record["account"]))

    email_valid = bool(re.fullmatch(email_pattern, record["email"]))

    phone_valid = bool(re.fullmatch(phone_pattern, record["phone"]))

    status = (account_valid and email_valid and phone_valid)

    if status:
        valid_records += 1

    print("\nRecord:", record)
    print("Account :", account_valid)
    print("Email   :", email_valid)
    print("Phone   :", phone_valid)
    print("Status  :", "PASS" if status else "FAIL")

print("\n----- DATA QUALITY REPORT -----")
print("Total Records :", len(records))
print("Valid Records :", valid_records)
print("Invalid Records :", len(records) - valid_records)
# Out:
# Record: {'account': 'ACC-1001', 'email': 'john@gmail.com', 'phone': '9876543210'}
# Account : True
# Email   : True
# Phone   : True
# Status  : PASS
#
# Record: {'account': 'ACC1002', 'email': 'invalid@email', 'phone': '98765'}
# Account : False
# Email   : False
# Phone   : False
# Status  : FAIL
#
# Record: {'account': 'ACC-1003', 'email': 'support@banking.co.in', 'phone': '9123456789'}
# Account : True
# Email   : True
# Phone   : True
# Status  : PASS
#
# ----- DATA QUALITY REPORT -----
# Total Records : 3
# Valid Records : 2
# Invalid Records : 1

# %%
#Q91. Tokenize a messy receipt safely for banking case 3; use sample reference ACC-1091 and explain the result.


import re

Acc_num = "ACC-1091"

receipt = """
Item: Laptop, Qty=2 | Price=55000;
Item: Mouse , Qty=3 || Price=600;
Payment: CARD-1234 ; Status: SUCCESS
"""

tokens = re.findall(r"\w+(?:-\w+)?", receipt)

print("Account:", Acc_num)
print("Tokens:", tokens)
# Out:
# Account: ACC-1091
# Tokens: ['Item', 'Laptop', 'Qty', '2', 'Price', '55000', 'Item', 'Mouse', 'Qty', '3', 'Price', '600', 'Payment', 'CARD-1234', 'Status', 'SUCCESS']

# %%
#Q92. Validate a multi-part warehouse location for banking case 3; use sample reference ACC-1092 and explain the result.


import re

Acc_num = "ACC-1092"

locations = [
    "WH-BNG-A1",
    "WH-HYD-B2",
    "WH-DEL-C10",
    "WH-MUM-12",
    "WH-BNG-AA1",
    "WH-bng-A1"
]

pattern = r"^WH-[A-Z]{3}-[A-Z]\d+$"

print("Account:", Acc_num)

for loc in locations:
    if re.fullmatch(pattern, loc):
        print(loc, "-> Valid")
    else:
        print(loc, "-> Invalid")
# Out:
# Account: ACC-1092
# WH-BNG-A1 -> Valid
# WH-HYD-B2 -> Valid
# WH-DEL-C10 -> Valid
# WH-MUM-12 -> Invalid
# WH-BNG-AA1 -> Invalid
# WH-bng-A1 -> Invalid

# %%
#Q93. Extract nested-looking account annotations within a defined limit for banking case 3; use sample reference ACC-1093 and explain the result.


import re

Acc_num = "ACC-1093"

details = """
Customer Rahul (Premium Customer)
Account ACC-1073 (VIP Level 2)
Branch (BNG Zone A)
Status (Active)
"""

pattern = r".*"

matches = re.findall(pattern, details)

print("Account:", Acc_num)

for m in matches:
    print(m)
# Out:
# Account: ACC-1093
#
# Customer Rahul (Premium Customer)
#
# Account ACC-1073 (VIP Level 2)
#
# Branch (BNG Zone A)
#
# Status (Active)

# %%
#Q94. Find duplicate adjacent account reference tokens with backreferences for banking case 3; use sample reference ACC-1094 and explain the result.


import re

Acc_num = "ACC-1094"

details = """
ACC1001 ACC1001
ACC2002 ACC3003
ACC4004 ACC4004
ACC5005 ACC5005
"""

pattern = r"\b(ACC\d+)\s+\1\b"

matches = re.findall(pattern, details)
### for replace that repeated value --- cleaned = re.sub(pattern, r"\1", details)  ------ r"\1" it will replace the value which is captured by 1st itraction

print("Account:", Acc_num)
print("Duplicate Adjacent References:")


for match in matches:
    print(match)
# Out:
# Account: ACC-1094
# Duplicate Adjacent References:
# ACC1001
# ACC4004
# ACC5005

# %%
#Q95. Redact card-like numbers while preserving last four digits for banking case 3; use sample reference ACC-1095 and explain the result.


import re

Acc_num = "ACC-1095"

details = """
Customer Rahul
Card: 1234-5678-9012-3456

Customer Priya
Card: 9876-1111-2222-4444

Customer Amit
Card: 5555-6666-7777-8888
"""

pattern = r"\b\d{4}-\d{4}-\d{4}-(\d{4})\b"

masked = re.sub(pattern,r"****-****-****-\1",details)

print("Account:", Acc_num)
print(masked)
# Out:
# Account: ACC-1095
#
# Customer Rahul
# Card: ****-****-****-3456
#
# Customer Priya
# Card: ****-****-****-4444
#
# Customer Amit
# Card: ****-****-****-8888

# %%
#Q96. Parse audit log entries with named groups for banking case 3; use sample reference ACC-1096 and explain the result.


import re

Acc_num = "ACC-1096"

logs = """
2026-09-11 | Rahul | LOGIN
2026-09-11 | Priya | TRANSFER
2026-09-11 | Amit | LOGOUT
"""

pattern = r"(?P<date>\d{4}-\d{2}-\d{2})\s*\|\s*(?P<user>[A-Za-z]+)\s*\|\s*(?P<action>[A-Z]+)"

for match in re.finditer(pattern, logs):
    print(match.groupdict())
# Out:
# {'date': '2026-09-11', 'user': 'Rahul', 'action': 'LOGIN'}
# {'date': '2026-09-11', 'user': 'Priya', 'action': 'TRANSFER'}
# {'date': '2026-09-11', 'user': 'Amit', 'action': 'LOGOUT'}

# %%
#Q97. Build a verbose-mode pattern for account holder ids for banking case 3; use sample reference ACC-1097 and explain the result.


import re

Acc_num = "ACC-1097"

holder_ids = [
    "AH-1001-IN",
    "AH-2002-US",
    "AH-3003-UK",
    "AH1004-IN",
    "AH-5005-IND"
]

pattern = re.compile(r"""
    ^               # Start of string
    AH              # Account Holder prefix
    -               # Hyphen
    \d{4}           # Exactly 4 digits
    -               # Hyphen
    [A-Z]{2}        # 2 uppercase country letters
    $               # End of string
""", re.VERBOSE)

for holder_id in holder_ids:
    if pattern.fullmatch(holder_id):
        print(holder_id, "-> Valid")
    else:
        print(holder_id, "-> Invalid")
### re.VERBOSE allows us to write a regex across multiple lines and include comments.
### It improves readability and maintainability of complex regular expressions by ignoring whitespace and comments inside the pattern.
# Out:
# AH-1001-IN -> Valid
# AH-2002-US -> Valid
# AH-3003-UK -> Valid
# AH1004-IN -> Invalid
# AH-5005-IND -> Invalid

# %%
#Q98. Avoid catastrophic backtracking in a interest offer pattern for banking case 3; use sample reference ACC-1098 and explain the result.


import re

Acc_num = "ACC-1098"

offer = "INTEREST-OFFER-15"

pattern = r"^[A-Z]+(?:-[A-Z]+)*-\d+$"

result = re.fullmatch(pattern, offer)

if result:
    print(f"{Acc_num} : Valid Interest Offer")
else:
    print(f"{Acc_num} : Invalid Interest Offer")

 ### Catastrophic backtracking occurs when a regex contains nested or overlapping quantifiers, causing excessive retry attempts during matching.
 ### To avoid it, use specific character classes, anchors, and non-ambiguous repetitions instead of patterns like (.+)+ or (.*)*.
  ### For ACC-1078, ^[A-Z]+(?:-[A-Z]+)*-\d+$ is a safe and efficient interest-offer validation pattern.
# Out:
# ACC-1098 : Valid Interest Offer

# %%
#Q99. Validate amount formats across supported currencies for banking case 3; use sample reference ACC-1099 and explain the result.


import re

Acc_num = "ACC-1099"

amount = "USD 1000.50"

pattern = r"^(USD|INR|EUR|GBP)\s\d+(?:\.\d{2})?$"

result = re.fullmatch(pattern, amount)

if result:
    print(f"{Acc_num} : Valid Amount Format")
else:
    print(f"{Acc_num} : Invalid Amount Format")
# Out:
# ACC-1099 : Valid Amount Format

# %%
#Q100. Create a regex-based data quality report for banking case 3; use sample reference ACC-1100 and explain the result.


import re

Acc_num = "ACC-1090"

records = [
    {
        "account": "ACC-1001",
        "email": "john@gmail.com",
        "phone": "9876543210"
    },
    {
        "account": "ACC1002",
        "email": "invalid@email",
        "phone": "98765"
    },
    {
        "account": "ACC-1003",
        "email": "support@banking.co.in",
        "phone": "9123456789"
    }
]

account_pattern = r"^ACC-\d{4}$"
email_pattern = r"^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$"
phone_pattern = r"^[6-9]\d{9}$"

valid_records = 0

for record in records:

    account_valid = bool(re.fullmatch(account_pattern, record["account"]))

    email_valid = bool(re.fullmatch(email_pattern, record["email"]))

    phone_valid = bool(re.fullmatch(phone_pattern, record["phone"]))

    status = (account_valid and email_valid and phone_valid)

    if status:
        valid_records += 1

    print("\nRecord:", record)
    print("Account :", account_valid)
    print("Email   :", email_valid)
    print("Phone   :", phone_valid)
    print("Status  :", "PASS" if status else "FAIL")

print("\n----- DATA QUALITY REPORT -----")
print("Total Records :", len(records))
print("Valid Records :", valid_records)
print("Invalid Records :", len(records) - valid_records)
# Out:
# Record: {'account': 'ACC-1001', 'email': 'john@gmail.com', 'phone': '9876543210'}
# Account : True
# Email   : True
# Phone   : True
# Status  : PASS
#
# Record: {'account': 'ACC1002', 'email': 'invalid@email', 'phone': '98765'}
# Account : False
# Email   : False
# Phone   : False
# Status  : FAIL
#
# Record: {'account': 'ACC-1003', 'email': 'support@banking.co.in', 'phone': '9123456789'}
# Account : True
# Email   : True
# Phone   : True
# Status  : PASS
#
# ----- DATA QUALITY REPORT -----
# Total Records : 3
# Valid Records : 2
# Invalid Records : 1
